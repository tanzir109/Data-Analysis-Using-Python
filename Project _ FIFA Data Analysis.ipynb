# %% [markdown]
# # <center>FIFA 21 DATA ANALYSIS</center>
# ![Cover](https://www.griffinsgamingguides.com/wp-content/uploads/2020/09/FIFA-21-Intro-Image.png)

# %% [markdown]
# # <i>RESOURCES OF THE DATASETS USED IN THIS PROJECT</i>

# %% [markdown]
# ### <li><strong>all.csv (contains all information about the players in FIFA 21)</strong> -  <a href="https://www.kaggle.com/stefanoleone992/fifa-21-complete-player-dataset?select=players_21.csv">Source</a><br>
# The given dataset was taken from the dataset bundle present in Kaggle Datasets.
# ### <li> <strong>ballon.csv (contains all informations about Ballon D'Or award winners)</strong> -  <a href="https://raw.githubusercontent.com/Sourajyoti1234/FIFA21_required_csv_files/main/BallonDOr.csv">Source</a>
# This ballon.csv data has been scraped from Wikepedia using <a href="https://wikitable2csv.ggor.de/">Tool Source</a>.
# Wikedpedia Source - <a href="https://en.wikipedia.org/wiki/Ballon_d%27Or">Click</a>

# %% [markdown]
# ## Downloading the Dataset

# %%
import numpy as np
import pandas as pd
from urllib.request import urlretrieve

# %% [markdown]
# Let's begin by downloading the data, and listing the files within the dataset.

# %%
urlretrieve('https://raw.githubusercontent.com/Sourajyoti1234/FIFA21_required_csv_files/main/BallonDOr.csv','ballon.csv')
urlretrieve('https://raw.githubusercontent.com/Sourajyoti1234/FIFA21_required_csv_files/main/players_21.csv','all.csv');

# %% [markdown]
# ## Data Preparation and Cleaning
#
# >  <strong>Let's convert these csv files into pandas dataframe for our future analysis.</strong><br>
# >  <strong>We also have to check whether any null value present inside the dataframe or not before analysis.</strong>

# %%
fifa_df = pd.read_csv("all.csv") # taking csv to pandas dataframe.
fifa_df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3         188545  https://sofifa.com/player/188545/robert-lewand...
# 4         190871  https://sofifa.com/player/190871/neymar-da-sil...
# ...          ...                                                ...
# 18939     256679  https://sofifa.com/player/256679/kevin-angulo/...
# 18940     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18941     250989  https://sofifa.com/player/250989/zhenghao-wang...
# 18942     257697  https://sofifa.com/player/257697/zitong-chen/2...
# 18943     257936   https://sofifa.com/player/257936/yue-song/210002
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   33
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35
# 2               J. Oblak                            Jan Oblak   27
# 3         R. Lewandowski                   Robert Lewandowski   31
# 4              Neymar Jr        Neymar da Silva Santos Júnior   28
# ...                  ...                                  ...  ...
# 18939          K. Angulo                         Kevin Angulo   24
# 18940     Zhang Mengxuan                       Mengxuan Zhang   21
# 18941      Wang Zhenghao                                  王政豪   20
# 18942        Chen Zitong                          Zitong Chen   23
# 18943           Song Yue                             Yue Song   28
#
#               dob  height_cm  weight_kg nationality  \
# 0      1987-06-24        170         72   Argentina
# 1      1985-02-05        187         83    Portugal
# 2      1993-01-07        188         87    Slovenia
# 3      1988-08-21        184         80      Poland
# 4      1992-02-05        175         68      Brazil
# ...           ...        ...        ...         ...
# 18939  1996-04-13        176         73    Colombia
# 18940  1999-04-26        177         70    China PR
# 18941  2000-06-28        185         74    China PR
# 18942  1997-02-20        186         80    China PR
# 18943  1991-11-20        185         79    China PR
#
#                                  club_name  ...   lwb   ldm   cdm   rdm   rwb  \
# 0                             FC Barcelona  ...  66+3  65+3  65+3  65+3  66+3
# 1                                 Juventus  ...  65+3  61+3  61+3  61+3  65+3
# 2                          Atlético Madrid  ...  32+3  36+3  36+3  36+3  32+3
# 3                        FC Bayern München  ...  64+3  65+3  65+3  65+3  64+3
# 4                      Paris Saint-Germain  ...  67+3  62+3  62+3  62+3  67+3
# ...                                    ...  ...   ...   ...   ...   ...   ...
# 18939                      América de Cali  ...  47+2  47+2  47+2  47+2  47+2
# 18940  Chongqing Dangdai Lifan FC SWM Team  ...  42+2  41+2  41+2  41+2  42+2
# 18941                      Tianjin TEDA FC  ...  42+2  42+2  42+2  42+2  42+2
# 18942        Shijiazhuang Ever Bright F.C.  ...  47+2  49+2  49+2  49+2  47+2
# 18943                      Tianjin TEDA FC  ...  47+0  47+0  47+0  47+0  47+0
#
#          lb   lcb    cb   rcb    rb
# 0      62+3  52+3  52+3  52+3  62+3
# 1      61+3  54+3  54+3  54+3  61+3
# 2      32+3  33+3  33+3  33+3  32+3
# 3      61+3  60+3  60+3  60+3  61+3
# 4      62+3  49+3  49+3  49+3  62+3
# ...     ...   ...   ...   ...   ...
# 18939  47+2  46+2  46+2  46+2  47+2
# 18940  45+2  47+2  47+2  47+2  45+2
# 18941  44+2  47+2  47+2  47+2  44+2
# 18942  47+2  49+2  49+2  49+2  47+2
# 18943  47+0  46+1  46+1  46+1  47+0
#
# [18944 rows x 106 columns]

# %%
fifa_df = fifa_df.drop(['sofifa_id', "player_url", "long_name", "dob", "team_jersey_number"], axis = 1)

# %%
fifa_df=fifa_df.rename(columns={'short_name':'name'}) #renaming 'short_name' to name for easy use
fifa_df
# Out:
#                     name  age  height_cm  weight_kg nationality  \
# 0               L. Messi   33        170         72   Argentina
# 1      Cristiano Ronaldo   35        187         83    Portugal
# 2               J. Oblak   27        188         87    Slovenia
# 3         R. Lewandowski   31        184         80      Poland
# 4              Neymar Jr   28        175         68      Brazil
# ...                  ...  ...        ...        ...         ...
# 18939          K. Angulo   24        176         73    Colombia
# 18940     Zhang Mengxuan   21        177         70    China PR
# 18941      Wang Zhenghao   20        185         74    China PR
# 18942        Chen Zitong   23        186         80    China PR
# 18943           Song Yue   28        185         79    China PR
#
#                                  club_name              league_name  \
# 0                             FC Barcelona   Spain Primera Division
# 1                                 Juventus          Italian Serie A
# 2                          Atlético Madrid   Spain Primera Division
# 3                        FC Bayern München     German 1. Bundesliga
# 4                      Paris Saint-Germain           French Ligue 1
# ...                                    ...                      ...
# 18939                      América de Cali  Colombian Liga Postobón
# 18940  Chongqing Dangdai Lifan FC SWM Team     Chinese Super League
# 18941                      Tianjin TEDA FC     Chinese Super League
# 18942        Shijiazhuang Ever Bright F.C.     Chinese Super League
# 18943                      Tianjin TEDA FC     Chinese Super League
#
#        league_rank  overall  potential  ...   lwb   ldm   cdm   rdm   rwb  \
# 0              1.0       93         93  ...  66+3  65+3  65+3  65+3  66+3
# 1              1.0       92         92  ...  65+3  61+3  61+3  61+3  65+3
# 2              1.0       91         93  ...  32+3  36+3  36+3  36+3  32+3
# 3              1.0       91         91  ...  64+3  65+3  65+3  65+3  64+3
# 4              1.0       91         91  ...  67+3  62+3  62+3  62+3  67+3
# ...            ...      ...        ...  ...   ...   ...   ...   ...   ...
# 18939          1.0       47         52  ...  47+2  47+2  47+2  47+2  47+2
# 18940          1.0       47         52  ...  42+2  41+2  41+2  41+2  42+2
# 18941          1.0       47         51  ...  42+2  42+2  42+2  42+2  42+2
# 18942          1.0       47         51  ...  47+2  49+2  49+2  49+2  47+2
# 18943          1.0       47         47  ...  47+0  47+0  47+0  47+0  47+0
#
#          lb   lcb    cb   rcb    rb
# 0      62+3  52+3  52+3  52+3  62+3
# 1      61+3  54+3  54+3  54+3  61+3
# 2      32+3  33+3  33+3  33+3  32+3
# 3      61+3  60+3  60+3  60+3  61+3
# 4      62+3  49+3  49+3  49+3  62+3
# ...     ...   ...   ...   ...   ...
# 18939  47+2  46+2  46+2  46+2  47+2
# 18940  45+2  47+2  47+2  47+2  45+2
# 18941  44+2  47+2  47+2  47+2  44+2
# 18942  47+2  49+2  49+2  49+2  47+2
# 18943  47+0  46+1  46+1  46+1  47+0
#
# [18944 rows x 101 columns]

# %%
#Columns with NaN null values
fifa_df.columns[fifa_df.isna().any()]
# Out:
# Index([], dtype='object')

# %%
#Dropping unnecessary columns which are filled with NaN values
fifa_df=fifa_df.drop(['player_traits', 'defending_marking','release_clause_eur',
       'player_tags', 'team_position', 'loaned_from', 'joined',
       'contract_valid_until', 'nation_position', 'nation_jersey_number','st','rs','lw','lf','cf',
        'rf','rw','lam','cam','ram','lm','lcm','cm','rcm','rm','lwb','ldm','cdm','rdm','rwb','lb','lcb','ls','cb','rcb','rb'],axis=1)
fifa_df
# Out:
#                     name  age  height_cm  weight_kg nationality  \
# 0               L. Messi   33        170         72   Argentina
# 1      Cristiano Ronaldo   35        187         83    Portugal
# 2               J. Oblak   27        188         87    Slovenia
# 3         R. Lewandowski   31        184         80      Poland
# 4              Neymar Jr   28        175         68      Brazil
# ...                  ...  ...        ...        ...         ...
# 18939          K. Angulo   24        176         73    Colombia
# 18940     Zhang Mengxuan   21        177         70    China PR
# 18941      Wang Zhenghao   20        185         74    China PR
# 18942        Chen Zitong   23        186         80    China PR
# 18943           Song Yue   28        185         79    China PR
#
#                                  club_name              league_name  \
# 0                             FC Barcelona   Spain Primera Division
# 1                                 Juventus          Italian Serie A
# 2                          Atlético Madrid   Spain Primera Division
# 3                        FC Bayern München     German 1. Bundesliga
# 4                      Paris Saint-Germain           French Ligue 1
# ...                                    ...                      ...
# 18939                      América de Cali  Colombian Liga Postobón
# 18940  Chongqing Dangdai Lifan FC SWM Team     Chinese Super League
# 18941                      Tianjin TEDA FC     Chinese Super League
# 18942        Shijiazhuang Ever Bright F.C.     Chinese Super League
# 18943                      Tianjin TEDA FC     Chinese Super League
#
#        league_rank  overall  potential  ...  mentality_vision  \
# 0              1.0       93         93  ...                95
# 1              1.0       92         92  ...                82
# 2              1.0       91         93  ...                65
# 3              1.0       91         91  ...                79
# 4              1.0       91         91  ...                90
# ...            ...      ...        ...  ...               ...
# 18939          1.0       47         52  ...                49
# 18940          1.0       47         52  ...                25
# 18941          1.0       47         51  ...                25
# 18942          1.0       47         51  ...                45
# 18943          1.0       47         47  ...                44
#
#        mentality_penalties mentality_composure defending_standing_tackle  \
# 0                       75                  96                        35
# 1                       84                  95                        32
# 2                       11                  68                        12
# 3                       88                  88                        42
# 4                       92                  93                        30
# ...                    ...                 ...                       ...
# 18939                   39                  36                        39
# 18940                   35                  40                        56
# 18941                   35                  40                        55
# 18942                   42                  43                        49
# 18943                   36                  35                        43
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                            24                   6                    11
# 1                            24                   7                    11
# 2                            18                  87                    92
# 3                            19                  15                     6
# 4                            29                   9                     9
# ...                         ...                 ...                   ...
# 18939                        54                  10                     9
# 18940                        47                  12                    13
# 18941                        45                  12                     9
# 18942                        45                  15                     7
# 18943                        45                   8                     5
#
#       goalkeeping_kicking goalkeeping_positioning goalkeeping_reflexes
# 0                      15                      14                    8
# 1                      15                      14                   11
# 2                      78                      90                   90
# 3                      12                       8                   10
# 4                      15                      15                   11
# ...                   ...                     ...                  ...
# 18939                  14                       6                    6
# 18940                   8                      14                    6
# 18941                  14                      15                   13
# 18942                   7                       5                   13
# 18943                  11                       5                    7
#
# [18944 rows x 65 columns]

# %%
#checking for NaN values 
fifa_df.isna().any().any()
# Out:
# False

# %% [markdown]
# isna().any().any() gives bool value 'True' that means there are some null(NaN) values.

# %%
#Taking only 'club_name' columns which has proper value
fifa_df=fifa_df[fifa_df['club_name'].notna()]
fifa_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'club_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 2
#       1 #Taking only 'club_name' columns which has proper value
# ----> 2 fifa_df=fifa_df[fifa_df['club_name'].notna()]
#       3 fifa_df
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'club_name'

# %%
#Filling remaining null values with 0
fifa_df.fillna(0)
# Out:
#                     name  age  height_cm  weight_kg nationality  \
# 0               L. Messi   33        170         72   Argentina
# 1      Cristiano Ronaldo   35        187         83    Portugal
# 2               J. Oblak   27        188         87    Slovenia
# 3         R. Lewandowski   31        184         80      Poland
# 4              Neymar Jr   28        175         68      Brazil
# ...                  ...  ...        ...        ...         ...
# 18939          K. Angulo   24        176         73    Colombia
# 18940     Zhang Mengxuan   21        177         70    China PR
# 18941      Wang Zhenghao   20        185         74    China PR
# 18942        Chen Zitong   23        186         80    China PR
# 18943           Song Yue   28        185         79    China PR
#
#                                  club_name              league_name  \
# 0                             FC Barcelona   Spain Primera Division
# 1                                 Juventus          Italian Serie A
# 2                          Atlético Madrid   Spain Primera Division
# 3                        FC Bayern München     German 1. Bundesliga
# 4                      Paris Saint-Germain           French Ligue 1
# ...                                    ...                      ...
# 18939                      América de Cali  Colombian Liga Postobón
# 18940  Chongqing Dangdai Lifan FC SWM Team     Chinese Super League
# 18941                      Tianjin TEDA FC     Chinese Super League
# 18942        Shijiazhuang Ever Bright F.C.     Chinese Super League
# 18943                      Tianjin TEDA FC     Chinese Super League
#
#        league_rank  overall  potential  ...  mentality_vision  \
# 0              1.0       93         93  ...                95
# 1              1.0       92         92  ...                82
# 2              1.0       91         93  ...                65
# 3              1.0       91         91  ...                79
# 4              1.0       91         91  ...                90
# ...            ...      ...        ...  ...               ...
# 18939          1.0       47         52  ...                49
# 18940          1.0       47         52  ...                25
# 18941          1.0       47         51  ...                25
# 18942          1.0       47         51  ...                45
# 18943          1.0       47         47  ...                44
#
#        mentality_penalties mentality_composure defending_standing_tackle  \
# 0                       75                  96                        35
# 1                       84                  95                        32
# 2                       11                  68                        12
# 3                       88                  88                        42
# 4                       92                  93                        30
# ...                    ...                 ...                       ...
# 18939                   39                  36                        39
# 18940                   35                  40                        56
# 18941                   35                  40                        55
# 18942                   42                  43                        49
# 18943                   36                  35                        43
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                            24                   6                    11
# 1                            24                   7                    11
# 2                            18                  87                    92
# 3                            19                  15                     6
# 4                            29                   9                     9
# ...                         ...                 ...                   ...
# 18939                        54                  10                     9
# 18940                        47                  12                    13
# 18941                        45                  12                     9
# 18942                        45                  15                     7
# 18943                        45                   8                     5
#
#       goalkeeping_kicking goalkeeping_positioning goalkeeping_reflexes
# 0                      15                      14                    8
# 1                      15                      14                   11
# 2                      78                      90                   90
# 3                      12                       8                   10
# 4                      15                      15                   11
# ...                   ...                     ...                  ...
# 18939                  14                       6                    6
# 18940                   8                      14                    6
# 18941                  14                      15                   13
# 18942                   7                       5                   13
# 18943                  11                       5                    7
#
# [18719 rows x 65 columns]

# %%
for i in fifa_df.columns:
    fifa_df[i]=fifa_df[i].replace(np.nan,0)
fifa_df.isnull().values.any()
# Out:
# False

# %% [markdown]
# fifa_df.isnull().values.any() gives boolean value 'False' it means there is no null value present inside the fifa_df dataframe.

# %%
print('The number of rows : {}'.format(fifa_df.shape[0]))
print('The number of columns :{}'.format(fifa_df.shape[1]))
# Out:
# The number of rows : 18719
# The number of columns :65

# %%
fifa_df.columns
# Out:
# Index(['name', 'age', 'height_cm', 'weight_kg', 'nationality', 'club_name',
#        'league_name', 'league_rank', 'overall', 'potential', 'value_eur',
#        'wage_eur', 'player_positions', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
#        'body_type', 'real_face', 'pace', 'shooting', 'passing', 'dribbling',
#        'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking',
#        'gk_reflexes', 'gk_speed', 'gk_positioning', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
#        'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
#        'movement_agility', 'movement_reactions', 'movement_balance',
#        'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
#        'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_standing_tackle',
#        'defending_sliding_tackle', 'goalkeeping_diving',
#        'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes'],
#       dtype='object')

# %%
fifa_df[["name", "nationality", "club_name", "age"]][fifa_df.nationality == "Brazil"] # "." to get to individual value.
# Out:
#                 name nationality            club_name  age
# 4          Neymar Jr      Brazil  Paris Saint-Germain   28
# 9            Alisson      Brazil            Liverpool   27
# 17          Casemiro      Brazil          Real Madrid   28
# 18           Ederson      Brazil      Manchester City   26
# 32           Fabinho      Brazil            Liverpool   26
# ...              ...         ...                  ...  ...
# 17023     Vintecinco      Brazil          Busan IPark   24
# 17028          Diogo      Brazil   Club Plaza Colonia   23
# 17392        Phelipe      Brazil            FC Dallas   21
# 17598  Bernardo Rosa      Brazil      West Ham United   19
# 17826     Yago Gomes      Brazil             FC Vaduz   18
#
# [885 rows x 4 columns]

# %%
print("Country wise each player list\n\n")
for country in fifa_df.nationality.unique():
    print("-"*25+country+'-'*25)
    country_df = fifa_df[["name", "nationality"]][fifa_df.nationality == country]
    for players in country_df.name:
        print(players)
# Out:
# Country wise each player list
#
#
# -------------------------Argentina-------------------------
# L. Messi
# S. Agüero
# P. Dybala
# A. Di María
# A. Gómez
# M. Icardi
# L. Martínez
# N. Tagliafico
# G. Higuaín
# E. Banega
# M. Acuña
# G. Lo Celso
# A. Correa
# G. Rulli
# L. Ocampos
# A. Marchesín
# W. Benítez
# J. Correa
# E. Andrada
# E. Salvio
# I. Fernández
# J. Musso
# E. Lamela
# S. Romero
# E. Pérez
# F. Armani
# C. Pavón
# L. Paredes
# E. Ávila
# J. Mascherano
# D. Valeri
# N. Guzmán
# D. Perotti
# N. Otamendi
# D. Benedetto
# F. Monteseirín
# L. Acosta
# B. Blasi
# L. Heredia
# T. Martínez
# L. Boyé
# F. Escobar
# N. Tripichio
# D. Sappa
# H. Fertoli
# L. Comas
# N. Leguizamón
# N. Morgantini
# N. Freire
# M. Herrera
# Marcos Mauro
# V. Cabrera
# J. Galván
# F. Álvarez
# J. Gutiérrez
# M. Silvestre
# N. Spolli
# F. González
# B. Urribarri
# F. Monzón
# M. Formica
# M. Coronel
# S. Araujo
# C. Insaurralde
# C. Chávez
# O. Benítez
# D. Rodríguez
# J. Burrai
# F. Milo
# M. Urruti
# J. Garro
# F. Cerro
# G. Campi
# C. Ortiz
# M. Riquelme
# N. Leyes
# R. Noya
# D. Lemos
# F. Sbuttoni
# R. Aliendro
# J. Segovia
# J. Rodríguez
# A. Manchot
# A. Ramúa
# M. Pellegrini
# M. Retegui
# L. Balerdi
# A. Barreal
# J. Cacciabue
# E. Coacci
# G. Ferrari
# J. Torres
# J. Carranza
# F. Nadalín
# L. Maciel
# M. Carabajal
# A. Fontana
# L. Gómez
# N. Linares
# F. Varela
# J. Devecchi
# M. Vera
# S. Colombatto
# B. Merlini
# M. Ortíz
# N. Paz
# E. Isnaldo
# E. Martínez
# N. Maná
# M. Comba
# J. Gandolfi
# A. Ríos
# G. Sauro
# L. Marín
# F. Bordagaray
# S. Vergini
# P. Rodríguez
# F. Barrientos
# E. Orfano
# M. Mantovani
# L. Barrera
# N. Aguirre
# N. Ibáñez
# E. Olivera
# F. Fontanini
# L. Lollo
# E. Triverio
# O. Cabral
# L. Geminiani
# N. Gorosito
# R. González
# M. Gagliardo
# A. Martínez
# C. Beltrán
# F. Vera
# B. Rollheiser
# M. Ojeda
# A. Almendra
# L. Necul
# L. Orellano
# F. Colidio
# N. Capaldo
# N. Molina
# S. Callegari
# F. Moyano
# R. Ramírez
# B. Rivero
# M. Peano
# F. Mac Allister
# E. Iñíguez
# M. Guanini
# F. Russo
# C. Valenzuela
# H. Tijanovich
# F. Henríquez
# G. Gil Romero
# G. Piovi
# N. Stefanelli
# S. Rosales
# F. Andrada
# M. De Iriondo
# R. Arciero
# M. Caranta
# L. Grimi
# C. Chávez
# M. Pérez García
# G. Marinelli
# S. Prediger
# C. Erbes
# D. Morales
# A. Sánchez
# C. Díaz
# F. Elizari
# L. Albertengo
# D. Miloc
# M. Orihuela
# B. Romero
# H. Galíndez
# A. Blanco
# M. Borgnino
# F. Feuillassier
# M. Gómez
# M. Payero
# M. Esquivel
# T. Andrade
# F. Cambeses
# D. Sosa
# J. Méndez
# F. Altamirano
# G. Gómez
# A. Frías
# F. Calderón
# D. Rodríguez
# J. López Pissano
# M. Curado
# E. Rolón
# I. Colman
# N. Estévez
# M. Pardo
# G. Iñiguez
# M. Ortíz
# L. Ojeda
# B. Vides
# L. Melano
# D. Mendoza
# C. Vega
# C. Luna
# R. Salinas
# I. Quílez
# A. Arregui
# J. Amoroso
# M. Cano
# D. Carando
# F. Pereyra
# M. Álvarez
# M. Palacios
# M. Weigandt
# L. Morales
# N. Delgadillo
# J. Kurtić
# M. Zajc
# V. Birsa
# N. Skubic
# P. Stojanović
# V. Belec
# J. Bijol
# L. Štulac
# D. Bohar
# J. Balkovec
# A. Struna
# S. Živec
# R. Rep
# J. Gorenc Stanković
# E. Janža
# Z. Dedič
# H. Vučkić
# Z. Majer
# D. Petrovič
# A. Delamea
# N. Omladič
# Z. Rogelj
# B. Kramer
# L. Šušnjara
# D. Maroh
# A. Vetrih
# L. Štor
# A. Ivačič
# M. Kocić
# D. Tijanić
# M. Tučić
# R. Sirk
# M. Poplatnik
# D. Vokić
# G. Dobrovoljc
# E. Kryeziu
# A. Casar
# D. Gril
# -------------------------Poland-------------------------
# R. Lewandowski
# W. Szczęsny
# A. Milik
# L. Fabiański
# P. Zieliński
# L. Piszczek
# G. Krychowiak
# K. Piątek
# J. Bednarek
# R. Gikiewicz
# T. Kędziora
# L. Skorupski
# B. Drągowski
# P. Kieszek
# A. Mierzejewski
# J. Błaszczykowski
# K. Glik
# K. Linetty
# K. Grosicki
# M. Rybus
# D. Kądzior
# A. Boruc
# K. Wilczek
# M. Klich
# B. Białkowski
# A. Jędrzejczyk
# J. Gol
# B. Bereszyński
# L. Teodorczyk
# J. Czerwiński
# K. Jóźwiak
# D. Kownacki
# K. Świderski
# M. Stępiński
# P. Frankowski
# M. Pazdan
# T. Romanczuk
# K. Bielik
# R. Gumny
# S. Żurkowski
# F. Kurto
# M. Kamiński
# K. Przybyłko
# A. Bodzek
# B. Pawłowski
# P. Wszołek
# F. Starzyński
# R. Kurzawa
# J. Moder
# P. Płacheta
# B. Kapustka
# M. Helik
# J. Niezgoda
# R. Murawski
# M. Nalepa
# A. Reca
# J. Świerczok
# A. Czerwiński
# B. Augustyn
# M. Sadlok
# B. Salamon
# B. Rymaniak
# D. Blacha
# K. Drygas
# D. Furman
# M. Karbownik
# S. Walukiewicz
# R. Majecki
# P. Dziczek
# S. Kowalczyk
# P. Dawidowicz
# A. Buksa
# D. Szymański
# M. Kobylański
# F. Bednarek
# D. Dąbrowski
# P. Parzyszek
# L. Zwoliński
# K. Mączyński
# P. Tytoń
# I. Lewczuk
# A. Sobiech
# M. Wilusz
# W. Sobota
# P. Olkowski
# D. Łukasik
# M. Konczkowski
# T. Puchacz
# K. Fila
# K. Pestka
# M. Wieteska
# P. Bochniewicz
# M. Wdowiak
# J. Kubicki
# S. Mrowca
# J. Słowik
# B. Kopacz
# K. Kamiński
# B. Nowak
# L. Trałka
# R. Boguski
# L. Burliga
# M. Makuszewski
# M. Kucharczyk
# M. Mak
# B. Białek
# T. Makowski
# M. Listkowski
# P. Stolarski
# D. Rasak
# H. Matynia
# J. Piotrowski
# D. Hładun
# D. Niepsuj
# J. Jach
# J. Szumski
# A. Uryga
# W. Golla
# R. Wolski
# J. Żubrowski
# P. Celeban
# T. Jodłowiec
# R. Pietrzak
# J. Bartkowski
# M. Mak
# M. Matras
# A. Frączczak
# J. Wójcicki
# M. Cholewiak
# K. Piątkowski
# B. Slisz
# P. Wiśniewski
# P. Klimala
# D. Michalski
# K. Michalak
# S. Milewski
# P. Sokołowski
# L. Klemenz
# K. Forenc
# A. Lis
# M. Szwoch
# J. Rzeźniczak
# R. Cierzniak
# M. Gliwa
# A. Borysiuk
# M. Buchalik
# M. Piossek
# M. Żyro
# D. Zbozień
# M. Gajos
# J. Kamiński
# M. Bułka
# M. Szczepański
# F. Jagiełło
# M. Lis
# D. Oko
# I. Sapała
# F. Piasecki
# M. Cebula
# D. Węglarz
# P. Lipski
# L. Wolsztyński
# R. Janicki
# M. Kopczyński
# J. Szmatuła
# T. Nowak
# K. Getinger
# P. Tomasik
# L. Sierpina
# K. Danielak
# R. Figiel
# F. Marchwiński
# B. Bida
# A. Stanilewicz
# T. Klupś
# S. Lusiusz
# J. Łabojko
# L. Poręba
# D. Szymonowicz
# G. Tomasiewicz
# R. Janicki
# M. Malec
# I. Łasicki
# S. Musiolik
# M. Szromnik
# P. Kun
# K. Osyra
# M. Urbańczyk
# S. Sobczak
# M. Kupczak
# K. Kościelny
# M. Pawelec
# G. Sandomierski
# P. Malarczyk
# P. Tuszyński
# M. Jakóbowski
# A. Dej
# P. Schikowski
# M. Żyro
# P. Szysz
# G. Jaroch
# M. Spychała
# D. Kopacz
# A. Gryszkiewicz
# J. Bursztyn
# J. Wrąbel
# P. Mystkowski
# R. Makowski
# B. Jaroch
# J. Grzesik
# D. Kudła
# M. Koj
# J. Kiełb
# P. Malinowski
# K. Biliński
# M. Bodzioch
# A. Niewulis
# A. Rakowski
# M. Szczepaniak
# D. Abramowicz
# M. Rybicki
# M. Domański
# B. Kieliba
# D. Kocyła
# M. Skóraś
# R. Kobryń
# S. Stasik
# M. Pałaszewski
# H. Adamczyk
# P. Tomczyk
# M. Hołownia
# M. Ambrosiewicz
# W. Szumilas
# J. Arak
# F. Piszczek
# M. Flis
# F. Modelski
# T. Mokwa
# M. Kuzimski
# M. Bogusz
# A. Buksa
# M. Rosołek
# A. Łyszczarz
# W. Hajda
# K. Niemczycki
# M. Sopoćko
# A. Ławniczak
# B. Żynel
# K. Michalski
# J. Bednarczyk
# M. Czyżycki
# P. Janasik
# M. Stryjek
# A. Ryczkowski
# M. Rzuchowski
# M. Marzec
# W. Lisowski
# D. Hoyo-Kowalski
# J. Iskra
# D. Ściślak
# P. Bargiel
# D. Pawłowski
# P. Olszewski
# D. Bielica
# D. Mikołajewski
# P. Pyrdoł
# D. Steczyk
# K. Handzlik
# A. Małachowski
# K. Gach
# T. Dejewski
# P. Krawczyk
# K. Szymański
# D. Szelągowski
# M. Żurawski
# A. Pyrka
# A. Benedyczak
# M. Zylla
# P. Żuk
# M. Sitek
# K. Kubica
# D. Jończy
# D. Pawłowski
# D. Pakulski
# J. Kuzdra
# A. Komor
# D. Primel
# R. Leszczyński
# J. Wróbel
# A. Laskowski
# B. Sielewski
# M. Rakoczy
# D. Szot
# M. Żukowski
# A. Paluszek
# B. Wdowik
# O. Nowak
# H. Gostomski
# R. Dadok
# P. Samiec-Talar
# M. Praszelik
# F. Szymczak
# J. Kałuziński
# B. Mruk
# L. Zjawiński
# L. Openda
# W. Faes
# A. Leya Iseka
# D. Cools
# I. Mbenza
# B. Bolingoli
# P. Gerkens
# O. Deschacht
# Igor de Camargo
# N. Schouterden
# N. De Pauw
# S. Peeters
# F. Amuzu
# T. De Smet
# M. Busi
# J. Bataille
# D. Wouters
# J. Vanlerberghe
# G. Hendrickx
# Z. Bakkali
# J. Kayembe
# K. Hazard
# C. Coosemans
# A. Corryn
# M. Vanhamel
# L. Ciman
# K. Steppe
# T. Derijck
# R. Boffin
# B. Capon
# P. Ngawa
# M. Vandevoordt
# N. Raskin
# S. Dewaele
# R. D'Haese
# B. Van Durmen
# Alex Craninx
# T. Vlietinck
# H. Cuypers
# O. De Wolf
# B. Guillaume
# G. Dewaele
# J. Van Cleemput
# A. Ciranni
# J. Van den Bergh
# Y. Thoelen
# R. Sanusi
# J. Dom
# G. Hairemans
# J. Cools
# M. Svilar
# E. Pletinckx
# G. Coucke
# D. Foulon
# L. Verstraete
# S. Miangue
# N. Jackers
# B. Badibanga
# J. Schryvers
# G. Hubert
# S. Coopman
# M. Maertens
# M. Tirpan
# L. Henkinet
# L. De Bock
# B. Godeau
# J. Gillet
# B. Castro
# C. Lepoint
# S. De Ridder
# F. Ojo
# D. Tshimanga
# L. Brogno
# S. Limbombe
# A. Vranckx
# K. Sardella
# A. Colassin
# D. Rigo
# A. Koita
# N. De Medina
# D. Lavalée
# L. Bostyn
# T. Lumanza Lembi
# J. Brondeel
# L. Pirard
# M. Heylen
# A. De Bruyn
# N. Dussenne
# T. Pietermaat
# T. Van Hyfte
# F. Frans
# D. Hubert
# D. Wuytens
# G. Grisez
# M. Jonckheere
# J. Heris
# K. Schuermans
# A. Maes
# M. Kana
# D. Mbayo
# L. Ndenbe
# R. Bushiri
# J. Ngoy
# T. Somers
# D. Peeters
# S. Mmaee
# A. Touba
# A. Benchaib
# D. Van den Buijs
# D. Seys
# M. Caufriez
# W. Janssens
# T. Defourny
# O. Myny
# M. De Cuyper
# A. Albanese
# C. Ngonge
# J. Mertens
# H. Delcroix
# I. Boonen
# E. Kabangu
# M. Verreth
# S. Bourard
# F. Vanzo
# L. Ramazani
# O. Boussaid
# S. Voet
# C. Dekuyper
# J. Vancamp
# D. Heymans
# B. Gabriël
# C. Vanhoutte
# L. Daneels
# R. Decostere
# N. Gillekens
# A. Yasar
# L. Schoofs
# F. Marquet
# M. Goblet
# E. Sağlık
# L. Oyen
# I. Van der Brempt
# R. Quirynen
# N. Shinton
# T. Lutonda
# N. Fadiga
# D. Jubitana
# M. Weymans
# A. Mboko
# M. Van Damme
# I. Takidine
# S. Sidibe
# H. Massoudi
# B. De Keersmaecker
# B. Dione
# A. Ait El Hadj
# A. Essabri
# T. Van Den Keybus
# B. Limbombe
# N. Pejčić
# M. De Smet
# S. Adewoye
# N. Nöstlinger
# A. Lejoly
# M. Delanghe
# A. Onana
# K. Nkuba
# T. Raemaekers
# M. Balikwisha
# M. Thiel
# S. Bouzian
# B. Schoonbaert
# J. Donkor
# K. Masangu
# S. Augustijns
# M. Ntelo
# B. Nsimba
# V. Van De Wiel
# O. Deman
# J. Carcela-González
# T. Reyners
# A. Theate
# A. Tanghe
# A. Carlone
# S. Lammens
# S. Asoma
# J. Van Hecke
# E. Sierra
# D. Lausberg
# L. Coveliers
# R. Vercauteren
# S. Lathouwers
# N. S'rifi
# A. Descotte
# M. Parmentier
# T. Leysen
# S. Van Dessel
# N. Dailly
# M. Deman
# B. Van Den Eynden
# J. Schelfhout
# L. Ritière
# D. Dassy
# B. Verkerken
# L. Maus
# -------------------------France-------------------------
# K. Mbappé
# K. Benzema
# N. Kanté
# A. Laporte
# H. Lloris
# A. Griezmann
# R. Varane
# P. Pogba
# C. Lenglet
# A. Martial
# K. Coman
# L. Digne
# W. Ben Yedder
# O. Dembélé
# F. Mendy
# S. Umtiti
# N. Fekir
# S. Mandanda
# B. Matuidi
# A. Lacazette
# L. Hernández
# A. Areola
# M. Maignan
# D. Payet
# F. Thauvin
# H. Aouar
# M. Diaby
# M. Dembélé
# T. Lemar
# P. Kimpembe
# B. Pavard
# B. Mendy
# S. Haller
# A. Rabiot
# A. Gignac
# F. Ribéry
# S. Ruffier
# N. Mukiele
# T. Ndombele
# A. Saint-Maximin
# M. Thuram
# C. Nkunku
# T. Hernández
# K. Zouma
# C. Tolisso
# V. Rongier
# B. Lecomte
# J. Roussillon
# A. Plea
# B. Gomis
# F. Coquelin
# B. André
# W. Boly
# D. Upamecano
# B. Kamara
# J. Ikoné
# D. Zagadou
# J. Koundé
# M. Sanson
# L. Dubois
# B. Santamaria
# J. Veretout
# T. Bakayoko
# B. Costil
# L. Koscielny
# K. Gameiro
# M. Valbuena
# O. Giroud
# M. Sissoko
# Y. M'Vila
# S. Nzonzi
# K. Lala
# I. Konaté
# P. Bernardoni
# A. Lafont
# J. Bamba
# S. Gigot
# A. Diallo
# A. Doucouré
# B. Bourigeaud
# J. Amavi
# R. Aguilar
# P. Lees-Melou
# M. Debuchy
# E. Capoue
# J. Guilavogui
# K. Malcuit
# N. Pallois
# D. Sidibé
# T. Savanier
# F. Mollet
# M. Guendouzi
# I. Diop
# G. Larsonneur
# N. Maupay
# F. Maouassa
# A. Thomasson
# A. Djiku
# H. Kamara
# W. Cyprien
# F. Lejeune
# R. Gurtner
# D. Da Silva
# R. Alessandrini
# X. Chavalerin
# B. Stambouli
# L. Kurzawa
# J. Schmid
# B. Sarr
# E. Camavinga
# B. Soumaré
# L. Blas
# J. Mateta
# M. Terrier
# F. Guilbert
# L. Tousart
# J. Gnagnon
# S. Meïté
# G. Laborde
# I. Amadou
# L. Ajorque
# A. Soumaoro
# M. Schneiderlin
# L. Rémy
# M. Sakho
# R. Thomas
# D. Le Tallec
# R. Hamouma
# M. Gonalons
# Y. Court
# G. Defrel
# F. Tait
# M. Caqueret
# J. Todibo
# J. Reine-Adélaïde
# O. Edouard
# Y. Karamoh
# R. Le Normand
# A. Claude-Maurice
# A. Disasi
# M. Coco
# F. Centonze
# V. Rosier
# C. Dagba
# E. Crivelli
# M. Niakhaté
# K. Amian
# R. Oudin
# M. Sarr
# C. Jullien
# A. Touré
# G. Nkoudou
# M. Lopez
# A. Hunou
# C. Hérelle
# J. Briand
# T. Mangani
# A. Modeste
# A. Rami
# S. Corchia
# A. Souquet
# F. Hanin
# N. Mendy
# N. De Préville
# D. Foulquier
# B. Reynet
# P. Capelle
# D. Liénard
# W. Saliba
# B. Mbeumo
# E. Ndicka
# I. Louza
# A. Caci
# E. Owusu
# A. Fulgini
# S. Alakouch
# M. Cafaro
# S. Guirassy
# A. Touré
# L. Mousset
# A. Briançon
# T. Kolodziejczak
# E. Mangala
# G. Hoarau
# D. Congré
# S. De Maio
# J. Faussurier
# K. Théophile-Catherine
# M. Barthelmé
# V. Le Goff
# V. Germain
# A. Knockaert
# B. Kamara
# S. Nsoki
# O. Ntcham
# M. Chouiar
# B. Dia
# J. Augustin
# R. Perraud
# F. Ballo-Touré
# Y. Fofana
# P. Nardi
# J. Léa Siliki
# N. Gavory
# T. Didillon
# A. Blin
# R. Del Castillo
# P. Burner
# A. Tameze
# E. Gnahoré
# N. Penneteau
# L. Butelle
# J. Leca
# L. Deaux
# J. Pied
# C. Grenier
# V. Manceau
# P. Lasne
# G. Charbonnier
# J. Martin
# M. Colin
# V. Eysseric
# T. Delaine
# A. Trebel
# J. Ferri
# T. Dingomé
# M. Poundjé
# V. Laurini
# J. Bela
# P. Martinez
# Y. Valery
# A. Nordin
# C. Michelin
# I. Diallo
# J. Prior
# K. N'Doram
# E. Kwateng
# J. Gélin
# S. Grandsir
# M. Diakhaby
# D. Bain
# W. Saïd
# F. Tardieu
# L. Diony
# Y. Niakaté
# A. Bamba
# Y. Pelé
# R. Salin
# J. Babin
# K. Monnet-Paquet
# F. Lemoine
# B. Leroy
# M. Autret
# R. Amalfitano
# V. Pajot
# D. Appiah
# L. Carole
# N. Benezet
# T. Monconduit
# B. Pelé
# J. Beauguel
# F. Sotoca
# J. Clauss
# R. Aït Nouri
# T. Kouassi
# Z. Youssouf
# M. Cuisance
# M. Simakan
# K. Thuram
# R. Nteka
# A. Bernede
# I. Cardona
# R. Pierre-Gabriel
# A. Tchouaméni
# B. Badiashile
# V. Koziello
# A. Bobichon
# J. Butez
# O. Boscagli
# C. Jean
# J. Gradit
# J. Dompé
# P. Hamel
# L. Landre
# M. Dupé
# P. Gouano
# S. Moreira
# V. Sasso
# B. Omrani
# R. Ripart
# Y. Cahuzac
# L. Baal
# M. Coutadeur
# P. Baysse
# A. Weber
# B. Poulain
# G. Belaud
# A. Losilla
# H. Gnohéré
# Q. Bernard
# S. Doukara
# R. Philippoteaux
# P. Gueye
# A. Gouiri
# Y. Adli
# W. Fofana
# F. Ayé
# J. Deminguet
# E. Lombardo
# J. Makengo
# F. Miguel
# M. Diaby
# M. Malsa
# A. Diakhaby
# I. Sissoko
# Y. Bodiger
# U. Bozok
# G. Gallon
# A. Kamara
# J. Lefort
# Y. Salmier
# P. Polomat
# J. Giraudon
# M. Michel
# L. Abergel
# A. Mendy
# Y. Barbet
# L. Dos Santos
# T. Mauricio
# R. Fanni
# R. Riou
# J. Moulin
# A. Bonnet
# T. Chevalier
# N. Roux
# R. Rodelin
# Y. Ravet
# M. Le Marchand
# R. Grange
# N. Isimat-Mirin
# M. Gorgelin
# G. Bussmann
# M. Le Bihan
# G. Courtet
# X. Mercier
# S. Willems
# R. Dugimont
# K. Fortuné
# J. Chotard
# I. Meslier
# M. Sagnan
# I. Sissoko
# M. Maolida
# J. Bellegarde
# M. Aké
# O. Kemen
# A. Sissako
# G. Kalulu
# G. Nyamsi
# M. Udol
# F. Honorat
# D. Cavaré
# J. Siebatcheu
# J. Laporte
# F. Bambock
# M. Caillard
# J. Pi
# V. Jacob
# M. Gakpa
# T. Henry
# J. Mellot
# T. Peyre
# G. Paquiez
# M. Peybernès
# G. Robail
# J. Sorbon
# G. Obertan
# F. Bellugou
# S. Souprayen
# A. Gonçalves
# M. Deplagne
# J. Gastien
# J. Marié
# M. Perez
# K. Vandendriessche
# J. Berthomier
# D. Keita-Ruel
# C. Mandouki
# T. Jaques
# N. Cozza
# B. Diakité
# G. Biancone
# J. Masson
# C. Rocchia
# A. Pelmard
# L. Fomba
# M. Prévot
# A. Sissoko
# T. Ambrose
# Q. Boisgard
# M. Tramoni
# K. Sidibé
# M. Huard
# J. Sambia
# K. Boto
# Z. Machach
# A. Kalulu
# J. Benet
# D. Douline
# G. Fofana
# A. Coeff
# Y. Cardinale
# B. Allain
# A. Desmas
# E. Vandenabeele
# J. Delle
# Q. Cornette
# R. Bayard
# U. Bonnet
# V. Demarconnay
# P. Gibaud
# C. Avinel
# D. Marcq
# J. Fontaine
# F. Sammaritano
# K. Yoda
# P. Valdivia
# R. Nouri
# M. Saunier
# B. Jeannot
# J. Delaplace
# J. Cuffaut
# F. Ogier
# M. Barreto
# Y. Croizet
# P. Paye
# J. Cordoval
# J. Hergault
# M. Alphonse
# K. Hoggas
# S. Karamoko
# R. Cherki
# M. Bard
# E. Le Fée
# M. Olise
# E. Dina Ebimbe
# G. Poussin
# A. Aouchiche
# H. Mendes
# M. Poaty
# J. Livolant
# Y. Armougom
# L. Perrin
# D. Poha
# Y. Gboho
# J. Duverne
# J. Dacosta
# A. Gory
# G. Hein
# D. Batubinsika
# A. Olliero
# R. Descamps
# J. Fabri
# A. Zedadka
# G. Lloris
# Q. Lecoeuche
# Y. Rahmani
# Y. Merdji
# S. Camara
# B. Valette
# A. Ngando
# M. Cabit
# J. Perbet
# S. Marveaux
# A. Scaramozzino
# R. Armand
# M. Dreyer
# E. Rivière
# B. Maubleu
# B. Ketkeophomphone
# Z. Diallo
# F. Brillant
# K. Rocheteau
# A. Monfray
# F. N'Goma
# F. Ourega
# H. Massengo
# P. Kalulu
# M. Lacroix
# B. Soppy
# O. Solet
# C. Abi
# K. Koné
# J. Ruiz
# L. Pintor
# S. Diop
# M. Sylla
# G. Koyalipou
# T. Cognat
# S. Niakaté
# M. Gonçalves
# L. Mbe Soh
# J. Pendant
# J. Serrano
# P. Cornud
# W. Kanga
# J. Leborgne
# S. Banza
# Q. Daubin
# Y. Magnin
# Y. Ben Balla
# P. Mendy
# B. Chardonnet
# M. D'Arpino
# D. Louiserre
# A. Maraval
# D. Léon
# F. David
# D. Milinković
# W. Semedo
# J. Taravel
# L. Nestor
# A. Collin
# F. Duplus
# W. Rémy
# R. Pillot
# M. Pereira
# J. Rivierez
# J. Faucher
# D. Mohamed
# R. Camacho
# A. Ndiaye
# K. Azamoum
# D. Diring
# C. Psyché
# F. Valot
# G. Bosca
# D. Boudaud
# N. Mbuku
# E. Loiodice
# I. Chouaref
# A. Kalimuendo
# Y. Letard
# C. Gomes
# S. Boey
# D. Bertaud
# A. Zagré
# R. Guitane
# S. Sadzoute
# A. Laurienté
# M. Camara
# W. Tchimbembé
# Y. Hamache
# H. Marcelin
# A. Ndom
# J. Gaspar
# I. Faraj
# L. Rajot
# T. Baya
# S. Mbakata
# N. Dieng
# Y. Roche
# A. Scheidler
# E. Bocat
# A. Maisonnial
# G. Weissbeck
# S. Cibois
# B. Soumaré
# M. Kikonda
# A. Gonçalves Pereira
# Y. Maçon
# A. Belmonte
# A. Batisse
# R. Basque
# T. Campanini
# G. Kyei
# C. Depres
# J. Vachoux
# A. Leautey
# P. Bourdin
# H. Keyta
# L. Rougeaux
# J. Beaulieu
# J. Eickmayer
# D. Dussaut
# D. Bansais
# W. Jobello
# V. Henry
# P. Bardy
# A. Raineau
# S. Pontdemé
# M. Baudry
# M. Martin
# M. Chergui
# P. Delecroix
# E. Dudouit
# E. Ba
# G. Dequaire
# L. Doucouré
# I. Ba
# D. Gomis
# M. Tchokounté
# P. Ruffaut
# A. Tertereau
# J. Chougrani
# D. Thiam
# J. Antiste
# H. Hassan
# T. Basila
# S. Sissoko
# L. Da Cunha
# A. Adli
# A. Taoui
# M. El Idrissy
# K. Cabral
# M. Sitti
# A. Georgen
# A. Ba
# S. Benchama
# M. Léris
# G. Traoré
# Y. Kitala
# E. Sylvestre
# L. Brassier
# R. Kolo Muani
# S. Ambri
# E. Massouema
# Y. Fekir
# R. Faivre
# F. Chabrolle
# I. Marega
# D. Furtado
# A. Phliponeau
# L. Bessilé
# Q. Braat
# G. Tormin
# L. Dias
# B. Passi
# D. Chambost
# N. Kocik
# M. Leverbe
# E. Zidane
# Y. Kaabouni
# N. Mbemba
# M. Chahiri
# L. Bury
# K. Tapoko
# L. Kouagba
# J. Delem
# R. Kerrouche
# M. Kamissoko
# R. Boissier
# J. Correa
# J. Phojo
# M. Derrien
# S. Rénot
# Y. Thuram
# F. Berenguer
# S. Kehli
# F. Martin
# G. Heinry
# M. Biamou
# R. Aabid
# D. Bertrand
# A. Soubervie
# F. Michel
# S. Mara
# T. Pembélé
# L. Agoume
# A. Dabo
# B. Benkhedim
# K. Koindredi
# J. Kadile
# Y. Diouf
# L. Leroy
# M. Bahlouli
# E. Youan
# M. Diarra
# M. Karamoko
# E. Guessand
# W. Geubbels
# J. Ponceau
# A. Trouillet
# C. Vidal
# W. Coulibaly
# A. Rouault
# I. Lihadji
# L. Diabyfadiga
# G. Rutter
# V. Postolachi
# E. Ebosse
# D. Osei Yaw
# N. Alioui
# H. Vandermersch
# B. Boutobba
# M. Merghem
# S. Elisor
# G. Mutombo
# Y. Bourhane
# J. Tell
# M. Bayo
# J. Krasso
# S. Coulibaly
# D. Dianessy
# Q. Bena
# Y. Maziz
# L. Mpasi
# T. Guivarch
# B. Konaté
# A. Nouri
# M. Mandron
# T. Vialla
# G. Laura
# B. Bertrand
# F. Fumu Tamuzo
# M. Latour
# J. Romil
# B. Nouvier
# A. Gomis
# M. Sourzac
# L. Poujol
# M. Guezoui
# K. Rimane
# T. Dieng
# G. Puel
# Y. Mamilonne
# N. Fofana
# S. Beusnard
# S. Bajic
# A. Traoré
# B. Fadiga
# A. Moueffek
# N. Djouahra
# H. Mbock
# M. Doucouré
# L. Badé
# G. Innocent
# S. Kyei
# C. Boli
# Z. Ould Khaled
# A. Flips
# R. Droehnle
# S. Sanna
# I. Kebbal
# T. Ndicka Matam
# D. N'Landu
# T. Lebeau
# W. Bianda
# M. Zerkane
# M. Diallo
# A. Dzabana
# L. Callegari
# A. Guendouz
# V. Lobry
# G. Lefebvre
# S. Flochon
# G. Amiot
# N. Ouammou
# T. Diagouraga
# R. Vincelot
# G. Gigliotti
# A. El Hriti
# L. Chevalier
# A. Virginius
# A. Konaté
# R. Richard
# J. Rahou
# M. Rouai
# A. Nguiamba
# A. Toufiqui
# E. Taha
# Y. Ammour
# B. Abdallah
# H. Abdelli
# L. Carnot
# A. Truffert
# G. Arib
# M. Phaëton
# N. Diliberto
# A. Kamardin
# B. Lasme
# V. Gendrey
# A. Pembélé
# I. Aaneba
# S. Arab
# V. Triboulet
# S. Delos
# W. Omari
# A. Baroan
# S. Raux-Yao
# Y. Severin
# M. Dembélé
# B. Tutu
# R. Sila
# L. Buades
# B. Danger
# V. Pinson
# I. Cissé
# N. Diallo
# D. Trichard
# J. Albert
# X. Pinoteau
# N. Atangana
# A. Ba
# A. Traoré
# M. Tshibuabua
# M. Rivera
# S. Laiton
# A. Beka Beka
# L. Tramoni
# K. Mouanga
# B. Ndilu
# U. Bertelli
# R. Yapi
# A. Valerio
# S. Doucouré
# T. Boulhendi
# J. Hadjam
# D. Desprez
# B. Mendy
# R. Sans
# I. Cissé
# B. Badu
# A. Lebeau
# T. Vargas
# B. Dedola
# N. Ngoumou
# M. Ahlinvi
# M. Robin
# H. Magnetti
# A. Tsague
# J. Le Douaron
# K. Benvindo
# J. Boyer
# D. Tokpa
# L. Morante
# K. Bemanga
# M. Siby
# J. Papeau
# T. Njiké
# R. Pereira de Sa
# N. Bruneel
# R. Muhammed
# P. Marie
# A. Oudrhiri
# A. Souda
# Y. Begraoui
# N. Fatar
# L. Gourna-Douath
# Y. Cimignani
# K. Bafounta
# H. Ekitike
# I. Ouattara
# A. Oudjani
# K. Boma
# P. Méliande
# B. Moltenis
# B. Canelhas
# L. Bernadou
# O. Camara
# O. Camara
# T. Coulibaly
# I. Gomis
# T. Nkada
# W. Jarmouni
# B. Doukansy
# S. Sy
# S. Karamoko
# M. Fischer
# D. Traore
# W. Moustache
# F. Poulolo
# J. Corinus
# A. Peyrelade
# A. Ouhafsa
# M. Guilavogui
# R. Latouchent
# F. Sollacaro
# S. Deslandes
# M. Diaw
# E. Salles
# G. Touré
# L. Lacroix
# J. Ngouabi
# W. Taïbi
# T. Tamas
# N. Zohoré
# L. Ntumba
# R. Philippe
# I. Boura
# R. Vita
# Y. Fortune
# L. Vallier
# M. Adopo
# N. Ntolla Thio
# M. Dembélé
# B. Domingues
# O. Cetiner
# K. Le Roy
# M. Nanizayamo
# B. Mathis
# R. Ponti
# D. Fage
# M. Aljic
# J. Bumbu
# T. Secchi
# C. Zabou
# B. Touré
# J. Popelard
# N. Innocenti
# A. Gomez Mancini
# W. Bedfian
# Y. Benhattab
# Y. Fofana
# G. Haag
# G. Kyeremeh
# M. Doué
# R. Bouallak
# C. Bombo
# L. Margueron
# R. Souici
# Y. Barka
# M. Bassouamina
# A. Linguet
# A. Kerouedan
# M. Picouleau
# B. Roux
# A. Barry
# A. Long
# O. Djoco
# P. Malumandsoko
# G. Coelho
# E. Basilio
# S. Ilgaz
# J. Huysman
# K. Nsona
# R. Jay
# P. Koffi
# L. Sinayoko
# N. Simon
# P. Trindade
# H. Constant
# C. Jan
# K. Guessoum
# S. Chader
# L. Camelo
# I. Karamoko
# B. Doucouré
# V. Daguin
# T. Vannoye
# J. Moutachy
# C. Chaminade
# M. Scalet
# M. Guillaume
# W. Bondo
# D. Meddah
# S. Renel
# E. Samba
# F. Bloch
# D. Rouyard
# J. Khasa
# F. Mattoir
# I. Dioh
# M. Biron
# R. Ndiaye
# A. Boutoutaou
# O. Nkambadio
# D. Youfeigane
# H. Gambor
# T. Okou
# K. Chapelle
# T. Herr
# L. Hervieu
# P. Bourdelle
# C. Goteni
# A. Martial
# T. Bartouche
# I. Doukouré
# L. Marsella
# M. Mazzolini
# D. Salhi
# J. Evan's Allan
# J. Belehouan
# T. Callens
# -------------------------Germany-------------------------
# M. ter Stegen
# M. Neuer
# J. Kimmich
# T. Kroos
# M. Hummels
# T. Müller
# K. Havertz
# L. Sané
# T. Werner
# B. Leno
# S. Gnabry
# M. Reus
# N. Süle
# L. Goretzka
# J. Brandt
# I. Gündoğan
# K. Trapp
# E. Can
# M. Ginter
# M. Özil
# L. Bender
# J. Boateng
# O. Baumann
# K. Bellarabi
# M. Halstenberg
# R. Gosens
# A. Rüdiger
# S. Bender
# S. Khedira
# M. Kruse
# K. Volland
# L. Klostermann
# N. Schulz
# J. Draxler
# K. Demirbay
# L. Stindl
# F. Neuhaus
# J. Tah
# J. Weigl
# A. Schwolow
# M. Arnold
# P. Max
# S. Ulreich
# S. Serdar
# L. Karius
# S. Mustafi
# D. Demme
# D. da Costa
# P. Herrmann
# C. Kramer
# C. Günter
# F. Niederlechner
# N. Amiri
# T. Kehrer
# T. Horn
# L. Unnerstall
# L. Bittencourt
# R. Fährmann
# S. Rudy
# B. Hübner
# P. Groß
# K. Vogt
# S. Rode
# J. Hector
# J. Hofmann
# R. Koch
# L. Waldschmidt
# M. Eggestein
# F. Müller
# M. Mittelstädt
# N. Stark
# M. Dahoud
# B. Henrichs
# M. Meyer
# M. Wolf
# R. Knoche
# N. Füllkrug
# M. Weiser
# T. Leibold
# N. Petersen
# D. Ginczek
# M. Plattenhardt
# F. Klos
# M. Uth
# T. Strobl
# A. Nübel
# J. Torunarigha
# F. Uduokhai
# M. Müller
# R. Zentner
# S. Ortega
# R. Khedira
# Y. Gerhardt
# D. Heintz
# D. Kohr
# J. Haberer
# E. Thommy
# L. Podolski
# R. Hennings
# M. Marin
# D. Brosinski
# D. Diekmeier
# B. Oczipka
# T. Jantschke
# D. Didavi
# A. Younes
# A. Maier
# R. Hack
# M. Richter
# N. Dorsch
# M. Friedrich
# T. Baumgartl
# M. Kempf
# J. Gressel
# C. Gentner
# F. Bastians
# S. Terodde
# N. Müller
# R. Zieler
# M. Schmelzer
# D. Latza
# M. Gulde
# T. Arslan
# A. Luthe
# M. Esser
# F. Klaus
# E. Löwen
# K. Akpoguma
# D. Selke
# L. Öztunalı
# J. Toljan
# J. Geis
# J. Blaswich
# P. Bauer
# P. Mainka
# S. Gümüş
# P. Pentke
# A. Hunt
# G. Castro
# T. Sippel
# F. Bartels
# M. Schäffler
# M. Zimmermann
# S. Bell
# D. Drexler
# S. Kittel
# L. Rupp
# C. Schindler
# O. Hernández
# K. Müller
# O. Kragl
# T. Leistner
# E. Durm
# D. Blum
# A. Voglsammer
# M. Bülter
# L. Maina
# R. Baku
# A. Fein
# D. Geiger
# S. Özcan
# A. Pieper
# W. Anton
# L. Klünter
# T. Kleindienst
# M. Ducksch
# R. Andrich
# P. Stenzel
# A. Hack
# M. Hartel
# K. Wagner
# C. Mathenia
# L. Zingerle
# A. Hoffmann
# M. Leitner
# F. Hübner
# T. Trybull
# K. Möhwald
# J. Zimmer
# P. Tschauner
# N. Theuerkauf
# L. Holtby
# S. Burchert
# H. Badstuber
# M. Höger
# J. Hochscheidt
# M. Riemann
# M. Rzatkowski
# N. Höfler
# D. Kaiser
# S. Dursun
# L. Kübler
# A. Mühling
# R. Czichos
# A. Hahn
# S. Griesbeck
# O. Kiomourtzoglou
# K. Günter
# H. Mukhtar
# M. Stendera
# R. Framberger
# J. Gyamerah
# S. Schonlau
# P. Seguin
# T. Wellenreuther
# G. Jung
# M. Wittek
# J. Pollersbeck
# M. Busch
# M. Schuhen
# B. Schmitz
# M. Sobottka
# L. Höler
# C. Zimmermann
# J. Börner
# S. Skrzybski
# P. Kühn
# A. Walke
# M. Männel
# M. Risse
# F. Jungwirth
# J. Schieber
# M. Stiepermann
# S. Jung
# C. Clemens
# H. Behrens
# L. Sobiech
# F. Wiedwald
# O. Sorg
# C. Löwe
# P. Hofmann
# F. Holland
# D. Linsmayer
# N. Gießelmann
# M. Schnatterer
# R. Leipertz
# N. Katterbach
# F. Agu
# M. Schubert
# M. Mehlem
# M. Bader
# J. Horn
# M. Köhlert
# K. Broll
# D. Kinsombi
# T. Pachonik
# G. Prömel
# M. Heyer
# A. Karazor
# K. Schlotterbeck
# H. Weydandt
# F. Kastenmeier
# B. Uphoff
# P. Tau
# T. Hlatshwayo
# L. Singh
# L. Phiri
# I. Khune
# L. Mothiba
# B. Zungu
# T. Lorch
# K. Dolly
# L. Manyama
# V. Pule
# D. Zuma
# F. Makaringe
# W. Sandilands
# K. Mokotjo
# E. Mathoho
# D. Cardoso
# I. Maela
# R. Frosler
# B. Parker
# D. Keet
# R. Mphahlele
# S. Ndlovu
# B. Bvuma
# T. Tlolane
# H. Jele
# L. Memela
# P. Zulu
# B. Motshwari
# P. Mako
# D. Furman
# K. Moleko
# N. Nyauza
# S. Ntshangase
# X. Mlambo
# A. Mabaso
# A. Ndengane
# L. Foster
# S. Ngezana
# S. Ntiya-Ntiya
# T. Mabasa
# B. Sam
# Y. Sasman
# T. Phete
# S. Mpontshane
# K. Ntlhe
# J. Chabalala
# G. Shitolo
# M. Dube
# K. Jacobs
# L. Mntambo
# N. Ngcobo
# L. Le Roux
# H. Mashiane
# T. Matthews
# K. Ayer
# N. Blom
# E. Chislett
# M. Mayambela
# G. Links
# B. Petersen
# D. Visser
# K. Molefe
# -------------------------Iraq-------------------------
# A. Adnan
# O. Rashid
# J. Meram
# A. Yasin
# -------------------------Madagascar-------------------------
# J. Morel
# M. Ilaimaharitra
# R. Métanire
# J. Mombris
# T. Fontaine
# R. Raveloson
# F. Andriatsima
# L. Nomenjanahary
# C. Andriamahitsinoro
# -------------------------Moldova-------------------------
# A. Epureanu
# A. Ioniță
# A. Koselev
# O. Reabciuk
# V. Damașcan
# D. Graur
# I. Armaș
# V. Rață
# E. Cebotaru
# N. Milinceanu
# A. Boiciuc
# I. Brînză
# -------------------------Curacao-------------------------
# E. Room
# J. Bacuna
# K. Gorré
# L. Bacuna
# Q. Martinus
# J. Cijntje
# J. Arias
# J. Gaari
# A. van den Hurk
# B. Martis
# G. Kastaneer
# J. Ogenia
# L. Caciano
# -------------------------Cuba-------------------------
# O. Alonso
# C. Sánchez
# J. Corrales
# C. Vázquez
# M. Chang
# -------------------------Mozambique-------------------------
# Mexer
# Zainadine
# Reinildo
# Witi
# Simao Mate
# -------------------------Gambia-------------------------
# O. Colley
# M. Barrow
# B. Jatta
# M. Barrow
# B. Trawally
# Y. Njie
# S. Marreh
# A. Kanté
# Nuha
# Y. Jarju
# I. Touray
# A. Sanyang
# E. Adams
# M. Jarjué
# K. Ceesay
# E. Colley
# S. Sinyan
# O. Jaiteh
# A. Manneh
# S. Bojang
# M. Juwara
# A. Ceesay
# S. Janneh
# J. Gomez
# -------------------------Cyprus-------------------------
# K. Laifis
# A. Gogić
# J. Demetriou
# J. Roles
# H. Kyprianou
# R. Sotiriou
# H. Kyprianou
# -------------------------Estonia-------------------------
# R. Klavan
# K. Mets
# T. Teniste
# E. Sorga
# G. Tunjov
# -------------------------Benin-------------------------
# S. Sessègnon
# S. Allagbé
# S. Mounié
# F. Farnolle
# C. Soukou
# J. Dossou
# C. Hountondji
# Y. Aguemon
# S. D'Almeida
# J. Adéoti
# D. Djigla
# -------------------------Lithuania-------------------------
# G. Arlauskis
# F. Černych
# A. Novikovas
# L. Spalvis
# E. Girdvainis
# T. Krapikas
# M. Palionis
# B. Satkus
# S. Olberkis
# E. Dubickas
# -------------------------Saudi Arabia-------------------------
# S. Al Dawsari
# Y. Al Shahrani
# M. Al Buraik
# S. Al Faraj
# M. Kanno
# M. Al Owais
# S. Al Ghannam
# A. Ateef
# A. Al Mayoof
# F. Al Muwallad
# A. Aseri
# M. Hawsawi
# N. Al Abed
# Y. Al Shehri
# W. Bakhashwain
# S. Muwashar
# A. Al Bulayhi
# A. Al Sulayhim
# M. Al Kuwaykibi
# M. Al Fatil
# A. Al Obaid
# Y. Al Mosailem
# O. Hawsawi
# K. Al Ghamdi
# H. Bahebri
# H. Al Moqahwi
# M. Al Harbi
# S. Al Muwallad
# A. Al Khaibari
# M. Al Olayan
# S. Al Shehri
# A. Madu
# F. Al Qarni
# J. Bajandouh
# M. Malaeka
# A. Khamis
# M. Jahfali
# I. Al Zubaidi
# A. Al Jebreen
# M. Salem
# H. Kadish
# F. Al Sagour
# M. Ali
# A. Sharahili
# M. Qasem
# A. Al Malki
# Z. Al Sahafi
# T. Al Absi
# M. Khubrani
# A. Al Hafith
# A. Al Shamekh
# A. Al Zori
# A. Al Khaibari
# A. Kurdi
# A. Asiri
# T. Bu Haymid
# R. Sufyani
# M. Al Amri
# N. Al Mousa
# H. Al Hazaa
# S. Abdulhamid
# S. Farhan
# H. Al Shamrani
# S. Al Rubaie
# A. Adam
# A. Al Ghamdi
# Y. Barnawi
# A. Al Salem
# A. Al Jadani
# H. Al Mansour
# A. Al Bishi
# S. Al Jaman
# M. Al Sahlawi
# H. Sulaimani
# S. Al Qumayzi
# M. Asiri
# F. Darwish
# M. Abusabaan
# A. Al Zaqan
# A. Al Barakah
# B. Al Mutairi
# S. Al Khaibari
# A. Al Najjar
# A. Ghareeb
# A. Abdu
# R. Al Mousa
# A. Hazazi
# A. Al Fahad
# F. Bin Jamayah
# W. Abdullah
# S. Sharahili
# M. Al Fehaid
# S. Al Sawadi
# A. Al Mutairi
# M. Hamzi
# K. Al Kaabi
# A. Al Zain
# K. Al Barakah
# T. Al Ammar
# A. Al Hamdan
# A. Lajami
# O. Al Khalaf
# A. Al Suwat
# A. Al Shammary
# H. Al Qahtani
# M. Al Baqawi
# K. Al Khathlan
# A. Al Shammari
# R. Al Ghamdi
# A. Al Obud
# M. Al Saiari
# H. Al Jayzani
# N. Hazazi
# A. Al Mazaidi
# K. Sharahili
# A. Al Kassar
# Y. Hamza
# A. Khrees
# A. Al Sahabi
# W. Suwayyid
# N. Al Subhi
# S. Amro
# A. Al Nazera
# M. Al Furayj
# N. Mousa
# O. Muzayil
# A. Al Qahtani
# A. Al Nemer
# M. Bakhit
# I. Mahnashi
# Y. Al Bakr
# A. Hindi
# A. Al Amri
# M. Al Dawsari
# K. Al Samiri
# A. Hassoun
# S. Al Najai
# S. Al Nabit
# S. Mandash
# H. Al Habib
# A. Al Joui
# A. Al Habib
# A. Al Ammar
# S. Al Qeshtah
# F. Ghazi
# M. Al Qarni
# M. Hazazi
# H. Al Shuwaysh
# A. Al Yousef
# B. Al Nakhli
# A. Al Khaibari
# F. Al Aiyaf
# M. Al Najrani
# A. Al Nashi
# K. Barnawi
# J. Issa
# H. Camara
# A. Al Dawsari
# A. Al Khulaif
# A. Al Asmari
# N. Al Omran
# M. Al Mufarrij
# N. Al Dawsari
# A. Ba Masoud
# M. Fallatah
# S. Al Khayri
# S. Al Abbas
# A. Fallatah
# M. Kanabah
# H. Shaian
# M. Majrashi
# A. Majrashi
# B. Al Baqi
# A. Al Saleh
# M. Al Thmali
# H. Al Juhayyim
# A. Kanno
# H. Jafry
# A. Qaisi
# M. Abu Shararah
# A. Jafar
# M. Harzan
# A. Ashraf
# M. Al Rashidi
# H. Al Ghamdi
# H. Al Watyan
# S. Al Hamsal
# M. Al Majhad
# A. Al Ruhaili
# A. Al Aryani
# T. Abdullah
# M. Naji
# H. Belal
# A. Al Najai
# A. Al Riou
# M. Al Najai
# O. Hawsawi
# A. Maadi
# R. Al Radhi
# N. Al Muwallad
# J. Al Dossary
# H. Al Raheb
# J. Al Zoaed
# F. Fallatah
# B. Al Seliteen
# M. Al Bassas
# M. Al Rashdi
# O. Ashoor
# M. Madkhali
# H. Tombakti
# H. Al Geed
# S. Al Selouli
# M. Al Mutlaq
# J. Asiri
# A. Majrashi
# M. Al Rubaie
# M. Al Qahtani
# F. Al Tryes
# A. Al Yami
# M. Rayman
# A. Al Hassan
# M. Al Moqahwi
# O. Ilyas
# H. Al Ruwaili
# H. Raghfawi
# W. Al Anazi
# A. Al Khatib
# S. Faqihi
# A. Al Sultan
# F. Al Shammari
# M. Al Burayh
# M. Attiyah
# D. Al Saeed
# M. Al Sahli
# M. Al Hassawi
# I. Omar
# H. Al Eissa
# M. Al Shanqeeti
# A. Al Saluli
# A. Attiah
# A. Al Yousif
# A. Majrashi
# T. Al Ali
# Y. Al Harbi
# A. Al Hejaili
# H. Halawani
# M. Mohammed
# M. Jawhar
# M. Al Haidari
# M. Al Subaie
# M. Al Sharimi
# A. Al Samtai
# A. Al Shamrani
# R. Sharahili
# A. Al Salem
# S. Al Dosari
# S. Otayf
# M. Al Wakid
# A. Al Humayan
# K. Al Ghannam
# R. Al Otaibi
# T. Al Otaibi
# R. Solan
# Q. Lajami
# M. Al Saeed
# F. Al Rashidi
# H. Al Hajouj
# A. Al Jamaan
# M. Al Haeti
# M. Awaji
# O. Al Sunain
# N. Al Rashidi
# M. Awadh
# M. Zoulan
# N. Boushal
# F. Abdi
# A. Abdullah
# A. Al Qahtani
# M. Al Mahasna
# H. Salem
# N. Al Dajani
# M. Al Thani
# F. Al Hamad
# A. Al Bahri
# I. Albaraka
# B. Al Enezi
# H. Fallatah
# A. Al Shammari
# H. Al Shamrani
# H. Al Abdan
# N. Al Ghamdi
# A. Al Hassan
# H. Hawsawi
# N. Al Sharari
# M. Al Shudukhi
# H. Asiri
# M. Al Baqawi
# M. Al Abdulmunem
# A. Al Meqran
# Y. Sahfi
# M. Al Nakhli
# R. Al Najjar
# M. Al Burayh
# M. Sibyani
# M. Sanyor
# M. Habkoor
# M. Al Ghamdi
# R. Al Najjar
# B. Al Bahrani
# R. Al Marshoud
# I. Al Otaibi
# S. Al Saeed
# G. Al Enazi
# H. Al Quraish
# A. Al Enazi
# A. Al Dheyabi
# T. Al Shahrani
# -------------------------Liberia-------------------------
# O. Dorley
# S. Johnson
# S. Nimely
# M. Sangare
# -------------------------Bulgaria-------------------------
# K. Despodov
# B. Kraev
# K. Malinov
# D. Velkovski
# S. Popov
# A. Galabinov
# R. Dimitrov
# I. Goranov
# A. Ivanov
# M. Minchev
# Diego Ferraresso
# S. Velkov
# I. Gruev
# A. Chandarov
# G. Pashov
# T. Chunchukov
# P. Hristov
# D. Mitov
# V. Nikolov
# -------------------------Libya-------------------------
# A. Musrati
# I. Tajouri-Shradi
# A. Benali
# M. El-Munir
# -------------------------Philippines-------------------------
# N. Etheridge
# J. Strauß
# J. Tabinas
# -------------------------Sierra Leone-------------------------
# K. Kamara
# M. Bundu
# M. Turay
# A. Kamara
# A. Kargbo
# G. Davies
# U. Bangura
# A. Bakayoko
# O. Kakay
# -------------------------Uzbekistan-------------------------
# O. Akhmedov
# I. Alibaev
# R. Ashurmatov
# O. Urunov
# D. Tursunov
# J. Jaloliddinov
# J. Iskanderov
# -------------------------Saint Kitts and Nevis-------------------------
# R. Sawyers
# M. Nottingham
# -------------------------United Arab Emirates-------------------------
# Caio
# K. Eissa
# B. Al Ahbabi
# A. Barman
# Y. Nader
# I. Ahmed
# J. Maroof
# M. Abdulrahman
# M. Shaker
# R. Yaslam
# M. Salem
# S. Juma
# M. Jamal
# M. Fayez
# F. Hadid
# M. Bu Sanda
# M. Helal
# M. Ahmed
# S. Abdullah
# H. Al Mansoury
# K. Al Blooshi
# M. Abdullah
# -------------------------Comoros-------------------------
# F. Bachirou
# A. Ahamada
# F. Selemani
# Y. M'Changama
# N. Chamed
# C. Alhadhur
# S. Bakari
# Y. Zahary
# A. Ali Mohamed
# M. Youssouf
# A. Abdallah
# R. Saïd
# -------------------------Chad-------------------------
# C. Ninga
# -------------------------Namibia-------------------------
# R. Nyambe
# D. Hotto
# M. Starke
# -------------------------Thailand-------------------------
# C. Songkrasin
# T. Bunmathan
# T. Dangda
# K. Thamsatchanan
# -------------------------Bermuda-------------------------
# N. Wells
# -------------------------Luxembourg-------------------------
# M. Chanot
# C. Martins
# L. Jans
# Gerson Rodrigues
# L. Gerson
# L. Barreiro Martins
# M. Deville
# V. Thill
# T. Hall
# D. Carlson
# D. Sinani
# -------------------------Trinidad & Tobago-------------------------
# J. Jones
# K. Molino
# L. García
# S. Bateau
# A. Jones
# G. Ranjitsingh
# -------------------------Antigua & Barbuda-------------------------
# M. Romeo
# L. James-Wildin
# J. Parker
# D. Bowry
# -------------------------Burundi-------------------------
# S. Berahino
# C. Amissi
# P. Bizoza
# M. Amissi
# E. Kamsoba
# Y. Ndayishimiye
# P. Niyongabire
# -------------------------Kazakhstan-------------------------
# B. Islamkhan
# Y. Vorogovskiy
# B. Zaynutdinov
# A. Merkel
# K. Engel
# G. Zhukov
# -------------------------New Caledonia-------------------------
# W. Lautoa
# -------------------------Puerto Rico-------------------------
# Z. Valentin
# -------------------------Bolivia-------------------------
# A. Chumacero
# D. Bejarano
# M. Zoch
# E. Saavedra
# C. Lampe
# O. Ribera
# D. Mancilla
# R. Cordano
# J. Arce
# J. Orellana
# H. Rodríguez
# E. Zenteno
# A. Meleán
# R. Ballivián
# F. Saucedo
# C. Melgar
# J. Torrico
# V. Castellón
# S. Galindo
# J. Carrasco
# J. Fernández
# L. Vaca
# L. Haquín
# J. Rojas
# L. Pavia
# F. Rodríguez
# L. Justiniano
# J. Vaca
# H. Suárez
# L. Gutiérrez
# G. Álvarez
# S. Galindo
# J. Arrascaita
# O. Vaca
# C. Machado
# J. Aponte
# O. Añez
# J. Candia
# R. Cueto
# J. Flores
# P. Laredo
# R. Quiñonez
# A. Jusino
# E. Rodríguez
# R. Pedriel
# R. Ramallo
# E. Sánchez
# J. Ortiz
# R. Montero
# V. Melgar
# M. Quiroga
# E. Puña
# C. Menacho
# S. Gamarra
# J. Roca
# A. Veizaga
# W. Soleto
# L. Vargas
# S. Adrián
# P. Arano
# A. Rey
# K. Romay
# E. Arauz
# M. Suárez
# C. Arabe
# K. Salvatierra
# R. Fernández
# D. Sandy
# G. Olguín
# C. Algarañaz
# W. Álvarez
# L. Cárdenas
# G. Viscarra
# J. Cuellar
# N. Cabrera
# H. Gutiérrez
# J. Rioja
# D. Rojas
# Jaume Cuéllar
# M. Villarroel
# J. Montenegro
# R. Banegas
# E. Cano
# J. Isita
# A. Mercado
# D. Torrico
# J. Peñarrieta
# E. Pérez
# S. Navarro
# L. Urapuca
# P. Azogue
# W. Saucedo
# S. Reyes
# P. Galindo
# B. Uraezaña
# J. Muñóz
# H. Rojas
# J. Castillo
# J. Fierro
# J. García
# E. Vaca
# E. Pacheco
# R. Sánchez
# B. Calderon
# J. Sagredo
# W. Rojas
# A. Cabrera
# J. Pérez
# W. Rioja
# M. Garzón
# L. Justiniano
# D. Pérez
# P. Justiniano
# S. Claure
# R. Cuellar
# M. Cabral
# R. Canido
# C. Solíz
# C. Menacho
# J. Mamani
# R. Spenhay
# J. Herrera
# S. Pozo
# D. Navarro
# F. Roca
# H. Cardozo
# L. Vaca
# E. Montero
# M. Barbery
# P. Alcocer
# J. Martínez
# J. Ferrufino
# B. Rivas
# N. Orozco
# R. Orihuela
# V. Abrego
# J. Quinteros
# M. Flores
# F. Cárdenas
# -------------------------Eritrea-------------------------
# H. Goitom
# M. Saeid
# -------------------------Latvia-------------------------
# P. Šteinbors
# M. Ošs
# V. Gutkovskis
# R. Uldriķis
# K. Tobers
# D. Titov
# D. Ontužāns
# -------------------------Montserrat-------------------------
# L. Taylor
# B. Comley
# D. Daniels
# -------------------------São Tomé & Príncipe-------------------------
# Luís Leal
# -------------------------Malawi-------------------------
# G. Mhango
# -------------------------Mauritania-------------------------
# M. El Hacen
# A. Abeid
# H. Sy
# A. Ba
# H. Abou Demba
# A. Mahmoud
# S. Anne
# -------------------------El Salvador-------------------------
# D. Cerén
# D. Pineda
# A. Flores
# R. Domínguez
# -------------------------Haiti-------------------------
# C. Arcus
# F. Pierrot
# H. Bazile
# D. Etienne Jr.
# S. Mustivar
# B. Alceus
# D. Nazon
# S. Saba
# L. Pierre
# D. Ulysse
# -------------------------Uganda-------------------------
# F. Miya
# E. Bwomono
# M. Azira
# M. Opondo
# U. Ikpeazu
# H. Bockhorn
# R. Mukiibi
# B. Mugabi
# R. Kakeeto
# -------------------------Chinese Taipei-------------------------
# Zhou Dingyang
# Yaki Yen
# -------------------------Aruba-------------------------
# J. John
# -------------------------Faroe Islands-------------------------
# J. Edmundsson
# H. Hansson
# G. Rólantsson
# V. Davidsen
# B. Hendriksson Olsen
# -------------------------Guyana-------------------------
# T. Ondaan
# W. Creavalle
# C. Harriott
# R. Greenidge
# M. Briggs
# T. Vancooten
# S. Duke-McKenna
# L. Gordon
# E. Bonds
# K. McKenzie-Lyle
# -------------------------Azerbaijan-------------------------
# D. Nazarov
# Eddy Silvestre
# E. Nouri
# E. Kaplan
# B. Ekincier
# S. Tasdemir
# -------------------------Afghanistan-------------------------
# H. Amin
# O. Haydary
# -------------------------Sudan-------------------------
# M. Eisa
# A. Eisa
# M. Al Dhaw
# M. Adam
# -------------------------Guam-------------------------
# A. DeLaGarza
# -------------------------Belarus-------------------------
# V. Lisakovich
# I. Shkurin
# J. Shcherbakovski
# -------------------------Rwanda-------------------------
# D. Bizimana
# -------------------------Grenada-------------------------
# A. Pierre
# S. Baptiste
# O. Beckles
# O. Norburn
# -------------------------Palestine-------------------------
# I. Khalili
# A. Awad
# -------------------------Lebanon-------------------------
# J. Oumari
# F. Michel
# H. El-Helwe
# -------------------------Papua New Guinea-------------------------
# D. Browne
# -------------------------Jordan-------------------------
# J. Tamimi
# M. Afana
# -------------------------Saint Lucia-------------------------
# J. Donacien
# -------------------------Liechtenstein-------------------------
# S. Wieser
# B. Büchel
# M. Göppel
# J. Ospelt
# F. Saglam
# -------------------------Ethiopia-------------------------
# A. Askar
# Y. Abetew
# -------------------------Belize-------------------------
# T. Rocha
# M. Salazar
# -------------------------Niger-------------------------
# Y. Diori
# H. Adamou
# Y. Omar
# I. Salou
# -------------------------Malta-------------------------
# L. Gambin
# -------------------------Andorra-------------------------
# Marc Vales
# -------------------------Barbados-------------------------
# H. Hope
# -------------------------South Sudan-------------------------
# R. Tongyik
# A. Kuol
# -------------------------Macau-------------------------
# David Cardoso
# -------------------------Korea DPR-------------------------
# Ryang Yong Gi
# -------------------------Hong Kong-------------------------
# Dai Wai-Tsun
# Tan Chun Lok
# -------------------------Malaysia-------------------------
# L. Hakim
# -------------------------Indonesia-------------------------
# E. Maulana Vikri
# -------------------------Nicaragua-------------------------
# J. Moreno

# %%
print('Countrty Wise each player list\n\n')
for country in fifa_df.nationality.unique():
    print('-'*25+country+'-'*25)
    country_df=fifa_df[['name','nationality']][fifa_df.nationality==country]
    for players in country_df.name:
        print(players)
# Out:
# Countrty Wise each player list
#
#
# -------------------------Argentina-------------------------
# L. Messi
# Tomás Reymão
# Jota Gonçalves
# Paulo Estrela
# Manuel Semedo
# Joel Sousa
# André Ribeiro
# João Silva
# Telmo Arcanjo
# Miguel Bandarra
# Rui Encarnação
# Gonçalo Franco
# Fábio Fortes
# José Oliveira
# Rafael Bandeira
# Mésaque Djú
# Luís Mata
# Jorge Vieira
# Joël Monteiro
# Fabio Lopes
# Andre Mendes
# -------------------------Slovenia-------------------------
# J. Oblak
# S. Handanovič
# J. Iličić
# K. Kampl
# B. Verbič
# A. Šporar
# R. Berić
# J. Kurtić
# M. Zajc
# V. Birsa
# N. Skubic
# P. Stojanović
# V. Belec
# J. Bijol
# L. Štulac
# D. Bohar
# J. Balkovec
# A. Struna
# S. Živec
# R. Rep
# J. Gorenc Stanković
# E. Janža
# Z. Dedič
# H. Vučkić
# Z. Majer
# D. Petrovič
# A. Delamea
# N. Omladič
# Z. Rogelj
# B. Kramer
# L. Šušnjara
# D. Maroh
# A. Vetrih
# L. Štor
# A. Ivačič
# M. Kocić
# D. Tijanić
# M. Tučić
# R. Sirk
# M. Poplatnik
# D. Vokić
# G. Dobrovoljc
# E. Kryeziu
# A. Casar
# D. Gril
# -------------------------Poland-------------------------
# R. Lewandowski
# W. Szczęsny
# A. Milik
# L. Fabiański
# P. Zieliński
# L. Piszczek
# G. Krychowiak
# K. Piątek
# J. Bednarek
# R. Gikiewicz
# T. Kędziora
# L. Skorupski
# B. Drągowski
# P. Kieszek
# A. Mierzejewski
# J. Błaszczykowski
# K. Glik
# K. Linetty
# K. Grosicki
# M. Rybus
# D. Kądzior
# A. Boruc
# K. Wilczek
# M. Klich
# B. Białkowski
# A. Jędrzejczyk
# J. Gol
# B. Bereszyński
# L. Teodorczyk
# J. Czerwiński
# K. Jóźwiak
# D. Kownacki
# K. Świderski
# M. Stępiński
# P. Frankowski
# M. Pazdan
# T. Romanczuk
# K. Bielik
# R. Gumny
# S. Żurkowski
# F. Kurto
# M. Kamiński
# K. Przybyłko
# A. Bodzek
# B. Pawłowski
# P. Wszołek
# F. Starzyński
# R. Kurzawa
# J. Moder
# P. Płacheta
# B. Kapustka
# M. Helik
# J. Niezgoda
# R. Murawski
# M. Nalepa
# A. Reca
# J. Świerczok
# A. Czerwiński
# B. Augustyn
# M. Sadlok
# B. Salamon
# B. Rymaniak
# D. Blacha
# K. Drygas
# D. Furman
# M. Karbownik
# S. Walukiewicz
# R. Majecki
# P. Dziczek
# S. Kowalczyk
# P. Dawidowicz
# A. Buksa
# D. Szymański
# M. Kobylański
# F. Bednarek
# D. Dąbrowski
# P. Parzyszek
# L. Zwoliński
# K. Mączyński
# P. Tytoń
# I. Lewczuk
# A. Sobiech
# M. Wilusz
# W. Sobota
# P. Olkowski
# D. Łukasik
# M. Konczkowski
# T. Puchacz
# K. Fila
# K. Pestka
# M. Wieteska
# P. Bochniewicz
# M. Wdowiak
# J. Kubicki
# S. Mrowca
# J. Słowik
# B. Kopacz
# K. Kamiński
# B. Nowak
# L. Trałka
# R. Boguski
# L. Burliga
# M. Makuszewski
# M. Kucharczyk
# M. Mak
# B. Białek
# T. Makowski
# M. Listkowski
# P. Stolarski
# D. Rasak
# H. Matynia
# J. Piotrowski
# D. Hładun
# D. Niepsuj
# J. Jach
# J. Szumski
# A. Uryga
# W. Golla
# R. Wolski
# J. Żubrowski
# P. Celeban
# T. Jodłowiec
# R. Pietrzak
# J. Bartkowski
# M. Mak
# M. Matras
# A. Frączczak
# J. Wójcicki
# M. Cholewiak
# K. Piątkowski
# B. Slisz
# P. Wiśniewski
# P. Klimala
# D. Michalski
# K. Michalak
# S. Milewski
# P. Sokołowski
# L. Klemenz
# K. Forenc
# A. Lis
# M. Szwoch
# J. Rzeźniczak
# R. Cierzniak
# M. Gliwa
# A. Borysiuk
# M. Buchalik
# M. Piossek
# M. Żyro
# D. Zbozień
# M. Gajos
# J. Kamiński
# M. Bułka
# M. Szczepański
# F. Jagiełło
# M. Lis
# D. Oko
# I. Sapała
# F. Piasecki
# M. Cebula
# D. Węglarz
# P. Lipski
# L. Wolsztyński
# R. Janicki
# M. Kopczyński
# J. Szmatuła
# T. Nowak
# K. Getinger
# P. Tomasik
# L. Sierpina
# K. Danielak
# R. Figiel
# F. Marchwiński
# B. Bida
# A. Stanilewicz
# T. Klupś
# S. Lusiusz
# J. Łabojko
# L. Poręba
# D. Szymonowicz
# G. Tomasiewicz
# R. Janicki
# M. Malec
# I. Łasicki
# S. Musiolik
# M. Szromnik
# P. Kun
# K. Osyra
# M. Urbańczyk
# S. Sobczak
# M. Kupczak
# K. Kościelny
# M. Pawelec
# G. Sandomierski
# P. Malarczyk
# P. Tuszyński
# M. Jakóbowski
# A. Dej
# P. Schikowski
# M. Żyro
# P. Szysz
# G. Jaroch
# M. Spychała
# D. Kopacz
# A. Gryszkiewicz
# J. Bursztyn
# J. Wrąbel
# P. Mystkowski
# R. Makowski
# B. Jaroch
# J. Grzesik
# D. Kudła
# M. Koj
# J. Kiełb
# P. Malinowski
# K. Biliński
# M. Bodzioch
# A. Niewulis
# A. Rakowski
# M. Szczepaniak
# D. Abramowicz
# M. Rybicki
# M. Domański
# B. Kieliba
# D. Kocyła
# M. Skóraś
# R. Kobryń
# S. Stasik
# M. Pałaszewski
# H. Adamczyk
# P. Tomczyk
# M. Hołownia
# M. Ambrosiewicz
# W. Szumilas
# J. Arak
# F. Piszczek
# M. Flis
# F. Modelski
# T. Mokwa
# M. Kuzimski
# M. Bogusz
# A. Buksa
# M. Rosołek
# A. Łyszczarz
# W. Hajda
# K. Niemczycki
# M. Sopoćko
# A. Ławniczak
# B. Żynel
# K. Michalski
# J. Bednarczyk
# M. Czyżycki
# P. Janasik
# M. Stryjek
# A. Ryczkowski
# M. Rzuchowski
# M. Marzec
# W. Lisowski
# D. Hoyo-Kowalski
# J. Iskra
# D. Ściślak
# P. Bargiel
# D. Pawłowski
# P. Olszewski
# D. Bielica
# D. Mikołajewski
# P. Pyrdoł
# D. Steczyk
# K. Handzlik
# A. Małachowski
# K. Gach
# T. Dejewski
# P. Krawczyk
# K. Szymański
# D. Szelągowski
# L. Dimata
# A. De Sart
# A. Castro-Montes
# B. Verstraete
# J. De Sart
# D. Roef
# C. Dessers
# T. Kaminski
# H. Van Der Bruggen
# D. Arslanagic
# N. Storm
# S. Bossut
# C. Benteke
# K. D'Haene
# J. Doku
# E. Cobbaut
# A. Bodart
# B. Manuel
# C. De Norre
# O. Oularé
# A. D'Alberto
# R. Schoofs
# G. Gillet
# O. Kaya
# J. Vossen
# G. Bruno
# D. Odoi
# I. Mboyo
# J. Van Damme
# B. Dejaegere
# R. Emond
# C. De Ketelaere
# L. Openda
# W. Faes
# A. Leya Iseka
# D. Cools
# I. Mbenza
# B. Bolingoli
# P. Gerkens
# O. Deschacht
# Igor de Camargo
# N. Schouterden
# N. De Pauw
# S. Peeters
# F. Amuzu
# T. De Smet
# M. Busi
# J. Bataille
# D. Wouters
# J. Vanlerberghe
# G. Hendrickx
# Z. Bakkali
# J. Kayembe
# K. Hazard
# C. Coosemans
# A. Corryn
# M. Vanhamel
# L. Ciman
# K. Steppe
# T. Derijck
# R. Boffin
# B. Capon
# P. Ngawa
# M. Vandevoordt
# N. Raskin
# S. Dewaele
# R. D'Haese
# B. Van Durmen
# Alex Craninx
# T. Vlietinck
# H. Cuypers
# O. De Wolf
# B. Guillaume
# G. Dewaele
# J. Van Cleemput
# A. Ciranni
# J. Van den Bergh
# Y. Thoelen
# R. Sanusi
# J. Dom
# G. Hairemans
# J. Cools
# M. Svilar
# E. Pletinckx
# G. Coucke
# D. Foulon
# L. Verstraete
# S. Miangue
# N. Jackers
# B. Badibanga
# J. Schryvers
# G. Hubert
# S. Coopman
# M. Maertens
# M. Tirpan
# L. Henkinet
# L. De Bock
# B. Godeau
# J. Gillet
# B. Castro
# C. Lepoint
# S. De Ridder
# F. Ojo
# D. Tshimanga
# L. Brogno
# S. Limbombe
# A. Vranckx
# K. Sardella
# A. Colassin
# D. Rigo
# A. Koita
# N. De Medina
# D. Lavalée
# L. Bostyn
# T. Lumanza Lembi
# J. Brondeel
# L. Pirard
# M. Heylen
# A. De Bruyn
# N. Dussenne
# T. Pietermaat
# T. Van Hyfte
# F. Frans
# D. Hubert
# D. Wuytens
# G. Grisez
# M. Jonckheere
# J. Heris
# K. Schuermans
# A. Maes
# M. Kana
# D. Mbayo
# L. Ndenbe
# R. Bushiri
# J. Ngoy
# T. Somers
# D. Peeters
# S. Mmaee
# A. Touba
# A. Benchaib
# D. Van den Buijs
# D. Seys
# M. Caufriez
# W. Janssens
# T. Defourny
# O. Myny
# M. De Cuyper
# A. Albanese
# C. Ngonge
# J. Mertens
# H. Delcroix
# I. Boonen
# E. Kabangu
# M. Verreth
# S. Bourard
# F. Vanzo
# L. Ramazani
# O. Boussaid
# S. Voet
# C. Dekuyper
# J. Vancamp
# D. Heymans
# B. Gabriël
# C. Vanhoutte
# L. Daneels
# R. Decostere
# N. Gillekens
# A. Yasar
# L. Schoofs
# F. Marquet
# M. Goblet
# E. Sağlık
# L. Oyen
# I. Van der Brempt
# R. Quirynen
# N. Shinton
# T. Lutonda
# N. Fadiga
# D. Jubitana
# M. Weymans
# A. Mboko
# M. Van Damme
# I. Takidine
# S. Sidibe
# H. Massoudi
# B. De Keersmaecker
# B. Dione
# A. Ait El Hadj
# A. Essabri
# T. Van Den Keybus
# B. Limbombe
# N. Pejčić
# M. De Smet
# S. Adewoye
# N. Nöstlinger
# A. Lejoly
# M. Delanghe
# A. Onana
# K. Nkuba
# T. Raemaekers
# M. Balikwisha
# M. Thiel
# S. Bouzian
# B. Schoonbaert
# J. Donkor
# K. Masangu
# S. Augustijns
# M. Ntelo
# B. Nsimba
# V. Van De Wiel
# O. Deman
# J. Carcela-González
# T. Reyners
# A. Theate
# A. Tanghe
# A. Carlone
# S. Lammens
# S. Asoma
# J. Van Hecke
# E. Sierra
# D. Lausberg
# L. Coveliers
# R. Vercauteren
# S. Lathouwers
# N. S'rifi
# A. Descotte
# M. Parmentier
# T. Leysen
# S. Van Dessel
# N. Dailly
# M. Deman
# B. Van Den Eynden
# J. Schelfhout
# L. Ritière
# D. Dassy
# B. Verkerken
# L. Maus
# -------------------------France-------------------------
# K. Mbappé
# K. Benzema
# N. Kanté
# A. Laporte
# H. Lloris
# A. Griezmann
# R. Varane
# P. Pogba
# C. Lenglet
# A. Martial
# K. Coman
# L. Digne
# W. Ben Yedder
# O. Dembélé
# F. Mendy
# S. Umtiti
# N. Fekir
# S. Mandanda
# B. Matuidi
# A. Lacazette
# L. Hernández
# A. Areola
# M. Maignan
# D. Payet
# F. Thauvin
# H. Aouar
# M. Diaby
# M. Dembélé
# T. Lemar
# P. Kimpembe
# B. Pavard
# B. Mendy
# S. Haller
# A. Rabiot
# A. Gignac
# F. Ribéry
# S. Ruffier
# N. Mukiele
# T. Ndombele
# A. Saint-Maximin
# M. Thuram
# C. Nkunku
# T. Hernández
# K. Zouma
# C. Tolisso
# V. Rongier
# B. Lecomte
# J. Roussillon
# A. Plea
# B. Gomis
# F. Coquelin
# B. André
# W. Boly
# D. Upamecano
# B. Kamara
# J. Ikoné
# D. Zagadou
# J. Koundé
# M. Sanson
# L. Dubois
# B. Santamaria
# J. Veretout
# T. Bakayoko
# B. Costil
# L. Koscielny
# K. Gameiro
# M. Valbuena
# O. Giroud
# M. Sissoko
# Y. M'Vila
# S. Nzonzi
# K. Lala
# I. Konaté
# P. Bernardoni
# A. Lafont
# J. Bamba
# S. Gigot
# A. Diallo
# A. Doucouré
# B. Bourigeaud
# J. Amavi
# R. Aguilar
# P. Lees-Melou
# M. Debuchy
# E. Capoue
# J. Guilavogui
# K. Malcuit
# N. Pallois
# D. Sidibé
# T. Savanier
# F. Mollet
# M. Guendouzi
# I. Diop
# G. Larsonneur
# N. Maupay
# F. Maouassa
# A. Thomasson
# A. Djiku
# H. Kamara
# W. Cyprien
# F. Lejeune
# R. Gurtner
# D. Da Silva
# R. Alessandrini
# X. Chavalerin
# B. Stambouli
# L. Kurzawa
# J. Schmid
# B. Sarr
# E. Camavinga
# B. Soumaré
# L. Blas
# J. Mateta
# M. Terrier
# F. Guilbert
# L. Tousart
# J. Gnagnon
# S. Meïté
# G. Laborde
# I. Amadou
# L. Ajorque
# A. Soumaoro
# M. Schneiderlin
# L. Rémy
# M. Sakho
# R. Thomas
# D. Le Tallec
# R. Hamouma
# M. Gonalons
# Y. Court
# G. Defrel
# F. Tait
# M. Caqueret
# J. Todibo
# J. Reine-Adélaïde
# O. Edouard
# Y. Karamoh
# R. Le Normand
# A. Claude-Maurice
# A. Disasi
# M. Coco
# F. Centonze
# V. Rosier
# C. Dagba
# E. Crivelli
# M. Niakhaté
# K. Amian
# R. Oudin
# M. Sarr
# C. Jullien
# A. Touré
# G. Nkoudou
# M. Lopez
# A. Hunou
# C. Hérelle
# J. Briand
# T. Mangani
# A. Modeste
# A. Rami
# S. Corchia
# A. Souquet
# F. Hanin
# N. Mendy
# N. De Préville
# D. Foulquier
# B. Reynet
# P. Capelle
# D. Liénard
# W. Saliba
# B. Mbeumo
# E. Ndicka
# I. Louza
# A. Caci
# E. Owusu
# A. Fulgini
# S. Alakouch
# M. Cafaro
# S. Guirassy
# A. Touré
# L. Mousset
# A. Briançon
# T. Kolodziejczak
# E. Mangala
# G. Hoarau
# D. Congré
# S. De Maio
# J. Faussurier
# K. Théophile-Catherine
# M. Barthelmé
# V. Le Goff
# V. Germain
# A. Knockaert
# B. Kamara
# S. Nsoki
# O. Ntcham
# M. Chouiar
# B. Dia
# J. Augustin
# R. Perraud
# F. Ballo-Touré
# Y. Fofana
# P. Nardi
# J. Léa Siliki
# N. Gavory
# T. Didillon
# A. Blin
# R. Del Castillo
# P. Burner
# A. Tameze
# E. Gnahoré
# N. Penneteau
# L. Butelle
# J. Leca
# L. Deaux
# J. Pied
# C. Grenier
# V. Manceau
# P. Lasne
# G. Charbonnier
# J. Martin
# M. Colin
# V. Eysseric
# T. Delaine
# A. Trebel
# J. Ferri
# T. Dingomé
# M. Poundjé
# V. Laurini
# J. Bela
# P. Martinez
# Y. Valery
# A. Nordin
# C. Michelin
# I. Diallo
# J. Prior
# K. N'Doram
# E. Kwateng
# J. Gélin
# S. Grandsir
# M. Diakhaby
# D. Bain
# W. Saïd
# F. Tardieu
# L. Diony
# Y. Niakaté
# A. Bamba
# Y. Pelé
# R. Salin
# J. Babin
# K. Monnet-Paquet
# F. Lemoine
# B. Leroy
# M. Autret
# R. Amalfitano
# V. Pajot
# D. Appiah
# L. Carole
# N. Benezet
# T. Monconduit
# B. Pelé
# J. Beauguel
# F. Sotoca
# J. Clauss
# R. Aït Nouri
# T. Kouassi
# Z. Youssouf
# M. Cuisance
# M. Simakan
# K. Thuram
# R. Nteka
# A. Bernede
# I. Cardona
# R. Pierre-Gabriel
# A. Tchouaméni
# B. Badiashile
# V. Koziello
# A. Bobichon
# J. Butez
# O. Boscagli
# C. Jean
# J. Gradit
# J. Dompé
# P. Hamel
# L. Landre
# M. Dupé
# P. Gouano
# S. Moreira
# V. Sasso
# B. Omrani
# R. Ripart
# Y. Cahuzac
# L. Baal
# M. Coutadeur
# P. Baysse
# A. Weber
# B. Poulain
# G. Belaud
# A. Losilla
# B. Ketkeophomphone
# Z. Diallo
# F. Brillant
# K. Rocheteau
# A. Monfray
# F. N'Goma
# F. Ourega
# H. Massengo
# P. Kalulu
# M. Lacroix
# B. Soppy
# O. Solet
# C. Abi
# K. Koné
# J. Ruiz
# L. Pintor
# S. Diop
# M. Sylla
# G. Koyalipou
# T. Cognat
# S. Niakaté
# M. Gonçalves
# L. Mbe Soh
# J. Pendant
# J. Serrano
# P. Cornud
# W. Kanga
# J. Leborgne
# S. Banza
# Q. Daubin
# Y. Magnin
# Y. Ben Balla
# P. Mendy
# B. Chardonnet
# M. D'Arpino
# D. Louiserre
# A. Maraval
# D. Léon
# F. David
# D. Milinković
# W. Semedo
# J. Taravel
# L. Nestor
# A. Collin
# F. Duplus
# W. Rémy
# R. Pillot
# M. Pereira
# J. Rivierez
# J. Faucher
# D. Mohamed
# R. Camacho
# A. Ndiaye
# K. Azamoum
# D. Diring
# C. Psyché
# F. Valot
# G. Bosca
# D. Boudaud
# N. Mbuku
# E. Loiodice
# I. Chouaref
# A. Kalimuendo
# Y. Letard
# C. Gomes
# S. Boey
# D. Bertaud
# A. Zagré
# R. Guitane
# S. Sadzoute
# A. Laurienté
# M. Camara
# W. Tchimbembé
# Y. Hamache
# H. Marcelin
# A. Ndom
# J. Gaspar
# I. Faraj
# L. Rajot
# T. Baya
# S. Mbakata
# N. Dieng
# Y. Roche
# A. Scheidler
# E. Bocat
# A. Maisonnial
# G. Weissbeck
# S. Cibois
# B. Soumaré
# M. Kikonda
# A. Gonçalves Pereira
# Y. Maçon
# A. Belmonte
# A. Batisse
# R. Basque
# T. Campanini
# G. Kyei
# C. Depres
# J. Vachoux
# A. Leautey
# P. Bourdin
# H. Keyta
# L. Rougeaux
# J. Beaulieu
# J. Eickmayer
# D. Dussaut
# D. Bansais
# W. Jobello
# V. Henry
# P. Bardy
# A. Raineau
# S. Pontdemé
# M. Baudry
# M. Martin
# M. Chergui
# P. Delecroix
# E. Dudouit
# E. Ba
# G. Dequaire
# L. Doucouré
# I. Ba
# D. Gomis
# M. Tchokounté
# P. Ruffaut
# A. Tertereau
# J. Chougrani
# D. Thiam
# J. Antiste
# H. Hassan
# T. Basila
# S. Sissoko
# L. Da Cunha
# A. Adli
# A. Taoui
# M. El Idrissy
# K. Cabral
# M. Sitti
# A. Georgen
# A. Ba
# S. Benchama
# M. Léris
# G. Traoré
# Y. Kitala
# E. Sylvestre
# L. Brassier
# R. Kolo Muani
# S. Ambri
# E. Massouema
# Y. Fekir
# R. Faivre
# F. Chabrolle
# I. Marega
# D. Furtado
# A. Phliponeau
# L. Bessilé
# Q. Braat
# G. Tormin
# L. Dias
# B. Passi
# D. Chambost
# N. Kocik
# M. Leverbe
# E. Zidane
# Y. Kaabouni
# N. Mbemba
# M. Chahiri
# L. Bury
# K. Tapoko
# L. Kouagba
# J. Delem
# R. Kerrouche
# M. Kamissoko
# R. Boissier
# J. Correa
# J. Phojo
# M. Derrien
# S. Rénot
# Y. Thuram
# F. Berenguer
# S. Kehli
# F. Martin
# G. Heinry
# M. Biamou
# R. Aabid
# D. Bertrand
# A. Soubervie
# F. Michel
# S. Mara
# T. Pembélé
# L. Agoume
# A. Dabo
# B. Benkhedim
# K. Koindredi
# J. Kadile
# Y. Diouf
# L. Leroy
# M. Bahlouli
# E. Youan
# M. Diarra
# M. Karamoko
# E. Guessand
# W. Geubbels
# J. Ponceau
# A. Trouillet
# C. Vidal
# W. Coulibaly
# A. Rouault
# I. Lihadji
# L. Diabyfadiga
# G. Rutter
# V. Postolachi
# E. Ebosse
# D. Osei Yaw
# N. Alioui
# H. Vandermersch
# B. Boutobba
# M. Merghem
# S. Elisor
# G. Mutombo
# Y. Bourhane
# J. Tell
# M. Bayo
# J. Krasso
# S. Coulibaly
# D. Dianessy
# Q. Bena
# Y. Maziz
# L. Mpasi
# T. Guivarch
# B. Konaté
# A. Nouri
# M. Mandron
# T. Vialla
# G. Laura
# B. Bertrand
# F. Fumu Tamuzo
# M. Latour
# J. Romil
# B. Nouvier
# A. Gomis
# M. Sourzac
# L. Poujol
# M. Guezoui
# K. Rimane
# T. Dieng
# G. Puel
# Y. Mamilonne
# N. Fofana
# S. Beusnard
# S. Bajic
# A. Traoré
# B. Fadiga
# A. Moueffek
# N. Djouahra
# H. Mbock
# M. Doucouré
# L. Badé
# G. Innocent
# S. Kyei
# C. Boli
# Z. Ould Khaled
# A. Flips
# R. Droehnle
# S. Sanna
# I. Kebbal
# T. Ndicka Matam
# D. N'Landu
# T. Lebeau
# W. Bianda
# M. Zerkane
# M. Diallo
# A. Dzabana
# L. Callegari
# A. Guendouz
# V. Lobry
# G. Lefebvre
# S. Flochon
# G. Amiot
# N. Ouammou
# T. Diagouraga
# R. Vincelot
# G. Gigliotti
# A. El Hriti
# L. Chevalier
# A. Virginius
# A. Konaté
# R. Richard
# J. Rahou
# M. Rouai
# A. Nguiamba
# A. Toufiqui
# E. Taha
# Y. Ammour
# B. Abdallah
# H. Abdelli
# L. Carnot
# A. Truffert
# G. Arib
# M. Phaëton
# N. Diliberto
# A. Kamardin
# B. Lasme
# V. Gendrey
# A. Pembélé
# I. Aaneba
# S. Arab
# V. Triboulet
# S. Delos
# W. Omari
# A. Baroan
# S. Raux-Yao
# Y. Severin
# M. Dembélé
# B. Tutu
# R. Sila
# L. Buades
# B. Danger
# V. Pinson
# I. Cissé
# N. Diallo
# D. Trichard
# J. Albert
# X. Pinoteau
# N. Atangana
# A. Ba
# A. Traoré
# M. Tshibuabua
# M. Rivera
# S. Laiton
# A. Beka Beka
# L. Tramoni
# K. Mouanga
# B. Ndilu
# U. Bertelli
# R. Yapi
# A. Valerio
# S. Doucouré
# T. Boulhendi
# J. Hadjam
# D. Desprez
# B. Mendy
# R. Sans
# I. Cissé
# B. Badu
# A. Lebeau
# T. Vargas
# B. Dedola
# N. Ngoumou
# M. Ahlinvi
# M. Robin
# H. Magnetti
# A. Tsague
# J. Le Douaron
# K. Benvindo
# J. Boyer
# D. Tokpa
# L. Morante
# K. Bemanga
# M. Siby
# J. Papeau
# T. Njiké
# R. Pereira de Sa
# N. Bruneel
# R. Muhammed
# P. Marie
# A. Oudrhiri
# A. Souda
# Y. Begraoui
# N. Fatar
# L. Gourna-Douath
# Y. Cimignani
# K. Bafounta
# H. Ekitike
# I. Ouattara
# A. Oudjani
# K. Boma
# P. Méliande
# B. Moltenis
# B. Canelhas
# L. Bernadou
# O. Camara
# O. Camara
# T. Coulibaly
# I. Gomis
# T. Nkada
# W. Jarmouni
# B. Doukansy
# S. Sy
# S. Karamoko
# M. Fischer
# D. Traore
# W. Moustache
# F. Poulolo
# J. Corinus
# A. Peyrelade
# A. Ouhafsa
# M. Guilavogui
# R. Latouchent
# F. Sollacaro
# S. Deslandes
# M. Diaw
# E. Salles
# G. Touré
# L. Lacroix
# J. Ngouabi
# W. Taïbi
# T. Tamas
# N. Zohoré
# L. Ntumba
# R. Philippe
# I. Boura
# R. Vita
# Y. Fortune
# L. Vallier
# M. Adopo
# N. Ntolla Thio
# M. Dembélé
# B. Domingues
# O. Cetiner
# K. Le Roy
# M. Nanizayamo
# B. Mathis
# R. Ponti
# D. Fage
# M. Aljic
# J. Bumbu
# T. Secchi
# C. Zabou
# B. Touré
# J. Popelard
# N. Innocenti
# A. Gomez Mancini
# W. Bedfian
# Y. Benhattab
# Y. Fofana
# G. Haag
# G. Kyeremeh
# M. Doué
# R. Bouallak
# C. Bombo
# L. Margueron
# R. Souici
# Y. Barka
# M. Bassouamina
# A. Linguet
# A. Kerouedan
# M. Picouleau
# B. Roux
# A. Barry
# A. Long
# O. Djoco
# P. Malumandsoko
# G. Coelho
# E. Basilio
# S. Ilgaz
# J. Huysman
# K. Nsona
# R. Jay
# P. Koffi
# L. Sinayoko
# N. Simon
# P. Trindade
# H. Constant
# C. Jan
# K. Guessoum
# S. Chader
# L. Camelo
# I. Karamoko
# B. Doucouré
# V. Daguin
# T. Vannoye
# J. Moutachy
# C. Chaminade
# M. Scalet
# M. Guillaume
# W. Bondo
# D. Meddah
# S. Renel
# E. Samba
# F. Bloch
# D. Rouyard
# J. Khasa
# F. Mattoir
# I. Dioh
# M. Biron
# R. Ndiaye
# A. Boutoutaou
# O. Nkambadio
# D. Youfeigane
# H. Gambor
# T. Okou
# K. Chapelle
# T. Herr
# L. Hervieu
# P. Bourdelle
# C. Goteni
# A. Martial
# T. Bartouche
# I. Doukouré
# L. Marsella
# M. Mazzolini
# D. Salhi
# J. Evan's Allan
# J. Belehouan
# T. Callens
# -------------------------Germany-------------------------
# M. ter Stegen
# M. Neuer
# J. Kimmich
# T. Kroos
# M. Hummels
# T. Müller
# K. Havertz
# L. Sané
# T. Werner
# B. Leno
# S. Gnabry
# M. Reus
# N. Süle
# L. Goretzka
# J. Brandt
# I. Gündoğan
# K. Trapp
# E. Can
# M. Ginter
# M. Özil
# L. Bender
# J. Boateng
# O. Baumann
# K. Bellarabi
# M. Halstenberg
# R. Gosens
# A. Rüdiger
# S. Bender
# S. Khedira
# M. Kruse
# K. Volland
# L. Klostermann
# N. Schulz
# J. Draxler
# K. Demirbay
# L. Stindl
# F. Neuhaus
# J. Tah
# J. Weigl
# A. Schwolow
# M. Arnold
# P. Max
# S. Ulreich
# S. Serdar
# L. Karius
# S. Mustafi
# D. Demme
# D. da Costa
# P. Herrmann
# C. Kramer
# C. Günter
# F. Niederlechner
# N. Amiri
# T. Kehrer
# T. Horn
# L. Unnerstall
# L. Bittencourt
# R. Fährmann
# S. Rudy
# B. Hübner
# P. Groß
# K. Vogt
# S. Rode
# J. Hector
# J. Hofmann
# R. Koch
# L. Waldschmidt
# M. Eggestein
# F. Müller
# M. Mittelstädt
# N. Stark
# M. Dahoud
# B. Henrichs
# M. Meyer
# M. Wolf
# R. Knoche
# N. Füllkrug
# M. Weiser
# T. Leibold
# N. Petersen
# D. Ginczek
# M. Plattenhardt
# F. Klos
# M. Uth
# T. Strobl
# A. Nübel
# J. Torunarigha
# F. Uduokhai
# M. Müller
# R. Zentner
# S. Ortega
# R. Khedira
# Y. Gerhardt
# D. Heintz
# D. Kohr
# J. Haberer
# E. Thommy
# L. Podolski
# R. Hennings
# M. Marin
# D. Brosinski
# D. Diekmeier
# B. Oczipka
# T. Jantschke
# D. Didavi
# A. Younes
# A. Maier
# R. Hack
# M. Richter
# N. Dorsch
# M. Friedrich
# T. Baumgartl
# M. Kempf
# J. Gressel
# C. Gentner
# F. Bastians
# S. Terodde
# N. Müller
# R. Zieler
# M. Schmelzer
# D. Latza
# M. Gulde
# T. Arslan
# A. Luthe
# M. Esser
# F. Klaus
# E. Löwen
# K. Akpoguma
# D. Selke
# L. Öztunalı
# J. Toljan
# J. Geis
# J. Blaswich
# P. Bauer
# P. Mainka
# S. Gümüş
# P. Pentke
# A. Hunt
# G. Castro
# T. Sippel
# F. Bartels
# M. Schäffler
# M. Zimmermann
# S. Bell
# D. Drexler
# S. Kittel
# L. Rupp
# C. Schindler
# O. Hernández
# K. Müller
# O. Kragl
# T. Leistner
# E. Durm
# D. Blum
# A. Voglsammer
# M. Bülter
# L. Maina
# R. Baku
# A. Fein
# D. Geiger
# S. Özcan
# A. Pieper
# W. Anton
# L. Klünter
# T. Kleindienst
# M. Ducksch
# R. Andrich
# P. Stenzel
# A. Hack
# M. Hartel
# K. Wagner
# C. Mathenia
# L. Zingerle
# A. Hoffmann
# M. Leitner
# F. Hübner
# T. Trybull
# K. Möhwald
# J. Zimmer
# P. Tschauner
# N. Theuerkauf
# L. Holtby
# S. Burchert
# H. Badstuber
# M. Höger
# J. Hochscheidt
# M. Riemann
# M. Rzatkowski
# N. Höfler
# D. Kaiser
# S. Dursun
# L. Kübler
# A. Mühling
# R. Czichos
# A. Hahn
# S. Griesbeck
# O. Kiomourtzoglou
# K. Günter
# H. Mukhtar
# M. Stendera
# R. Framberger
# J. Gyamerah
# S. Schonlau
# P. Seguin
# T. Wellenreuther
# G. Jung
# M. Wittek
# J. Pollersbeck
# M. Busch
# M. Schuhen
# B. Schmitz
# M. Sobottka
# L. Höler
# C. Zimmermann
# J. Börner
# S. Skrzybski
# P. Kühn
# A. Walke
# M. Männel
# M. Risse
# F. Jungwirth
# -------------------------Guinea Bissau-------------------------
# Mama Baldé
# Gerso
# Pelé
# Nanu
# Jaquité
# Sori Mané
# Carlos Embaló
# Romário Baldé
# Moreto Cassamá
# Marcelo Djaló
# Bura
# Panutche Camará
# Indjai Correia
# Edson Pires
# Junior Quitirna
# -------------------------Zimbabwe-------------------------
# M. Nakamba
# K. Billiat
# T. Kadewere
# T. Darikwa
# W. Katsande
# K. Musona
# M. Munetsi
# T. Hadebe
# M. Bonne
# M. Rusike
# D. Moyo
# -------------------------South Africa-------------------------
# P. Tau
# T. Hlatshwayo
# L. Singh
# L. Phiri
# I. Khune
# L. Mothiba
# B. Zungu
# T. Lorch
# K. Dolly
# L. Manyama
# V. Pule
# D. Zuma
# F. Makaringe
# W. Sandilands
# K. Mokotjo
# E. Mathoho
# D. Cardoso
# I. Maela
# R. Frosler
# B. Parker
# D. Keet
# R. Mphahlele
# S. Ndlovu
# B. Bvuma
# T. Tlolane
# H. Jele
# L. Memela
# P. Zulu
# B. Motshwari
# P. Mako
# D. Furman
# K. Moleko
# N. Nyauza
# S. Ntshangase
# X. Mlambo
# A. Mabaso
# A. Ndengane
# L. Foster
# S. Ngezana
# S. Ntiya-Ntiya
# T. Mabasa
# B. Sam
# Y. Sasman
# T. Phete
# S. Mpontshane
# K. Ntlhe
# J. Chabalala
# G. Shitolo
# M. Dube
# K. Jacobs
# L. Mntambo
# N. Ngcobo
# L. Le Roux
# H. Mashiane
# T. Matthews
# K. Ayer
# N. Blom
# E. Chislett
# M. Mayambela
# G. Links
# B. Petersen
# D. Visser
# K. Molefe
# -------------------------Iraq-------------------------
# A. Adnan
# O. Rashid
# J. Meram
# A. Yasin
# -------------------------Madagascar-------------------------
# J. Morel
# M. Ilaimaharitra
# R. Métanire
# J. Mombris
# T. Fontaine
# R. Raveloson
# F. Andriatsima
# L. Nomenjanahary
# C. Andriamahitsinoro
# -------------------------Moldova-------------------------
# A. Epureanu
# A. Ioniță
# A. Koselev
# O. Reabciuk
# V. Damașcan
# D. Graur
# I. Armaș
# V. Rață
# E. Cebotaru
# N. Milinceanu
# A. Boiciuc
# I. Brînză
# -------------------------Curacao-------------------------
# E. Room
# J. Bacuna
# K. Gorré
# L. Bacuna
# Q. Martinus
# J. Cijntje
# J. Arias
# J. Gaari
# A. van den Hurk
# B. Martis
# G. Kastaneer
# J. Ogenia
# L. Caciano
# -------------------------Cuba-------------------------
# O. Alonso
# C. Sánchez
# J. Corrales
# C. Vázquez
# M. Chang
# -------------------------Mozambique-------------------------
# Mexer
# Zainadine
# Reinildo
# Witi
# Simao Mate
# -------------------------Gambia-------------------------
# O. Colley
# M. Barrow
# B. Jatta
# M. Barrow
# B. Trawally
# Y. Njie
# S. Marreh
# A. Kanté
# Nuha
# Y. Jarju
# I. Touray
# A. Sanyang
# E. Adams
# M. Jarjué
# K. Ceesay
# E. Colley
# S. Sinyan
# O. Jaiteh
# A. Manneh
# S. Bojang
# M. Juwara
# A. Ceesay
# S. Janneh
# J. Gomez
# -------------------------Cyprus-------------------------
# K. Laifis
# A. Gogić
# J. Demetriou
# J. Roles
# H. Kyprianou
# R. Sotiriou
# H. Kyprianou
# -------------------------Estonia-------------------------
# R. Klavan
# K. Mets
# T. Teniste
# E. Sorga
# G. Tunjov
# -------------------------Benin-------------------------
# S. Sessègnon
# S. Allagbé
# S. Mounié
# F. Farnolle
# C. Soukou
# J. Dossou
# C. Hountondji
# Y. Aguemon
# S. D'Almeida
# J. Adéoti
# D. Djigla
# -------------------------Lithuania-------------------------
# G. Arlauskis
# F. Černych
# A. Novikovas
# L. Spalvis
# E. Girdvainis
# T. Krapikas
# M. Palionis
# B. Satkus
# S. Olberkis
# E. Dubickas
# -------------------------Saudi Arabia-------------------------
# S. Al Dawsari
# Y. Al Shahrani
# M. Al Buraik
# S. Al Faraj
# M. Kanno
# M. Al Owais
# S. Al Ghannam
# A. Ateef
# A. Al Mayoof
# F. Al Muwallad
# A. Aseri
# M. Hawsawi
# N. Al Abed
# Y. Al Shehri
# W. Bakhashwain
# S. Muwashar
# A. Al Bulayhi
# A. Al Sulayhim
# M. Al Kuwaykibi
# M. Al Fatil
# A. Al Obaid
# Y. Al Mosailem
# O. Hawsawi
# K. Al Ghamdi
# H. Bahebri
# H. Al Moqahwi
# M. Al Harbi
# S. Al Muwallad
# A. Al Khaibari
# M. Al Olayan
# S. Al Shehri
# A. Madu
# F. Al Qarni
# J. Bajandouh
# M. Malaeka
# A. Khamis
# M. Jahfali
# I. Al Zubaidi
# A. Al Jebreen
# M. Salem
# H. Kadish
# F. Al Sagour
# M. Ali
# A. Sharahili
# M. Qasem
# A. Al Malki
# Z. Al Sahafi
# T. Al Absi
# M. Khubrani
# A. Al Hafith
# A. Al Shamekh
# A. Al Zori
# A. Al Khaibari
# A. Kurdi
# A. Asiri
# T. Bu Haymid
# R. Sufyani
# M. Al Amri
# N. Al Mousa
# H. Al Hazaa
# S. Abdulhamid
# S. Farhan
# H. Al Shamrani
# S. Al Rubaie
# A. Adam
# A. Al Ghamdi
# Y. Barnawi
# A. Al Salem
# A. Al Jadani
# H. Al Mansour
# A. Al Bishi
# S. Al Jaman
# M. Al Sahlawi
# H. Sulaimani
# S. Al Qumayzi
# M. Asiri
# F. Darwish
# M. Abusabaan
# A. Al Zaqan
# A. Al Barakah
# B. Al Mutairi
# S. Al Khaibari
# A. Al Najjar
# A. Ghareeb
# A. Abdu
# R. Al Mousa
# A. Hazazi
# A. Al Fahad
# F. Bin Jamayah
# W. Abdullah
# S. Sharahili
# M. Al Fehaid
# S. Al Sawadi
# A. Al Mutairi
# M. Hamzi
# K. Al Kaabi
# A. Al Zain
# K. Al Barakah
# T. Al Ammar
# A. Al Hamdan
# A. Lajami
# O. Al Khalaf
# A. Al Suwat
# A. Al Shammary
# H. Al Qahtani
# M. Al Baqawi
# K. Al Khathlan
# A. Al Shammari
# R. Al Ghamdi
# A. Al Obud
# M. Al Saiari
# H. Al Jayzani
# N. Hazazi
# A. Al Mazaidi
# K. Sharahili
# A. Al Kassar
# Y. Hamza
# A. Khrees
# A. Al Sahabi
# W. Suwayyid
# N. Al Subhi
# S. Amro
# A. Al Nazera
# M. Al Furayj
# N. Mousa
# O. Muzayil
# A. Al Qahtani
# A. Al Nemer
# M. Bakhit
# I. Mahnashi
# Y. Al Bakr
# A. Hindi
# A. Al Amri
# M. Al Dawsari
# K. Al Samiri
# A. Hassoun
# S. Al Najai
# S. Al Nabit
# S. Mandash
# H. Al Habib
# A. Al Joui
# A. Al Habib
# A. Al Ammar
# S. Al Qeshtah
# F. Ghazi
# M. Al Qarni
# M. Hazazi
# H. Al Shuwaysh
# A. Al Yousef
# B. Al Nakhli
# A. Al Khaibari
# F. Al Aiyaf
# M. Al Najrani
# A. Al Nashi
# K. Barnawi
# J. Issa
# H. Camara
# A. Al Dawsari
# A. Al Khulaif
# A. Al Asmari
# N. Al Omran
# M. Al Mufarrij
# N. Al Dawsari
# A. Ba Masoud
# M. Fallatah
# S. Al Khayri
# S. Al Abbas
# A. Fallatah
# M. Kanabah
# H. Shaian
# M. Majrashi
# A. Majrashi
# B. Al Baqi
# A. Al Saleh
# M. Al Thmali
# H. Al Juhayyim
# A. Kanno
# H. Jafry
# A. Qaisi
# M. Abu Shararah
# A. Jafar
# M. Harzan
# A. Ashraf
# M. Al Rashidi
# H. Al Ghamdi
# H. Al Watyan
# S. Al Hamsal
# M. Al Majhad
# A. Al Ruhaili
# A. Al Aryani
# T. Abdullah
# M. Naji
# H. Belal
# A. Al Najai
# A. Al Riou
# M. Al Najai
# O. Hawsawi
# A. Maadi
# R. Al Radhi
# N. Al Muwallad
# J. Al Dossary
# H. Al Raheb
# J. Al Zoaed
# F. Fallatah
# B. Al Seliteen
# M. Al Bassas
# M. Al Rashdi
# O. Ashoor
# M. Madkhali
# H. Tombakti
# H. Al Geed
# S. Al Selouli
# M. Al Mutlaq
# J. Asiri
# A. Majrashi
# M. Al Rubaie
# M. Al Qahtani
# F. Al Tryes
# A. Al Yami
# M. Rayman
# A. Al Hassan
# M. Al Moqahwi
# O. Ilyas
# H. Al Ruwaili
# H. Raghfawi
# W. Al Anazi
# A. Al Khatib
# S. Faqihi
# A. Al Sultan
# F. Al Shammari
# M. Al Burayh
# M. Attiyah
# D. Al Saeed
# M. Al Sahli
# M. Al Hassawi
# I. Omar
# H. Al Eissa
# M. Al Shanqeeti
# A. Al Saluli
# A. Attiah
# A. Al Yousif
# A. Majrashi
# T. Al Ali
# Y. Al Harbi
# A. Al Hejaili
# H. Halawani
# M. Mohammed
# M. Jawhar
# M. Al Haidari
# M. Al Subaie
# M. Al Sharimi
# A. Al Samtai
# A. Al Shamrani
# R. Sharahili
# A. Al Salem
# S. Al Dosari
# S. Otayf
# M. Al Wakid
# A. Al Humayan
# K. Al Ghannam
# R. Al Otaibi
# T. Al Otaibi
# R. Solan
# Q. Lajami
# M. Al Saeed
# F. Al Rashidi
# H. Al Hajouj
# A. Al Jamaan
# M. Al Haeti
# M. Awaji
# O. Al Sunain
# N. Al Rashidi
# M. Awadh
# M. Zoulan
# N. Boushal
# F. Abdi
# A. Abdullah
# A. Al Qahtani
# M. Al Mahasna
# H. Salem
# N. Al Dajani
# M. Al Thani
# F. Al Hamad
# A. Al Bahri
# I. Albaraka
# B. Al Enezi
# H. Fallatah
# A. Al Shammari
# H. Al Shamrani
# H. Al Abdan
# N. Al Ghamdi
# A. Al Hassan
# H. Hawsawi
# N. Al Sharari
# M. Al Shudukhi
# H. Asiri
# M. Al Baqawi
# M. Al Abdulmunem
# A. Al Meqran
# Y. Sahfi
# M. Al Nakhli
# R. Al Najjar
# M. Al Burayh
# M. Sibyani
# M. Sanyor
# M. Habkoor
# M. Al Ghamdi
# R. Al Najjar
# B. Al Bahrani
# R. Al Marshoud
# I. Al Otaibi
# S. Al Saeed
# G. Al Enazi
# H. Al Quraish
# A. Al Enazi
# A. Al Dheyabi
# T. Al Shahrani
# -------------------------Liberia-------------------------
# O. Dorley
# S. Johnson
# S. Nimely
# M. Sangare
# -------------------------Bulgaria-------------------------
# K. Despodov
# B. Kraev
# K. Malinov
# D. Velkovski
# S. Popov
# A. Galabinov
# R. Dimitrov
# I. Goranov
# A. Ivanov
# M. Minchev
# Diego Ferraresso
# S. Velkov
# I. Gruev
# A. Chandarov
# G. Pashov
# T. Chunchukov
# P. Hristov
# D. Mitov
# V. Nikolov
# -------------------------Libya-------------------------
# A. Musrati
# I. Tajouri-Shradi
# A. Benali
# M. El-Munir
# -------------------------Philippines-------------------------
# N. Etheridge
# J. Strauß
# J. Tabinas
# -------------------------Sierra Leone-------------------------
# K. Kamara
# M. Bundu
# M. Turay
# A. Kamara
# A. Kargbo
# G. Davies
# U. Bangura
# A. Bakayoko
# O. Kakay
# -------------------------Uzbekistan-------------------------
# O. Akhmedov
# I. Alibaev
# R. Ashurmatov
# O. Urunov
# D. Tursunov
# J. Jaloliddinov
# J. Iskanderov
# -------------------------Saint Kitts and Nevis-------------------------
# R. Sawyers
# M. Nottingham
# -------------------------United Arab Emirates-------------------------
# Caio
# K. Eissa
# B. Al Ahbabi
# A. Barman
# Y. Nader
# I. Ahmed
# J. Maroof
# M. Abdulrahman
# M. Shaker
# R. Yaslam
# M. Salem
# S. Juma
# M. Jamal
# M. Fayez
# F. Hadid
# M. Bu Sanda
# M. Helal
# M. Ahmed
# S. Abdullah
# H. Al Mansoury
# K. Al Blooshi
# M. Abdullah
# -------------------------Comoros-------------------------
# F. Bachirou
# A. Ahamada
# F. Selemani
# Y. M'Changama
# N. Chamed
# C. Alhadhur
# S. Bakari
# Y. Zahary
# A. Ali Mohamed
# M. Youssouf
# A. Abdallah
# R. Saïd
# -------------------------Chad-------------------------
# C. Ninga
# -------------------------Namibia-------------------------
# R. Nyambe
# D. Hotto
# M. Starke
# -------------------------Thailand-------------------------
# C. Songkrasin
# T. Bunmathan
# T. Dangda
# K. Thamsatchanan
# -------------------------Bermuda-------------------------
# N. Wells
# -------------------------Luxembourg-------------------------
# M. Chanot
# C. Martins
# L. Jans
# Gerson Rodrigues
# L. Gerson
# L. Barreiro Martins
# M. Deville
# V. Thill
# T. Hall
# D. Carlson
# D. Sinani
# -------------------------Trinidad & Tobago-------------------------
# J. Jones
# K. Molino
# L. García
# S. Bateau
# A. Jones
# G. Ranjitsingh
# -------------------------Antigua & Barbuda-------------------------
# M. Romeo
# L. James-Wildin
# J. Parker
# D. Bowry
# -------------------------Burundi-------------------------
# S. Berahino
# C. Amissi
# P. Bizoza
# M. Amissi
# E. Kamsoba
# Y. Ndayishimiye
# P. Niyongabire
# -------------------------Kazakhstan-------------------------
# B. Islamkhan
# Y. Vorogovskiy
# B. Zaynutdinov
# A. Merkel
# K. Engel
# G. Zhukov
# -------------------------New Caledonia-------------------------
# W. Lautoa
# -------------------------Puerto Rico-------------------------
# Z. Valentin
# -------------------------Bolivia-------------------------
# A. Chumacero
# D. Bejarano
# M. Zoch
# E. Saavedra
# C. Lampe
# O. Ribera
# D. Mancilla
# R. Cordano
# J. Arce
# J. Orellana
# H. Rodríguez
# E. Zenteno
# A. Meleán
# R. Ballivián
# F. Saucedo
# C. Melgar
# J. Torrico
# V. Castellón
# S. Galindo
# J. Carrasco
# J. Fernández
# L. Vaca
# L. Haquín
# J. Rojas
# L. Pavia
# F. Rodríguez
# L. Justiniano
# J. Vaca
# H. Suárez
# L. Gutiérrez
# G. Álvarez
# S. Galindo
# J. Arrascaita
# O. Vaca
# C. Machado
# J. Aponte
# O. Añez
# J. Candia
# R. Cueto
# J. Flores
# P. Laredo
# R. Quiñonez
# A. Jusino
# E. Rodríguez
# R. Pedriel
# R. Ramallo
# E. Sánchez
# J. Ortiz
# R. Montero
# V. Melgar
# M. Quiroga
# E. Puña
# C. Menacho
# S. Gamarra
# J. Roca
# A. Veizaga
# W. Soleto
# L. Vargas
# S. Adrián
# P. Arano
# A. Rey
# K. Romay
# E. Arauz
# M. Suárez
# C. Arabe
# K. Salvatierra
# R. Fernández
# D. Sandy
# G. Olguín
# C. Algarañaz
# W. Álvarez
# L. Cárdenas
# G. Viscarra
# J. Cuellar
# N. Cabrera
# H. Gutiérrez
# J. Rioja
# D. Rojas
# Jaume Cuéllar
# M. Villarroel
# J. Montenegro
# R. Banegas
# E. Cano
# J. Isita
# A. Mercado
# D. Torrico
# J. Peñarrieta
# E. Pérez
# S. Navarro
# L. Urapuca
# P. Azogue
# W. Saucedo
# S. Reyes
# P. Galindo
# B. Uraezaña
# J. Muñóz
# H. Rojas
# J. Castillo
# J. Fierro
# J. García
# E. Vaca
# E. Pacheco
# R. Sánchez
# B. Calderon
# J. Sagredo
# W. Rojas
# A. Cabrera
# J. Pérez
# W. Rioja
# M. Garzón
# L. Justiniano
# D. Pérez
# P. Justiniano
# S. Claure
# R. Cuellar
# M. Cabral
# R. Canido
# C. Solíz
# C. Menacho
# J. Mamani
# R. Spenhay
# J. Herrera
# S. Pozo
# D. Navarro
# F. Roca
# H. Cardozo
# L. Vaca
# E. Montero
# M. Barbery
# P. Alcocer
# J. Martínez
# J. Ferrufino
# B. Rivas
# N. Orozco
# R. Orihuela
# V. Abrego
# J. Quinteros
# M. Flores
# F. Cárdenas
# -------------------------Eritrea-------------------------
# H. Goitom
# M. Saeid
# -------------------------Latvia-------------------------
# P. Šteinbors
# M. Ošs
# V. Gutkovskis
# R. Uldriķis
# K. Tobers
# D. Titov
# D. Ontužāns
# -------------------------Montserrat-------------------------
# L. Taylor
# B. Comley
# D. Daniels
# -------------------------São Tomé & Príncipe-------------------------
# Luís Leal
# -------------------------Malawi-------------------------
# G. Mhango
# -------------------------Mauritania-------------------------
# M. El Hacen
# A. Abeid
# H. Sy
# A. Ba
# H. Abou Demba
# A. Mahmoud
# S. Anne
# -------------------------El Salvador-------------------------
# D. Cerén
# D. Pineda
# A. Flores
# R. Domínguez
# -------------------------Haiti-------------------------
# C. Arcus
# F. Pierrot
# H. Bazile
# D. Etienne Jr.
# S. Mustivar
# B. Alceus
# D. Nazon
# S. Saba
# L. Pierre
# D. Ulysse
# -------------------------Uganda-------------------------
# F. Miya
# E. Bwomono
# M. Azira
# M. Opondo
# U. Ikpeazu
# H. Bockhorn
# R. Mukiibi
# B. Mugabi
# R. Kakeeto
# -------------------------Chinese Taipei-------------------------
# Zhou Dingyang
# Yaki Yen
# -------------------------Aruba-------------------------
# J. John
# -------------------------Faroe Islands-------------------------
# J. Edmundsson
# H. Hansson
# G. Rólantsson
# V. Davidsen
# B. Hendriksson Olsen
# -------------------------Guyana-------------------------
# T. Ondaan
# W. Creavalle
# C. Harriott
# R. Greenidge
# M. Briggs
# T. Vancooten
# S. Duke-McKenna
# L. Gordon
# E. Bonds
# K. McKenzie-Lyle
# -------------------------Azerbaijan-------------------------
# D. Nazarov
# Eddy Silvestre
# E. Nouri
# E. Kaplan
# B. Ekincier
# S. Tasdemir
# -------------------------Afghanistan-------------------------
# H. Amin
# O. Haydary
# -------------------------Sudan-------------------------
# M. Eisa
# A. Eisa
# M. Al Dhaw
# M. Adam
# -------------------------Guam-------------------------
# A. DeLaGarza
# -------------------------Belarus-------------------------
# V. Lisakovich
# I. Shkurin
# J. Shcherbakovski
# -------------------------Rwanda-------------------------
# D. Bizimana
# -------------------------Grenada-------------------------
# A. Pierre
# S. Baptiste
# O. Beckles
# O. Norburn
# -------------------------Palestine-------------------------
# I. Khalili
# A. Awad
# -------------------------Lebanon-------------------------
# J. Oumari
# F. Michel
# H. El-Helwe
# -------------------------Papua New Guinea-------------------------
# D. Browne
# -------------------------Jordan-------------------------
# J. Tamimi
# M. Afana
# -------------------------Saint Lucia-------------------------
# J. Donacien
# -------------------------Liechtenstein-------------------------
# S. Wieser
# B. Büchel
# M. Göppel
# J. Ospelt
# F. Saglam
# -------------------------Ethiopia-------------------------
# A. Askar
# Y. Abetew
# -------------------------Belize-------------------------
# T. Rocha
# M. Salazar
# -------------------------Niger-------------------------
# Y. Diori
# H. Adamou
# Y. Omar
# I. Salou
# -------------------------Malta-------------------------
# L. Gambin
# -------------------------Andorra-------------------------
# Marc Vales
# -------------------------Barbados-------------------------
# H. Hope
# -------------------------South Sudan-------------------------
# R. Tongyik
# A. Kuol
# -------------------------Macau-------------------------
# David Cardoso
# -------------------------Korea DPR-------------------------
# Ryang Yong Gi
# -------------------------Hong Kong-------------------------
# Dai Wai-Tsun
# Tan Chun Lok
# -------------------------Malaysia-------------------------
# L. Hakim
# -------------------------Indonesia-------------------------
# E. Maulana Vikri
# -------------------------Nicaragua-------------------------
# J. Moreno

# %%
fifa_df.info
# Out:
# <bound method DataFrame.info of                     name  age  height_cm  weight_kg nationality  \
# 0               L. Messi   33        170         72   Argentina
# 1      Cristiano Ronaldo   35        187         83    Portugal
# 2               J. Oblak   27        188         87    Slovenia
# 3         R. Lewandowski   31        184         80      Poland
# 4              Neymar Jr   28        175         68      Brazil
# ...                  ...  ...        ...        ...         ...
# 18939          K. Angulo   24        176         73    Colombia
# 18940     Zhang Mengxuan   21        177         70    China PR
# 18941      Wang Zhenghao   20        185         74    China PR
# 18942        Chen Zitong   23        186         80    China PR
# 18943           Song Yue   28        185         79    China PR
#
#                                  club_name              league_name  \
# 0                             FC Barcelona   Spain Primera Division
# 1                                 Juventus          Italian Serie A
# 2                          Atlético Madrid   Spain Primera Division
# 3                        FC Bayern München     German 1. Bundesliga
# 4                      Paris Saint-Germain           French Ligue 1
# ...                                    ...                      ...
# 18939                      América de Cali  Colombian Liga Postobón
# 18940  Chongqing Dangdai Lifan FC SWM Team     Chinese Super League
# 18941                      Tianjin TEDA FC     Chinese Super League
# 18942        Shijiazhuang Ever Bright F.C.     Chinese Super League
# 18943                      Tianjin TEDA FC     Chinese Super League
#
#        league_rank  overall  potential  ...  mentality_vision  \
# 0              1.0       93         93  ...                95
# 1              1.0       92         92  ...                82
# 2              1.0       91         93  ...                65
# 3              1.0       91         91  ...                79
# 4              1.0       91         91  ...                90
# ...            ...      ...        ...  ...               ...
# 18939          1.0       47         52  ...                49
# 18940          1.0       47         52  ...                25
# 18941          1.0       47         51  ...                25
# 18942          1.0       47         51  ...                45
# 18943          1.0       47         47  ...                44
#
#        mentality_penalties mentality_composure defending_standing_tackle  \
# 0                       75                  96                        35
# 1                       84                  95                        32
# 2                       11                  68                        12
# 3                       88                  88                        42
# 4                       92                  93                        30
# ...                    ...                 ...                       ...
# 18939                   39                  36                        39
# 18940                   35                  40                        56
# 18941                   35                  40                        55
# 18942                   42                  43                        49
# 18943                   36                  35                        43
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                            24                   6                    11
# 1                            24                   7                    11
# 2                            18                  87                    92
# 3                            19                  15                     6
# 4                            29                   9                     9
# ...                         ...                 ...                   ...
# 18939                        54                  10                     9
# 18940                        47                  12                    13
# 18941                        45                  12                     9
# 18942                        45                  15                     7
# 18943                        45                   8                     5
#
#       goalkeeping_kicking goalkeeping_positioning goalkeeping_reflexes
# 0                      15                      14                    8
# 1                      15                      14                   11
# 2                      78                      90                   90
# 3                      12                       8                   10
# 4                      15                      15                   11
# ...                   ...                     ...                  ...
# 18939                  14                       6                    6
# 18940                   8                      14                    6
# 18941                  14                      15                   13
# 18942                   7                       5                   13
# 18943                  11                       5                    7
#
# [18719 rows x 65 columns]>

# %%
description=fifa_df.describe()
description
# Out:
#                 age     height_cm     weight_kg   league_rank       overall  \
# count  18719.000000  18719.000000  18719.000000  18719.000000  18719.000000
# mean      25.177787    181.190074     75.006945      1.357070     65.635023
# std        4.682187      6.819258      7.053984      0.739327      7.003908
# min       16.000000    155.000000     50.000000      1.000000     47.000000
# 25%       21.000000    176.000000     70.000000      1.000000     61.000000
# 50%       25.000000    181.000000     75.000000      1.000000     66.000000
# 75%       28.000000    186.000000     80.000000      1.000000     70.000000
# max       53.000000    206.000000    110.000000      4.000000     93.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18719.000000  1.871900e+04   18719.000000              18719.000000
# mean      71.089695  2.251555e+06    8780.135157                  1.091832
# std        6.112693  5.127193e+06   19749.383757                  0.362167
# min       47.000000  0.000000e+00     500.000000                  1.000000
# 25%       67.000000  3.000000e+05    1000.000000                  1.000000
# 50%       71.000000  6.500000e+05    3000.000000                  1.000000
# 75%       75.000000  1.800000e+06    8000.000000                  1.000000
# max       95.000000  1.055000e+08  560000.000000                  5.000000
#
#           weak_foot  ...  mentality_vision  mentality_penalties  \
# count  18719.000000  ...      18719.000000         18719.000000
# mean       2.935787  ...         53.803943            48.018430
# std        0.666895  ...         13.710659            15.658848
# min        1.000000  ...          9.000000             6.000000
# 25%        3.000000  ...         45.000000            38.000000
# 50%        3.000000  ...         55.000000            49.000000
# 75%        3.000000  ...         64.000000            60.000000
# max        5.000000  ...         95.000000            92.000000
#
#        mentality_composure  defending_standing_tackle  \
# count         18719.000000               18719.000000
# mean             57.938672                  47.552006
# std              12.103234                  21.381018
# min              12.000000                   5.000000
# 25%              50.000000                  27.000000
# 50%              59.000000                  55.000000
# 75%              66.000000                  65.000000
# max              96.000000                  93.000000
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# count              18719.000000        18719.000000          18719.000000
# mean                  45.516320           16.415620             16.213046
# std                   20.927713           17.547823             16.811146
# min                    4.000000            1.000000              1.000000
# 25%                   24.000000            8.000000              8.000000
# 50%                   52.000000           11.000000             11.000000
# 75%                   63.000000           14.000000             14.000000
# max                   90.000000           90.000000             92.000000
#
#        goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes
# count         18719.000000             18719.000000          18719.000000
# mean             16.076126                16.199583             16.527218
# std              16.491500                16.982050             17.848455
# min               1.000000                 1.000000              1.000000
# 25%               8.000000                 8.000000              8.000000
# 50%              11.000000                11.000000             11.000000
# 75%              14.000000                14.000000             14.000000
# max              93.000000                91.000000             90.000000
#
# [8 rows x 56 columns]

# %% [markdown]
# From the above description we can see >>><br>
# **The range of ages of the players is between 16 and 53**<br>
# **The range of weights(in kg) of the players is between 50 and 110**<br>

# %%
#printing all columns
for i in fifa_df.columns:
    print(i)
# Out:
# name
# age
# height_cm
# weight_kg
# nationality
# club_name
# league_name
# league_rank
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# mentality_aggression
# mentality_interceptions
# mentality_positioning
# mentality_vision
# mentality_penalties
# mentality_composure
# defending_standing_tackle
# defending_sliding_tackle
# goalkeeping_diving
# goalkeeping_handling
# goalkeeping_kicking
# goalkeeping_positioning
# goalkeeping_reflexes

# %%
#First 10 rows 
fifa_df.head(10)
# Out:
#                 name  age  height_cm  weight_kg  nationality  \
# 0           L. Messi   33        170         72    Argentina
# 1  Cristiano Ronaldo   35        187         83     Portugal
# 2           J. Oblak   27        188         87     Slovenia
# 3     R. Lewandowski   31        184         80       Poland
# 4          Neymar Jr   28        175         68       Brazil
# 5       K. De Bruyne   29        181         70      Belgium
# 6          K. Mbappé   21        178         73       France
# 7      M. ter Stegen   28        187         85      Germany
# 8        V. van Dijk   28        193         92  Netherlands
# 9            Alisson   27        191         91       Brazil
#
#              club_name             league_name  league_rank  overall  \
# 0         FC Barcelona  Spain Primera Division          1.0       93
# 1             Juventus         Italian Serie A          1.0       92
# 2      Atlético Madrid  Spain Primera Division          1.0       91
# 3    FC Bayern München    German 1. Bundesliga          1.0       91
# 4  Paris Saint-Germain          French Ligue 1          1.0       91
# 5      Manchester City  English Premier League          1.0       91
# 6  Paris Saint-Germain          French Ligue 1          1.0       90
# 7         FC Barcelona  Spain Primera Division          1.0       90
# 8            Liverpool  English Premier League          1.0       90
# 9            Liverpool  English Premier League          1.0       90
#
#    potential  ...  mentality_vision  mentality_penalties mentality_composure  \
# 0         93  ...                95                   75                  96
# 1         92  ...                82                   84                  95
# 2         93  ...                65                   11                  68
# 3         91  ...                79                   88                  88
# 4         91  ...                90                   92                  93
# 5         91  ...                94                   84                  91
# 6         95  ...                80                   70                  84
# 7         93  ...                70                   25                  70
# 8         91  ...                65                   62                  90
# 9         91  ...                66                   23                  65
#
#   defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                        35                        24                   6
# 1                        32                        24                   7
# 2                        12                        18                  87
# 3                        42                        19                  15
# 4                        30                        29                   9
# 5                        65                        53                  15
# 6                        34                        32                  13
# 7                        13                        10                  88
# 8                        93                        86                  13
# 9                        19                        16                  86
#
#    goalkeeping_handling goalkeeping_kicking goalkeeping_positioning  \
# 0                    11                  15                      14
# 1                    11                  15                      14
# 2                    92                  78                      90
# 3                     6                  12                       8
# 4                     9                  15                      15
# 5                    13                   5                      10
# 6                     5                   7                      11
# 7                    85                  88                      88
# 8                    10                  13                      11
# 9                    88                  85                      91
#
#   goalkeeping_reflexes
# 0                    8
# 1                   11
# 2                   90
# 3                   10
# 4                   11
# 5                   13
# 6                    6
# 7                   90
# 8                   11
# 9                   89
#
# [10 rows x 65 columns]

# %%
#last 10 rows
fifa_df.tail(10)
# Out:
#                  name  age  height_cm  weight_kg nationality  \
# 18934    Wang Zhen'ao   20        175         69    China PR
# 18935          Xia Ao   21        178         66    China PR
# 18936      Zhong Jiyu   23        170         62    China PR
# 18937    Wang Huapeng   20        181         77    China PR
# 18938   Huang Wenzhou   21        174         68    China PR
# 18939       K. Angulo   24        176         73    Colombia
# 18940  Zhang Mengxuan   21        177         70    China PR
# 18941   Wang Zhenghao   20        185         74    China PR
# 18942     Chen Zitong   23        186         80    China PR
# 18943        Song Yue   28        185         79    China PR
#
#                                  club_name              league_name  \
# 18934                     Dalian YiFang FC     Chinese Super League
# 18935                           Wuhan Zall     Chinese Super League
# 18936        Shijiazhuang Ever Bright F.C.     Chinese Super League
# 18937                     Guangzhou R&F FC     Chinese Super League
# 18938                     Shanghai SIPG FC     Chinese Super League
# 18939                      América de Cali  Colombian Liga Postobón
# 18940  Chongqing Dangdai Lifan FC SWM Team     Chinese Super League
# 18941                      Tianjin TEDA FC     Chinese Super League
# 18942        Shijiazhuang Ever Bright F.C.     Chinese Super League
# 18943                      Tianjin TEDA FC     Chinese Super League
#
#        league_rank  overall  potential  ...  mentality_vision  \
# 18934          1.0       47         57  ...                46
# 18935          1.0       47         55  ...                28
# 18936          1.0       47         55  ...                46
# 18937          1.0       47         53  ...                33
# 18938          1.0       47         53  ...                53
# 18939          1.0       47         52  ...                49
# 18940          1.0       47         52  ...                25
# 18941          1.0       47         51  ...                25
# 18942          1.0       47         51  ...                45
# 18943          1.0       47         47  ...                44
#
#        mentality_penalties mentality_composure defending_standing_tackle  \
# 18934                   46                  45                        32
# 18935                   38                  44                        52
# 18936                   35                  43                        39
# 18937                   35                  37                        52
# 18938                   35                  35                        42
# 18939                   39                  36                        39
# 18940                   35                  40                        56
# 18941                   35                  40                        55
# 18942                   42                  43                        49
# 18943                   36                  35                        43
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 18934                        42                  14                    12
# 18935                        50                   7                     8
# 18936                        45                   5                    13
# 18937                        55                  10                    15
# 18938                        53                   8                     8
# 18939                        54                  10                     9
# 18940                        47                  12                    13
# 18941                        45                  12                     9
# 18942                        45                  15                     7
# 18943                        45                   8                     5
#
#       goalkeeping_kicking goalkeeping_positioning goalkeeping_reflexes
# 18934                   9                       8                   12
# 18935                   5                      14                   11
# 18936                   7                      13                   13
# 18937                  12                       8                   13
# 18938                  13                      14                   10
# 18939                  14                       6                    6
# 18940                   8                      14                    6
# 18941                  14                      15                   13
# 18942                   7                       5                   13
# 18943                  11                       5                    7
#
# [10 rows x 65 columns]

# %% [markdown]
# Let's split up the fifa_df into sub-df's so that we can perform and use the df's accoridng to our need.

# %%
#Total number of players
print('The total number of players in FIFA21 : {}'.format(fifa_df.shape[0]))
# Out:
# The total number of players in FIFA21 : 18719

# %%
#All countries
countries_df=fifa_df.drop_duplicates(subset='nationality',keep='first')[['nationality']]
countries_df
# Out:
#       nationality
# 0       Argentina
# 1        Portugal
# 2        Slovenia
# 3          Poland
# 4          Brazil
# ...           ...
# 15386   Korea DPR
# 16819   Hong Kong
# 17121    Malaysia
# 17179   Indonesia
# 17422   Nicaragua
#
# [161 rows x 1 columns]

# %%
print('Total number of countries in FIFA21 : {}'.format(countries_df.shape[0]))
# Out:
# Total number of countries in FIFA21 : 161

# %%
#Players who are goalkeepers
strickers_df=fifa_df[['name','player_positions','nationality','club_name','overall','potential']]
strickers_df=strickers_df[strickers_df['player_positions'].str.contains(pat='GK')]
strickers_df.sort_values('overall',ascending=False).head(20)
# Out:
#               name player_positions  nationality                 club_name  \
# 2         J. Oblak               GK     Slovenia           Atlético Madrid
# 9          Alisson               GK       Brazil                 Liverpool
# 7    M. ter Stegen               GK      Germany              FC Barcelona
# 12     T. Courtois               GK      Belgium               Real Madrid
# 16        M. Neuer               GK      Germany         FC Bayern München
# 18         Ederson               GK       Brazil           Manchester City
# 23   S. Handanovič               GK     Slovenia                     Inter
# 44        K. Navas               GK   Costa Rica       Paris Saint-Germain
# 40     W. Szczęsny               GK       Poland                  Juventus
# 36       H. Lloris               GK       France         Tottenham Hotspur
# 54       Y. Sommer               GK  Switzerland  Borussia Mönchengladbach
# 59          De Gea               GK        Spain         Manchester United
# 63   G. Donnarumma               GK        Italy                     Milan
# 75         B. Leno               GK      Germany                   Arsenal
# 89      P. Gulácsi               GK      Hungary                RB Leipzig
# 122  K. Schmeichel               GK      Denmark            Leicester City
# 126   Rui Patrício               GK     Portugal   Wolverhampton Wanderers
# 123      S. Sirigu               GK        Italy                    Torino
# 113       R. Bürki               GK  Switzerland         Borussia Dortmund
# 110       A. Onana               GK     Cameroon                      Ajax
#
#      overall  potential
# 2         91         93
# 9         90         91
# 7         90         93
# 12        89         90
# 16        89         89
# 18        88         91
# 23        88         88
# 44        87         87
# 40        87         87
# 36        87         87
# 54        86         86
# 59        86         86
# 63        85         92
# 75        85         87
# 89        85         85
# 122       84         84
# 126       84         84
# 123       84         84
# 113       84         85
# 110       84         88

# %%
#Let's check how many players are here only from England
eng_players_df=fifa_df[fifa_df.nationality=='England']
eng_players_df
# Out:
#                       name  age  height_cm  weight_kg nationality  \
# 19             R. Sterling   25        170         69     England
# 21                 H. Kane   26        188         89     England
# 28               J. Sancho   20        180         76     England
# 29     T. Alexander-Arnold   21        180         69     England
# 56            J. Henderson   30        182         80     England
# ...                    ...  ...        ...        ...         ...
# 18919         J. Akintunde   24        175         75     England
# 18926            L. Walker   30        196         80     England
# 18928          V. Da Silva   17        171         58     England
# 18929             B. Hough   17        175         65     England
# 18930          R. McKinley   18        179         74     England
#
#                 club_name                     league_name  league_rank  \
# 19        Manchester City          English Premier League          1.0
# 21      Tottenham Hotspur          English Premier League          1.0
# 28      Borussia Dortmund            German 1. Bundesliga          1.0
# 29              Liverpool          English Premier League          1.0
# 56              Liverpool          English Premier League          1.0
# ...                   ...                             ...          ...
# 18919          Derry City  Rep. Ireland Airtricity League          1.0
# 18926  Milton Keynes Dons              English League One          3.0
# 18928     Oldham Athletic              English League Two          4.0
# 18929     Oldham Athletic              English League Two          4.0
# 18930          Derry City  Rep. Ireland Airtricity League          1.0
#
#        overall  potential  ...  mentality_vision  mentality_penalties  \
# 19          88         90  ...                82                   69
# 21          88         89  ...                83                   90
# 28          87         93  ...                87                   60
# 29          87         92  ...                84                   55
# 56          86         86  ...                83                   64
# ...        ...        ...  ...               ...                  ...
# 18919       48         55  ...                43                   46
# 18926       48         48  ...                23                   19
# 18928       47         67  ...                49                   50
# 18929       47         67  ...                47                   36
# 18930       47         65  ...                43                   42
#
#       mentality_composure defending_standing_tackle  defending_sliding_tackle  \
# 19                     80                        53                        47
# 21                     91                        36                        38
# 28                     84                        41                        32
# 29                     81                        83                        79
# 56                     82                        83                        77
# ...                   ...                       ...                       ...
# 18919                  44                        12                        16
# 18926                  27                        12                        14
# 18928                  45                        11                        13
# 18929                  38                        44                        40
# 18930                  43                        43                        45
#
#        goalkeeping_diving  goalkeeping_handling goalkeeping_kicking  \
# 19                     15                    12                  12
# 21                      8                    10                  11
# 28                      7                    11                  10
# 29                     14                    15                  14
# 56                      7                    13                   7
# ...                   ...                   ...                 ...
# 18919                  12                    13                   9
# 18926                  51                    47                  43
# 18928                  11                    13                   9
# 18929                  12                    10                   9
# 18930                  13                    12                   6
#
#       goalkeeping_positioning goalkeeping_reflexes
# 19                         15                    9
# 21                         14                   11
# 28                         11                   13
# 29                          6                    7
# 56                          9                   13
# ...                       ...                  ...
# 18919                       7                    9
# 18926                      46                   48
# 18928                       9                    6
# 18929                       6                    8
# 18930                       6                   11
#
# [1685 rows x 65 columns]

# %%
print('Total number of players from England : {}'.format(eng_players_df.shape[0]))
# Out:
# Total number of players from England : 1685

# %%
clubs_df=fifa_df[['club_name',]].drop_duplicates(subset='club_name')
clubs_df
# Out:
#                  club_name
# 0             FC Barcelona
# 1                 Juventus
# 2          Atlético Madrid
# 3        FC Bayern München
# 4      Paris Saint-Germain
# ...                    ...
# 13830            Zamora FC
# 14556        Shelbourne FC
# 14994       Harrogate Town
# 15150         Waterford FC
# 15979           Finn Harps
#
# [681 rows x 1 columns]

# %% [markdown]
# ![Cover](https://thefootballlovers.com/wp-content/uploads/2020/10/famous-football-club-fans-758x379.jpg)

# %%
print('Toal Number of clubs : {}'.format(clubs_df.shape[0]))
# Out:
# Toal Number of clubs : 681

# %%
leagues_df=fifa_df[['league_name']].drop_duplicates(subset='league_name')
leagues_df
# Out:
#                                league_name
# 0                   Spain Primera Division
# 1                          Italian Serie A
# 3                     German 1. Bundesliga
# 4                           French Ligue 1
# 5                   English Premier League
# 105             Portuguese Liga ZON SAGRES
# 110                     Holland Eredivisie
# 171                USA Major League Soccer
# 172                   Chinese Super League
# 179           Saudi Abdul L. Jameel League
# 204                      Turkish Süper Lig
# 211          Campeonato Brasileiro Série A
# 255                 Russian Premier League
# 311             Argentina Primera División
# 316          Japanese J. League Division 1
# 318                        Mexican Liga MX
# 325             Belgian Jupiler Pro League
# 331               Ukrainian Premier League
# 380                      Croatian Prva HNL
# 420            English League Championship
# 599                     Greek Super League
# 623               Spanish Segunda División
# 732          Czech Republic Gambrinus Liga
# 773                     Swiss Super League
# 994                   Scottish Premiership
# 1031                        French Ligue 2
# 1108           Chilian Campeonato Nacional
# 1189          Austrian Football Bundesliga
# 1255                       Italian Serie B
# 1298            Uruguayan Primera División
# 1309                      Danish Superliga
# 1325           Paraguayan Primera División
# 1336               Colombian Liga Postobón
# 1337                  German 2. Bundesliga
# 1350           Australian Hyundai A-League
# 1352                 Norwegian Eliteserien
# 1435               UAE Arabian Gulf League
# 1711               Korean K League Classic
# 1797           Polish T-Mobile Ekstraklasa
# 1821                   Swedish Allsvenskan
# 1960                    Ecuadorian Serie A
# 1986        South African Premier Division
# 2001                       Romanian Liga I
# 3474                  German 3. Bundesliga
# 3714             Peruvian Primera División
# 3950        Rep. Ireland Airtricity League
# 3955                    English League One
# 4408                 Finnish Veikkausliiga
# 4928        Argentinian Primera B Nacional
# 5175  Liga de Fútbol Profesional Boliviano
# 7304           Venezuelan Primera División
# 7903                    English League Two

# %%
print('Total number of leauges : {}'.format(leagues_df.shape[0]))
# Out:
# Total number of leauges : 52

# %%
right_footed_players_df=fifa_df[['name','age','nationality','overall','club_name','preferred_foot']][fifa_df.preferred_foot=='Right']
right_footed_players_df
# Out:
#                     name  age nationality  overall  \
# 1      Cristiano Ronaldo   35    Portugal       92
# 2               J. Oblak   27    Slovenia       91
# 3         R. Lewandowski   31      Poland       91
# 4              Neymar Jr   28      Brazil       91
# 5           K. De Bruyne   29     Belgium       91
# ...                  ...  ...         ...      ...
# 18939          K. Angulo   24    Colombia       47
# 18940     Zhang Mengxuan   21    China PR       47
# 18941      Wang Zhenghao   20    China PR       47
# 18942        Chen Zitong   23    China PR       47
# 18943           Song Yue   28    China PR       47
#
#                                  club_name preferred_foot
# 1                                 Juventus          Right
# 2                          Atlético Madrid          Right
# 3                        FC Bayern München          Right
# 4                      Paris Saint-Germain          Right
# 5                          Manchester City          Right
# ...                                    ...            ...
# 18939                      América de Cali          Right
# 18940  Chongqing Dangdai Lifan FC SWM Team          Right
# 18941                      Tianjin TEDA FC          Right
# 18942        Shijiazhuang Ever Bright F.C.          Right
# 18943                      Tianjin TEDA FC          Right
#
# [14279 rows x 6 columns]

# %%
print(' The total number of Right-footed players are : {}'.format(right_footed_players_df.shape[0]))
# Out:
#  The total number of Right-footed players are : 14279

# %%
left_footed_players_df=fifa_df[['name','age','nationality','overall','club_name','preferred_foot']][fifa_df.preferred_foot=='Left']
left_footed_players_df
# Out:
#                name  age nationality  overall         club_name preferred_foot
# 0          L. Messi   33   Argentina       93      FC Barcelona           Left
# 11         M. Salah   28       Egypt       90         Liverpool           Left
# 12      T. Courtois   28     Belgium       89       Real Madrid           Left
# 18          Ederson   26      Brazil       88   Manchester City           Left
# 22        P. Dybala   26   Argentina       88          Juventus           Left
# ...             ...  ...         ...      ...               ...            ...
# 18891      M. Ćoćić   17      Serbia       48  TSV 1860 München           Left
# 18900    D. Aravena   19       Chile       48     CD Huachipato           Left
# 18908   R. Fontalvo   21    Colombia       48         Junior FC           Left
# 18925  Song Haiwang   25    China PR       48   Henan Jianye FC           Left
# 18933     Zhou Xiao   21    China PR       47  Dalian YiFang FC           Left
#
# [4440 rows x 6 columns]

# %%
print(' The total number of Left-footed players are : {}'.format(left_footed_players_df.shape[0]))
# Out:
#  The total number of Left-footed players are : 4440

# %%
#Let's take a random loc in fifa_df and check the data
fifa_df.loc[1224]
# Out:
# name                       Aurélio Buta
# age                                  23
# height_cm                           172
# weight_kg                            72
# nationality                    Portugal
#                                ...
# goalkeeping_diving                    9
# goalkeeping_handling                  5
# goalkeeping_kicking                  13
# goalkeeping_positioning               9
# goalkeeping_reflexes                 10
# Name: 1224, Length: 65, dtype: object

# %%
#Let's check how many players from Germany are here in the fifa_df
print('The total number of players from India in FIFA 21 is {}.'.format(fifa_df[fifa_df['nationality']=='Germany'].name.count()))
# Out:
# The total number of players from India in FIFA 21 is 1189.

# %%
print('The weightage of German players in FIFA 21 is {:.2f}% of all players'.format((fifa_df[fifa_df['nationality']=='Germany'].name.count()/fifa_df.shape[0])*100))
# Out:
# The weightage of German players in FIFA 21 is 6.35% of all players

# %%
#Top 10 positions of maxmium players
fifa_df.player_positions.value_counts().head(10)
# Out:
# CB         2408
# GK         2053
# ST         1875
# CDM, CM     811
# CM          805
# LB          764
# CM, CDM     688
# RB          650
# CDM         343
# RM          268
# Name: player_positions, dtype: int64

# %% [markdown]
# ###### Let's do some  additional operations like merging,spliting,handling null/Nan tyoe type values

# %%
ballon_df=pd.read_csv('ballon.csv')
ballon_df.isna().sum().sum()
# Out:
# 1105

# %% [markdown]
# We can see that in this ballon_df dataframe there are total 1105 values are either not given or null values.<br>
# So, lets replace those values with 0.

# %%
ballon_df=ballon_df.fillna(value=0)
ballon_df
# Out:
#       Year  Rank              Player               Club   Nationality
# 0     1956     1    Stanley Matthews          Blackpool       England
# 1     1956     2  Alfredo Di Stéfano     Real Madrid CF         Spain
# 2     1956     3        Raymond Kopa     Real Madrid CF        France
# 3     1956     4       Ferenc Puskás             Honvéd       Hungary
# 4     1956     5          Lev Yashin      Dynamo Moskva  Soviet Union
# ...    ...   ...                 ...                ...           ...
# 1775  2018    25     Mario Mandžukić           Juventus       Croatia
# 1776  2018    25           Jan Oblak    Atlético Madrid      Slovenia
# 1777  2018    28         Diego Godín    Atlético Madrid       Uruguay
# 1778  2018    50                Isco     Real Madrid CF         Spain
# 1779  2018    50         Hugo Lloris  Tottenham Hotspur        France
#
# [1780 rows x 5 columns]

# %%
ballon_df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# We only take some columns which are mostly needed for our future analysis.<br>
# We can drop the rest columns which are not needed.

# %%
ballon_df=ballon_df[['Year','Rank','Player','Club','Nationality']]
ballon_df
# Out:
#       Year  Rank              Player               Club   Nationality
# 0     1956     1    Stanley Matthews          Blackpool       England
# 1     1956     2  Alfredo Di Stéfano     Real Madrid CF         Spain
# 2     1956     3        Raymond Kopa     Real Madrid CF        France
# 3     1956     4       Ferenc Puskás             Honvéd       Hungary
# 4     1956     5          Lev Yashin      Dynamo Moskva  Soviet Union
# ...    ...   ...                 ...                ...           ...
# 1775  2018    25     Mario Mandžukić           Juventus       Croatia
# 1776  2018    25           Jan Oblak    Atlético Madrid      Slovenia
# 1777  2018    28         Diego Godín    Atlético Madrid       Uruguay
# 1778  2018    50                Isco     Real Madrid CF         Spain
# 1779  2018    50         Hugo Lloris  Tottenham Hotspur        France
#
# [1780 rows x 5 columns]

# %%
ballon_df.info
# Out:
# <bound method DataFrame.info of       Year  Rank              Player               Club   Nationality
# 0     1956     1    Stanley Matthews          Blackpool       England
# 1     1956     2  Alfredo Di Stéfano     Real Madrid CF         Spain
# 2     1956     3        Raymond Kopa     Real Madrid CF        France
# 3     1956     4       Ferenc Puskás             Honvéd       Hungary
# 4     1956     5          Lev Yashin      Dynamo Moskva  Soviet Union
# ...    ...   ...                 ...                ...           ...
# 1775  2018    25     Mario Mandžukić           Juventus       Croatia
# 1776  2018    25           Jan Oblak    Atlético Madrid      Slovenia
# 1777  2018    28         Diego Godín    Atlético Madrid       Uruguay
# 1778  2018    50                Isco     Real Madrid CF         Spain
# 1779  2018    50         Hugo Lloris  Tottenham Hotspur        France
#
# [1780 rows x 5 columns]>

# %%
won_df=ballon_df[ballon_df.Rank==1]
#I have appended 2019 value row as the df only consists upto 2018
df=pd.DataFrame({'Year':2019,'Rank':[1],'Player':['Lionel Messi'],'Club':['Barcelona'],'Nationality':['Argentina']})
won_df=won_df.append(df,ignore_index=True)
won_df
# Out:
#     Year  Rank                  Player            Club Nationality
# 0   1956     1        Stanley Matthews       Blackpool     England
# 1   1957     1      Alfredo Di Stéfano  Real Madrid CF       Spain
# 2   1958     1            Raymond Kopa  Real Madrid CF      France
# 3   1959     1      Alfredo Di Stéfano  Real Madrid CF       Spain
# 4   1960     1  Luis Suárez Miramontes    FC Barcelona       Spain
# ..   ...   ...                     ...             ...         ...
# 59  2015     1            Lionel Messi    FC Barcelona   Argentina
# 60  2016     1       Cristiano Ronaldo  Real Madrid CF    Portugal
# 61  2017     1       Cristiano Ronaldo  Real Madrid CF    Portugal
# 62  2018     1             Luka Modrić  Real Madrid CF     Croatia
# 63  2019     1            Lionel Messi       Barcelona   Argentina
#
# [64 rows x 5 columns]

# %% [markdown]
# For Ballon d'OR Source - <a href="https://en.wikipedia.org/wiki/Ballon_d%27Or">Click</a>

# %% [markdown]
# Total out of 1780, only 64 players have won the Ballon D'OR in FIFA history.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "sourajyotipdfghosh/zerotopandas-course-project-starter" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/sourajyotipdfghosh/zerotopandas-course-project-starter
# 'https://jovian.ai/sourajyotipdfghosh/zerotopandas-course-project-starter'

# %% [markdown]
# # Exploratory Analysis and Visualization

# %% [markdown]
# > EXPLORATIONS ACHIEVED USING THE FIFA 21 DATA :-
# >
# > - <i>Clustering players by Overall and Potential rating</i>
# > - <i>Players Overall vs Potential Rating Distribution</i>
# > - <i>Clustering players by Nationaity</i>
# > - <i>Top 20 Countries With Maximum Number of Players in FIFA 21</i>
# > - <i>Clustering players by International Reputation</i>
# > - <i>Representation of The Distribution of International Reputation of Players in FIFA 21</i>
# > - <i>Each Different Playing Positions Distribution Among Players in FIFA 21 </i>
# > - <i>Plotting Players With Different Playing Positions</i>
# > - <i>Top 10 Players in Each Different Playing Positions</i>
#      <ol> <i>Top 10 Goalkeepers in FIFA 21</i> </ol>
#      <ol> <i> Top 10 Strickers in FIFA 21</i></ol>
#      <ol><i>Top 10 Center Backs in FIFA 21</i> </ol>
#      <ol><i>Top 10 Left Wings in FIFA 21</i></ol>
#      <ol><i>Top 10 Right Wings in FIFA 21</i></ol>
#      <ol><i>Top 10 Center Defensive Midfielders in FIFA 21</i></ol>
#      <ol><i>Top 10 Center Midfielders in FIFA 21</i></ol>
#      <ol><i>Top 10 RIght Backs in FIFA 21</i></ol>
#      <ol><i>Top 10 Left Backs in FIFA 21</i></ol>
#      <ol><i>Top 10 Center Forwards in FIFA 21</i></ol>
#      <ol><i>Top 10 Left Midfielders in FIFA 21</i></ol>
#      <ol><i>Top 10 Right Midfielders in FIFA 21</i></ol>
#      <ol><i>Top 10 Left Wing Backs in FIFA 21</i></ol>
#      <ol><i>Top 10 Center Attacking Midfielders in FIFA 21</i></ol>
#      <ol><i>Top 10 Right Wing Backs in FIFA 21</i></ol>
# > - <i>Top 10 Heaviest Players in FIFA 21</i>
# > - <i>Top 10 Hardworking Players in FIFA 21</i>
# > - <i>Football Leagues vs Players Frequency FIFA 21</i>
# > - <i>Top 10 Shooters in FIFA 21</i>
# > - <i>Top 10 Fastest Players in FIFA 21</i>
# > - <i>Count Plotting Players on Basis of Their Heights</i>
# > - <i>Finding Out Players with Maximum Wage in FIFA 21(in euro)</i>
# > - <i>Top 10 Players with Maximum Wage in FIFA 21(in euro)</i></ol>
# > - <i>Finding Out Players With Maximum Value Package</i>
# > - <i>Top 10 Players With Maximum Wage in FIFA 21</i></ol>
# > - <i>Finding Out Players With Maximum Value(in euro)</i>
# > - <i>Top 10 Valuable Players in FIFA 21</i>
# > - <i>Distributions of Players In Different Age Groups</i>
# > _ <i>Players Overall and Potential Rating vs Age in FIFA 21</i>
# > - <i>Top 15 Players Key Performance Indication</i>
# > - <i>Distributions of players mentality aggression,positioning and vision</i>

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline 
import seaborn as sns
sns.set_style("darkgrid")
#matplotlib.rcParams['font.size'] = 14
#matplotlib.rcParams['figure.figsize'] = (20, 10)
#matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ###  Clustering Players by Overall and Potential Rating

# %%
player_highest_overall_df=fifa_df[['name','overall','potential','age','nationality','club_name','preferred_foot']].copy()
player_highest_overall_df=player_highest_overall_df.sort_values('overall',ascending=False)
player_highest_overall_df
# Out:
#                     name  overall  potential  age nationality  \
# 0               L. Messi       93         93   33   Argentina
# 1      Cristiano Ronaldo       92         92   35    Portugal
# 2               J. Oblak       91         93   27    Slovenia
# 3         R. Lewandowski       91         91   31      Poland
# 4              Neymar Jr       91         91   28      Brazil
# ...                  ...      ...        ...  ...         ...
# 18932        F. Cárdenas       47         62   19     Bolivia
# 18930        R. McKinley       47         65   18     England
# 18929           B. Hough       47         67   17     England
# 18928        V. Da Silva       47         67   17     England
# 18943           Song Yue       47         47   28    China PR
#
#                  club_name preferred_foot
# 0             FC Barcelona           Left
# 1                 Juventus          Right
# 2          Atlético Madrid          Right
# 3        FC Bayern München          Right
# 4      Paris Saint-Germain          Right
# ...                    ...            ...
# 18932         Club Bolívar          Right
# 18930           Derry City          Right
# 18929      Oldham Athletic          Right
# 18928      Oldham Athletic          Right
# 18943      Tianjin TEDA FC          Right
#
# [18719 rows x 7 columns]

# %%
#Top 10 players with highest overall rating
top_10_overall_df=player_highest_overall_df.head(10)
top_10_overall_df
# Out:
#                  name  overall  potential  age  nationality  \
# 0            L. Messi       93         93   33    Argentina
# 1   Cristiano Ronaldo       92         92   35     Portugal
# 2            J. Oblak       91         93   27     Slovenia
# 3      R. Lewandowski       91         91   31       Poland
# 4           Neymar Jr       91         91   28       Brazil
# 5        K. De Bruyne       91         91   29      Belgium
# 9             Alisson       90         91   27       Brazil
# 10            S. Mané       90         90   28      Senegal
# 11           M. Salah       90         90   28        Egypt
# 8         V. van Dijk       90         91   28  Netherlands
#
#               club_name preferred_foot
# 0          FC Barcelona           Left
# 1              Juventus          Right
# 2       Atlético Madrid          Right
# 3     FC Bayern München          Right
# 4   Paris Saint-Germain          Right
# 5       Manchester City          Right
# 9             Liverpool          Right
# 10            Liverpool          Right
# 11            Liverpool           Left
# 8             Liverpool          Right

# %%
player_highest_potential_df=fifa_df[['name','potential','overall','age','nationality','club_name','preferred_foot']].copy()
player_highest_potential_df=player_highest_potential_df.sort_values('potential',ascending=False)
player_highest_potential_df
# Out:
#                name  potential  overall  age       nationality  \
# 6         K. Mbappé         95       90   21            France
# 0          L. Messi         93       93   33         Argentina
# 366    Vinícius Jr.         93       80   19            Brazil
# 2          J. Oblak         93       91   27          Slovenia
# 272      João Félix         93       81   20          Portugal
# ...             ...        ...      ...  ...               ...
# 18817      A. Foley         50       50   30  Northern Ireland
# 18884     Gao Xiang         49       49   31          China PR
# 18927  Wang Jianwen         48       48   32          China PR
# 18926     L. Walker         48       48   30           England
# 18943      Song Yue         47       47   28          China PR
#
#                    club_name preferred_foot
# 6        Paris Saint-Germain          Right
# 0               FC Barcelona           Left
# 366              Real Madrid          Right
# 2            Atlético Madrid          Right
# 272          Atlético Madrid          Right
# ...                      ...            ...
# 18817             Finn Harps          Right
# 18884  Qingdao Huanghai F.C.          Right
# 18927  Qingdao Huanghai F.C.          Right
# 18926     Milton Keynes Dons          Right
# 18943        Tianjin TEDA FC          Right
#
# [18719 rows x 7 columns]

# %%
##Top 10 players with highest potential rating
top_10_potential_df=player_highest_potential_df.head(10)
top_10_potential_df
# Out:
#               name  potential  overall  age  nationality            club_name  \
# 6        K. Mbappé         95       90   21       France  Paris Saint-Germain
# 0         L. Messi         93       93   33    Argentina         FC Barcelona
# 366   Vinícius Jr.         93       80   19       Brazil          Real Madrid
# 2         J. Oblak         93       91   27     Slovenia      Atlético Madrid
# 272     João Félix         93       81   20     Portugal      Atlético Madrid
# 7    M. ter Stegen         93       90   28      Germany         FC Barcelona
# 28       J. Sancho         93       87   20      England    Borussia Dortmund
# 62      K. Havertz         93       85   21      Germany              Chelsea
# 64      M. de Ligt         92       85   20  Netherlands             Juventus
# 99      E. Haaland         92       84   19       Norway    Borussia Dortmund
#
#     preferred_foot
# 6            Right
# 0             Left
# 366          Right
# 2            Right
# 272          Right
# 7            Right
# 28           Right
# 62            Left
# 64           Right
# 99            Left

# %%
#Top 10 players with potential rating + Top 10 players with overall rating
top_10_combined_df=pd.concat([top_10_potential_df,top_10_overall_df], axis=0)
top_10_combined_df=top_10_combined_df.drop_duplicates(subset='name')
combined_df=top_10_combined_df.groupby('name')[['overall','potential']].max()
combined_df=combined_df.sort_values('overall',ascending=True)
combined_df
# Out:
#                    overall  potential
# name
# Vinícius Jr.            80         93
# João Félix              81         93
# E. Haaland              84         92
# M. de Ligt              85         92
# K. Havertz              85         93
# J. Sancho               87         93
# S. Mané                 90         90
# M. ter Stegen           90         93
# M. Salah                90         90
# Alisson                 90         91
# V. van Dijk             90         91
# K. Mbappé               90         95
# K. De Bruyne            91         91
# J. Oblak                91         93
# Neymar Jr               91         91
# R. Lewandowski          91         91
# Cristiano Ronaldo       92         92
# L. Messi                93         93

# %% [markdown]
# ### Bar chart of players with potential and overall rating

# %%
combined_df.plot(kind='barh',figsize=(15,10))
plt.title('Overall Rating vs Potential Rating ',fontsize=25)
plt.xlim(0,110,10)
plt.xlabel('Name')
plt.ylabel('Rating')
plt.legend();

# %% [markdown]
# From the barplot what can be observed is that some players have same potential and overall.It means those players are performing as they are expected to be.But the players who has more potential rating than their overall it means they can perform far way better than their overall in future.

# %% [markdown]
# ### Players Overall and Potential Rating Distribution

# %%
plt.figure(figsize=(10,5))
plt.hist([fifa_df.overall,fifa_df.potential],color=['blue','black'],alpha=0.4,stacked=True)
plt.title('Players Overall and Potential Rating Distribution',fontsize=20)
plt.xlabel('Rating',fontsize=20)
plt.ylabel('Players Frequency',fontsize=20)
plt.legend(['overall','potential'],fontsize=20);

# %% [markdown]
# It is clearly shown that in each rating point, potential rating of players are more higher than overall rating.The observation is very simple, players in that rating points are not showing their 100% but in future they can perform better from their previous.

# %% [markdown]
# ### Clustering players By Nationality

# %%
#Players number counts country wise
country_count_df=fifa_df['nationality'].value_counts()
country_count_df
# Out:
# England          1685
# Germany          1189
# Spain            1072
# France            984
# Argentina         936
#                  ...
# Puerto Rico         1
# New Caledonia       1
# Bermuda             1
# Chad                1
# Nicaragua           1
# Name: nationality, Length: 161, dtype: int64

# %% [markdown]
# It shows each country has how many players in FIFA 21.<br>
# Looks like England has the maximum number of players in FIFA 21.

# %% [markdown]
# ### Top 20 Countries With Maximum Number of Players in FIFA 21

# %%
#Let's plot Top 20 countries with maximum number of players in FIFA 21
country_df=pd.DataFrame(country_count_df.head(20))
country_df.sort_values('nationality',ascending=True).plot(kind='barh',figsize=(15,10),color='lightgreen')
plt.title('Top 20 Countries With Maximum Number of Players in FIFA 21',fontsize=25)
plt.ylabel('Countries',fontsize=20)
plt.xlabel('Number of Players',fontsize=20)
plt.legend(['Number of Players']);

# %% [markdown]
# Plot shows that England,Germany and Spain are the 3 only countries which has more than 1000 players in FIFA 21.

# %% [markdown]
# ### Clustering players by International Reputation

# %%
rep_df=fifa_df[['name','international_reputation']].sort_values('international_reputation',ascending=False)
rep_df
# Out:
#                     name  international_reputation
# 0               L. Messi                         5
# 1      Cristiano Ronaldo                         5
# 168       Z. Ibrahimović                         5
# 16              M. Neuer                         5
# 37             L. Suárez                         5
# ...                  ...                       ...
# 7232         Y. Takahagi                         1
# 7233          M. Johnson                         1
# 7234        Chi Zhongguo                         1
# 7235           L. Azcona                         1
# 18943           Song Yue                         1
#
# [18719 rows x 2 columns]

# %%
#Top 10 players with respect to their international reputation
rep_df.head(10)
# Out:
#                   name  international_reputation
# 0             L. Messi                         5
# 1    Cristiano Ronaldo                         5
# 168     Z. Ibrahimović                         5
# 16            M. Neuer                         5
# 37           L. Suárez                         5
# 4            Neymar Jr                         5
# 459               Hulk                         4
# 55          M. Hummels                         4
# 449        Diego Costa                         4
# 132           D. Alaba                         4

# %% [markdown]
# So, we can see that only 6 players are on the top with maximum international reputation value of 5.<br>

# %% [markdown]
# ### Representation of The Distribution of International Reputation of Players in FIFA 21

# %%
#Plotting a pie chart to represent the distribution of international reputation of players in FIFA 21
labels=['1','2','3','4','5']
sizes=fifa_df['international_reputation'].value_counts()
colors=['green','blue','yellow','red','black']
explode=[0.1,0.1,0.2,0.5,0.9]
plt.rcParams['figure.figsize']=(10,10)
plt.pie(sizes,labels=labels,colors=colors,explode=explode,shadow=True)
plt.title('International Reputation of The Players in FIFA 21',fontsize=20)
plt.legend()
plt.show()

# %%
v=fifa_df['international_reputation'].value_counts()
print('Out of all players, {:.2f}% players have international reputation of 1 in FIFA 21'.format(v.iloc[0]/fifa_df.shape[0]*100))
# Out:
# Out of all players, 92.88% players have international reputation of 1 in FIFA 21

# %% [markdown]
# ### Each Different Playing Positions Distribution  in FIFA 21

# %%
#printing total different positions
c=0
for i in fifa_df.player_positions.unique():
    if ',' not in i:
        print(i)
        c+=1
print('\n\nTotal {} different playing positions.'.format(c))
# Out:
# GK
# ST
# CB
# LW
# RW
# CDM
# CM
# RB
# LB
# CF
# LM
# RM
# LWB
# CAM
# RWB
#
#
# Total 15 different playing positions.

# %%
#Taking each different position players in each seperate dataframes
plis=[fifa_df[fifa_df.player_positions.str[-2:]=='GK'].value_counts().sum(),
fifa_df[fifa_df.player_positions.str[-2:]=='ST'].value_counts().sum(),
fifa_df[fifa_df.player_positions.str[-2:]=='CB'].value_counts().sum(),
fifa_df[fifa_df.player_positions.str[-2:]=='LW'].value_counts().sum(),
fifa_df[fifa_df.player_positions.str[-2:]=='RW'].value_counts().sum(),
fifa_df[fifa_df.player_positions.str[-3:]=='CDM'].value_counts().sum(),
fifa_df[fifa_df.player_positions.str[-2:]=='CM'].value_counts().sum(),
fifa_df[fifa_df.player_positions.str[-2:]=='RB'].value_counts().sum(),
fifa_df[fifa_df.player_positions.str[-2:]=='LB'].value_counts().sum(),
fifa_df[fifa_df.player_positions.str[-2:]=='CF'].value_counts().sum(),
fifa_df[fifa_df.player_positions.str[-2:]=='LM'].value_counts().sum(),
fifa_df[fifa_df.player_positions.str[-2:]=='RM'].value_counts().sum(),
fifa_df[fifa_df.player_positions.str[-3:]=='LWB'].value_counts().sum(),
fifa_df[fifa_df.player_positions.str[-3:]=='CAM'].value_counts().sum(),
fifa_df[fifa_df.player_positions.str[-3:]=='RWB'].value_counts().sum()]

# %%
#Storing plis list values in a dictionary
c=0
dic={}
for i in fifa_df.player_positions.unique():
    if ',' not in i:
        dic[i]=plis[c]
        c+=1
dic
# Out:
# {'GK': 2053,
#  'ST': 2415,
#  'CB': 2879,
#  'LW': 574,
#  'RW': 574,
#  'CDM': 1440,
#  'CM': 2186,
#  'RB': 1194,
#  'LB': 1329,
#  'CF': 187,
#  'LM': 1212,
#  'RM': 1225,
#  'LWB': 198,
#  'CAM': 1063,
#  'RWB': 190}

# %% [markdown]
# ## Plotting Number of Players With Different Playing Positions

# %%
keys=dic.keys()
values=dic.values()
plt.figure(figsize=(20,15))
plt.xlabel('Playing Positions',fontsize=20)
plt.ylabel('Number of Players',fontsize=20)
plt.title('Each Playing Positions of Players In FIFA 21',fontsize=25)
plt.bar(keys,values,color='y')
plt.show()
#Let's plot each playing positions of Players in FIFA 21

# %% [markdown]
# From the  plot we can easily analyze that CM,CB,ST and GK are the only 4 positions which are mostly acquired by the players of FIFA 21.<br>
# CB is the most played position with more than 2500 players in FIFA 21.

# %% [markdown]
# ## Top 10 Players In Each Different Playing Positions in FIFA 21

# %% [markdown]
# ### Top 10 Goalkeepers in FIFA 21

# %% [markdown]
# ![Cover](https://cdn-wp.thesportsrush.com/2020/09/Untitled-design-11.jpg)

# %%
#Top 10 goalkeepers in FIFA 21
gk_df=fifa_df[fifa_df.player_positions.str[-2:]=='GK'][['name','nationality','club_name','height_cm','player_positions','overall','potential']]
gk_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#              name nationality            club_name  height_cm  \
# 2        J. Oblak    Slovenia      Atlético Madrid        188
# 7   M. ter Stegen     Germany         FC Barcelona        187
# 9         Alisson      Brazil            Liverpool        191
# 12    T. Courtois     Belgium          Real Madrid        199
# 16       M. Neuer     Germany    FC Bayern München        193
# 18        Ederson      Brazil      Manchester City        188
# 23  S. Handanovič    Slovenia                Inter        193
# 36      H. Lloris      France    Tottenham Hotspur        188
# 40    W. Szczęsny      Poland             Juventus        195
# 44       K. Navas  Costa Rica  Paris Saint-Germain        185
#
#    player_positions  overall  potential
# 2                GK       91         93
# 7                GK       90         93
# 9                GK       90         91
# 12               GK       89         90
# 16               GK       89         89
# 18               GK       88         91
# 23               GK       88         88
# 36               GK       87         87
# 40               GK       87         87
# 44               GK       87         87

# %% [markdown]
# ### Top 10 Strickers in FIFA 21

# %% [markdown]
# ![cover](https://www.teahub.io/photos/full/222-2225805_robert-lewandowski-bayern-munich-fc-polish-football-robert.jpg)

# %%
#Top 10 Strickers in FIFA 21
st_df=fifa_df[fifa_df.player_positions.str[-2:]=='ST'][['name','nationality','club_name','height_cm','player_positions','overall','potential']]
st_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#               name nationality          club_name  height_cm player_positions  \
# 3   R. Lewandowski      Poland  FC Bayern München        184               ST
# 13       S. Agüero   Argentina    Manchester City        173               ST
# 15      K. Benzema      France        Real Madrid        185           CF, ST
# 21         H. Kane     England  Tottenham Hotspur        188               ST
# 25       E. Hazard     Belgium        Real Madrid        175           LW, ST
# 37       L. Suárez     Uruguay       FC Barcelona        182               ST
# 43     C. Immobile       Italy              Lazio        185               ST
# 51        A. Gómez   Argentina           Atalanta        167      CAM, CF, ST
# 61        J. Vardy     England     Leicester City        179               ST
# 65     M. Rashford     England  Manchester United        186           LM, ST
#
#     overall  potential
# 3        91         91
# 13       89         89
# 15       89         89
# 21       88         89
# 25       88         88
# 37       87         87
# 43       87         87
# 51       86         86
# 61       86         86
# 65       85         91

# %% [markdown]
# So,Bayern Munich front man **Robert Lewandowski** is best rated stricker in FIFA 21 (in overall and potential).

# %% [markdown]
# ### Top 10 Centre Backs in FIFA 21

# %% [markdown]
# ![cover](https://images7.alphacoders.com/978/thumb-1920-978775.jpg)

# %%
#Top 10 Centre Backs in FIFA 21
cb_df=fifa_df[fifa_df.player_positions.str[-2:]=='CB'][['name','nationality','club_name','height_cm','player_positions','overall','potential']]
cb_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#             name  nationality          club_name  height_cm player_positions  \
# 8    V. van Dijk  Netherlands          Liverpool        193               CB
# 14  Sergio Ramos        Spain        Real Madrid        184               CB
# 26  K. Koulibaly      Senegal             Napoli        187               CB
# 31    A. Laporte       France    Manchester City        189               CB
# 35  G. Chiellini        Italy           Juventus        187               CB
# 48     R. Varane       France        Real Madrid        191               CB
# 52         Piqué        Spain       FC Barcelona        194               CB
# 55    M. Hummels      Germany  Borussia Dortmund        191               CB
# 64    M. de Ligt  Netherlands           Juventus        189               CB
# 69    C. Lenglet       France       FC Barcelona        186               CB
#
#     overall  potential
# 8        90         91
# 14       89         89
# 26       88         88
# 31       87         90
# 35       87         87
# 48       86         88
# 52       86         86
# 55       86         86
# 64       85         92
# 69       85         89

# %% [markdown]
# **V. van Dijk** is the best Centre Back in FIFA 21.

# %% [markdown]
# ### Top 10 Left Wing Players in FIFA 21

# %% [markdown]
# <img src="https://pbs.twimg.com/media/EyCdMieXIAI1C0v.jpg" width="1000" align="center">

# %%
#Top 10 Left Wings in FIFA 21
lw_df=fifa_df[fifa_df.player_positions.str[-2:]=='LW'][['name','nationality','club_name','height_cm','player_positions','overall','potential']]
lw_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#                   name nationality            club_name  height_cm  \
# 1    Cristiano Ronaldo    Portugal             Juventus        187
# 10             S. Mané     Senegal            Liverpool        175
# 39         A. Di María   Argentina  Paris Saint-Germain        180
# 41       P. Aubameyang       Gabon              Arsenal        187
# 45        A. Griezmann      France         FC Barcelona        176
# 108           K. Coman      France    FC Bayern München        179
# 128      Douglas Costa      Brazil             Juventus        172
# 133               Isco       Spain          Real Madrid        176
# 187              Oscar      Brazil     Shanghai SIPG FC        179
# 235         L. Ocampos   Argentina           Sevilla FC        188
#
#     player_positions  overall  potential
# 1             ST, LW       92         92
# 10                LW       90         90
# 39            RW, LW       87         87
# 41            ST, LW       87         87
# 45        ST, CF, LW       87         87
# 108       LM, RM, LW       84         88
# 128       LM, RW, LW       84         84
# 133      CAM, CM, LW       84         84
# 187      CAM, CM, LW       83         83
# 235           RW, LW       82         83

# %% [markdown]
# **Cristiano Ronaldo** is one of the greatest players ever to have lived - of course he's the best left winger ever.<br>

# %% [markdown]
# ### Top 10 Right Wingers in FIFA 21

# %% [markdown]
# ![cover](https://phantom-marca.unidadeditorial.es/245d20ac000035cfd4064c6480420d09/crop/535x70/1523x625/resize/1320/f/jpg/assets/multimedia/imagenes/2021/09/01/16304948646356.jpg)

# %%
#Top 10 Right Wings in FIFA 21
rw_df=fifa_df[fifa_df.player_positions.str[-2:]=='RW'][['name','nationality','club_name','height_cm','player_positions','overall','potential']]
rw_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#             name nationality            club_name  height_cm player_positions  \
# 6      K. Mbappé      France  Paris Saint-Germain        178       ST, LW, RW
# 11      M. Salah       Egypt            Liverpool        175               RW
# 19   R. Sterling     England      Manchester City        170           LW, RW
# 58     T. Müller     Germany    FC Bayern München        186      CAM, RM, RW
# 76     S. Gnabry     Germany    FC Bayern München        175       RM, LM, RW
# 81     H. Ziyech     Morocco              Chelsea        181          CAM, RW
# 101    Oyarzabal       Spain        Real Sociedad        181           LW, RW
# 129   Iago Aspas       Spain             RC Celta        176           ST, RW
# 142   O. Dembélé      France         FC Barcelona        178           LW, RW
# 176      G. Bale       Wales    Tottenham Hotspur        185               RW
#
#      overall  potential
# 6         90         95
# 11        90         90
# 19        88         90
# 58        86         86
# 76        85         87
# 81        85         86
# 101       84         90
# 129       84         84
# 142       83         89
# 176       83         83

# %% [markdown]
# **K. Mbappé** is on the top in rw_df on the basis of overall and potential rating.

# %% [markdown]
# ### Top 10 Center Defensive Midfielder in FIFA 21

# %% [markdown]
# ![cover](https://wallpaperaccess.com/full/4106975.jpg)

# %%
#Top 10 cdm in FIFA 21
cdm_df=fifa_df[fifa_df.player_positions.str[-3:]=='CDM'][['name','nationality','club_name','height_cm','player_positions','overall','potential']]
cdm_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#                 name         nationality            club_name  height_cm  \
# 17          Casemiro              Brazil          Real Madrid        185
# 32           Fabinho              Brazil            Liverpool        188
# 42   Sergio Busquets               Spain         FC Barcelona        189
# 49          P. Pogba              France    Manchester United        191
# 50       M. Verratti               Italy  Paris Saint-Germain        165
# 68        Marquinhos              Brazil  Paris Saint-Germain        183
# 84         M. Pjanić  Bosnia Herzegovina         FC Barcelona        178
# 92            Thiago               Spain            Liverpool        174
# 104      L. Goretzka             Germany    FC Bayern München        189
# 120      Fernandinho              Brazil      Manchester City        179
#
#     player_positions  overall  potential
# 17               CDM       89         89
# 32               CDM       87         89
# 42               CDM       87         87
# 49           CM, CDM       86         87
# 50           CM, CDM       86         87
# 68           CB, CDM       85         89
# 84           CM, CDM       85         85
# 92           CM, CDM       85         85
# 104          CM, CDM       84         88
# 120          CB, CDM       84         84

# %% [markdown]
# **Casemiro** seems to be the best center defensive midfielder in FIFA 21.

# %% [markdown]
# ### Top 10 Center Midfielder in FIFA 21

# %% [markdown]
# ![cover](https://wallpaperaccess.com/full/1785691.jpg)

# %%
#Top 10 cm in FIFA 21
cm_df=fifa_df[fifa_df.player_positions.str[-2:]=='CM'][['name','nationality','club_name','height_cm','player_positions','overall','potential']]
cm_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#                name  nationality          club_name  height_cm  \
# 5      K. De Bruyne      Belgium    Manchester City        181
# 24         T. Kroos      Germany        Real Madrid        183
# 27         N. Kanté       France            Chelsea        168
# 30  Bruno Fernandes     Portugal  Manchester United        179
# 34   Bernardo Silva     Portugal    Manchester City        173
# 38        L. Modrić      Croatia        Real Madrid        172
# 53      David Silva        Spain      Real Sociedad        173
# 56     J. Henderson      England          Liverpool        182
# 67       F. de Jong  Netherlands       FC Barcelona        180
# 74            Rodri        Spain    Manchester City        191
#
#    player_positions  overall  potential
# 5           CAM, CM       91         91
# 24               CM       88         88
# 27          CDM, CM       88         88
# 30          CAM, CM       87         90
# 34      RW, CAM, CM       87         88
# 38               CM       87         87
# 53          CAM, CM       86         86
# 56          CDM, CM       86         86
# 67               CM       85         90
# 74          CDM, CM       85         88

# %% [markdown]
# **K. De Bruyne** is the best center midfielder (also plays CAM)with overall and potential rating of 91.

# %% [markdown]
# ### Top 10 Right Backs in FIFA 21

# %% [markdown]
# ![cover](https://wallpaperaccess.com/full/2983159.jpg)

# %%
#Top 10 RB in FIFA 21
rb_df=fifa_df[fifa_df.player_positions.str[-2:]=='RB'][['name','nationality','club_name','height_cm','player_positions','overall','potential']]
rb_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#                     name nationality          club_name  height_cm  \
# 20            J. Kimmich     Germany  FC Bayern München        176
# 29   T. Alexander-Arnold     England          Liverpool        180
# 60              Carvajal       Spain        Real Madrid        173
# 77       Ricardo Pereira    Portugal     Leicester City        175
# 91             K. Walker     England    Manchester City        183
# 130            J. Corona      Mexico           FC Porto        173
# 158         João Cancelo    Portugal    Manchester City        182
# 159        Nélson Semedo    Portugal       FC Barcelona        177
# 184          K. Trippier     England    Atlético Madrid        173
# 221            K. Laimer     Austria         RB Leipzig        180
#
#     player_positions  overall  potential
# 20           CDM, RB       88         90
# 29                RB       87         92
# 60                RB       86         86
# 77                RB       85         87
# 91                RB       85         85
# 130           RM, RB       84         84
# 158               RB       83         86
# 159               RB       83         86
# 184               RB       83         83
# 221      CDM, CM, RB       82         86

# %% [markdown]
# **J. Kimmich** is the best right back but he also plays as center defensive midfielder in FIFA 21.

# %% [markdown]
# ### Top 10 Left Backs in FIFA 21

# %% [markdown]
# ![cover](https://files.oyebesmartest.com/uploads/preview/scrape-wp5515691btenx1ca.jpeg)

# %%
#Top 10 LB in FIFA 21
lb_df=fifa_df[fifa_df.player_positions.str[-2:]=='LB'][['name','nationality','club_name','height_cm','player_positions','overall','potential']]
lb_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#               name nationality          club_name  height_cm player_positions  \
# 33    A. Robertson    Scotland          Liverpool        178               LB
# 57      Jordi Alba       Spain       FC Barcelona        170               LB
# 105       Grimaldo       Spain         SL Benfica        171               LB
# 112           Saúl       Spain    Atlético Madrid        184       CM, LM, LB
# 115       L. Digne      France            Everton        178               LB
# 118    Alex Telles      Brazil           FC Porto        181               LB
# 127    Azpilicueta       Spain            Chelsea        178           RB, LB
# 132       D. Alaba     Austria  FC Bayern München        180           CB, LB
# 139  N. Tagliafico   Argentina               Ajax        172               LB
# 143           Gayà       Spain        Valencia CF        172               LB
#
#      overall  potential
# 33        87         89
# 57        86         86
# 105       84         88
# 112       84         87
# 115       84         85
# 118       84         85
# 127       84         84
# 132       84         84
# 139       84         84
# 143       83         88

# %% [markdown]
# **A. Robertson** of Scotland is the top rated Left Back in FIFA 21.

# %% [markdown]
# ### Top 10 Center Forwards in FIFA 21

# %% [markdown]
# ![cover](https://wallpapers-hub.art/wallpaper-images/781192.jpg)

# %%
#Top 10 CF in FIFA 21
cf_df=fifa_df[fifa_df.player_positions.str[-2:]=='CF'][['name','nationality','club_name','height_cm','player_positions','overall','potential']]
cf_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#                 name     nationality          club_name  height_cm  \
# 0           L. Messi       Argentina       FC Barcelona        170
# 46            H. Son  Korea Republic  Tottenham Hotspur        183
# 47   Roberto Firmino          Brazil          Liverpool        181
# 62        K. Havertz         Germany            Chelsea        188
# 79      Luis Alberto           Spain              Lazio        183
# 90           M. Reus         Germany  Borussia Dortmund        180
# 97        L. Insigne           Italy             Napoli        163
# 178    R. Nainggolan         Belgium              Inter        176
# 194          W. Zaha     Ivory Coast     Crystal Palace        180
# 200      Lucas Moura          Brazil  Tottenham Hotspur        174
#
#     player_positions  overall  potential
# 0         RW, ST, CF       93         93
# 46            LM, CF       87         87
# 47                CF       87         87
# 62       CAM, RM, CF       85         93
# 79       CAM, CM, CF       85         86
# 90           CAM, CF       85         85
# 97            LW, CF       85         85
# 178      CAM, CM, CF       83         83
# 194           LM, CF       83         83
# 200           RM, CF       83         83

# %% [markdown]
# So, **L. Messi** is the best center forward with highest overall and potential rating of 93.

# %% [markdown]
# ### Top 10 Left Midfielders in FIFA 21

# %% [markdown]
# ![cover](https://e0.365dm.com/20/07/1600x900/skysports-leroy-sane-bayern-munich_5028899.jpg?20200703094025)

# %%
#Top 10 LM in FIFA 21
lm_df=fifa_df[fifa_df.player_positions.str[-2:]=='LM'][['name','nationality','club_name','height_cm','player_positions','overall','potential']]
lm_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#                name nationality                club_name  height_cm  \
# 66          L. Sané     Germany        FC Bayern München        183
# 95      Alex Sandro      Brazil                 Juventus        180
# 96             Koke       Spain          Atlético Madrid        176
# 166     Juan Bernat       Spain      Paris Saint-Germain        170
# 172  Renato Augusto      Brazil  Beijing Sinobo Guoan FC        186
# 210        M. Acuña   Argentina               Sevilla FC        172
# 212        Reguilón       Spain        Tottenham Hotspur        178
# 265     Y. Carrasco     Belgium          Atlético Madrid        181
# 269       R. Gosens     Germany                 Atalanta        183
# 274        H. Aouar      France       Olympique Lyonnais        175
#
#     player_positions  overall  potential
# 66                LM       85         90
# 95            LB, LM       85         85
# 96        CM, RM, LM       85         85
# 166           LB, LM       83         84
# 172      CM, CAM, LM       83         83
# 210           LB, LM       83         83
# 212           LB, LM       82         89
# 265               LM       82         82
# 269               LM       82         82
# 274           CM, LM       81         89

# %% [markdown]
# **L. Sané** is the top rated left midfielder with overall rating of 85 and potential rating of 90.

# %% [markdown]
# ### Top 10 Right Midfielders in FIFA 21

# %% [markdown]
# ![cover](https://besthqwallpapers.com/img/original/87242/christian-eriksen-grunge-joy-tottenham-hotspur-fc-danish-footballers.jpg)

# %%
#Top 10 RM in FIFA 21
rm_df=fifa_df[fifa_df.player_positions.str[-2:]=='RM'][['name','nationality','club_name','height_cm','player_positions','overall','potential']]
rm_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#                 name         nationality              club_name  height_cm  \
# 94        C. Eriksen             Denmark                  Inter        181
# 98         R. Mahrez             Algeria        Manchester City        179
# 121      Jesús Navas               Spain             Sevilla FC        172
# 141      M. Ødegaard              Norway            Real Madrid        178
# 147      S. Bergwijn         Netherlands      Tottenham Hotspur        178
# 150        A. Hakimi             Morocco                  Inter        181
# 204         E. Višća  Bosnia Herzegovina  Medipol Başakşehir FK        172
# 208             Rafa            Portugal             SL Benfica        172
# 211  Ronaldo Cabrais              Brazil                 Grêmio        177
# 227  Marcos Llorente               Spain        Atlético Madrid        184
#
#     player_positions  overall  potential
# 94       CAM, CM, RM       85         85
# 98            RW, RM       85         85
# 121           RB, RM       84         84
# 141      CAM, CM, RM       83         89
# 147       LM, LW, RM       83         88
# 150               RM       83         88
# 204               RM       83         83
# 208           LM, RM       83         83
# 211          CAM, RM       83         83
# 227       CM, CF, RM       82         85

# %% [markdown]
# Denmark's **C. Eriksen** is the top rated right midfielder with overall and potential rating of 85.

# %% [markdown]
# ### Top 10 Left Wing Backs in FIFA 21

# %% [markdown]
# ![cover](https://sempreinter.com/wp-content/uploads/2016/05/F-Kostic-.jpg)

# %%
#Top 10 LWB in FIFA 21
lwb_df=fifa_df[fifa_df.player_positions.str[-3:]=='LWB'][['name','nationality','club_name','height_cm','player_positions','overall','potential']]
lwb_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#                name         nationality                club_name  height_cm  \
# 206       F. Kostić              Serbia      Eintracht Frankfurt        184
# 267  M. Halstenberg             Germany               RB Leipzig        188
# 300           Jonny               Spain  Wolverhampton Wanderers        170
# 334   Marcos Alonso               Spain                  Chelsea        188
# 417       N. Schulz             Germany        Borussia Dortmund        181
# 424       B. Davies               Wales        Tottenham Hotspur        182
# 600         D. Rose             England        Tottenham Hotspur        174
# 663        M. Casco           Argentina              River Plate        170
# 693      K. Tierney            Scotland                  Arsenal        178
# 772    S. Kolašinac  Bosnia Herzegovina                  Arsenal        183
#
#     player_positions  overall  potential
# 206          LM, LWB       83         83
# 267      LB, CB, LWB       82         82
# 300              LWB       81         84
# 334          LB, LWB       81         81
# 417      LB, LM, LWB       80         81
# 424          LB, LWB       80         81
# 600          LB, LWB       79         79
# 663          LB, LWB       79         79
# 693          LB, LWB       78         86
# 772          LB, LWB       78         79

# %% [markdown]
# **F. Kostić** is the top rated left wing back with overall and potential rating of 83.

# %% [markdown]
# ### Top 10 Center Attacking Midfielders in FIFA 21

# %% [markdown]
# ![cover](https://c4.wallpaperflare.com/wallpaper/205/990/398/soccer-neymar-brazilian-paris-saint-germain-f-c-wallpaper-preview.jpg)

# %%
#Top 10 CAM in FIFA 21
cam_df=fifa_df[fifa_df.player_positions.str[-3:]=='CAM'][['name','nationality','club_name','player_positions','height_cm','overall','potential']]
cam_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#                     name  nationality            club_name player_positions  \
# 4              Neymar Jr       Brazil  Paris Saint-Germain          LW, CAM
# 22             P. Dybala    Argentina             Juventus          CF, CAM
# 28             J. Sancho      England    Borussia Dortmund      RM, LM, CAM
# 70   S. Milinković-Savić       Serbia                Lazio     CM, CDM, CAM
# 72              M. Depay  Netherlands   Olympique Lyonnais      CF, LW, CAM
# 153       D. van de Beek  Netherlands    Manchester United          CM, CAM
# 162          M. Sabitzer      Austria           RB Leipzig          CM, CAM
# 173              C. Vela       Mexico       Los Angeles FC      RW, LW, CAM
# 181             A. Vidal        Chile                Inter     CM, CDM, CAM
# 196             D. Tadić       Serbia                 Ajax      CF, LW, CAM
#
#      height_cm  overall  potential
# 4          175       91         91
# 22         177       88         89
# 28         180       87         93
# 70         191       85         89
# 72         176       85         88
# 153        184       83         87
# 162        178       83         85
# 173        177       83         83
# 181        180       83         83
# 196        181       83         83

# %% [markdown]
# **Neymar** seems to be the top most rated center attacking midfielder with overall and potential rating of 91.

# %% [markdown]
# ### Top 10 Right Wing Backs in FIFA 21

# %% [markdown]
# ![cover](https://wallpaperaccess.com/full/2466596.jpg)

# %%
#Top 10 RWB in FIFA 21
rwb_df=fifa_df[fifa_df.player_positions.str[-3:]=='RWB'][['name','nationality','club_name','height_cm','player_positions','overall','potential']]
rwb_df.sort_values(['overall','potential'],ascending=(False,False)).head(10)
# Out:
#                 name  nationality                club_name  height_cm  \
# 149   A. Wan-Bissaka      England        Manchester United        183
# 368       N. Mukiele       France               RB Leipzig        187
# 382  Héctor Bellerín        Spain                  Arsenal        178
# 384   L. Klostermann      Germany               RB Leipzig        187
# 476        S. Aurier  Ivory Coast        Tottenham Hotspur        174
# 518     Adama Traoré        Spain  Wolverhampton Wanderers        178
# 667        H. Traoré         Mali         Stade Rennais FC        175
# 686          Emerson       Brazil               Real Betis        181
# 699       G. Montiel    Argentina              River Plate        175
# 778       R. Aguilar       France                AS Monaco        172
#
#     player_positions  overall  potential
# 149          RB, RWB       83         88
# 368      RB, CB, RWB       80         87
# 382          RB, RWB       80         85
# 384      CB, RB, RWB       80         85
# 476          RB, RWB       80         80
# 518          RW, RWB       79         85
# 667          RB, RWB       79         79
# 686      RB, RM, RWB       78         88
# 699          RB, RWB       78         85
# 778          RB, RWB       78         79

# %% [markdown]
# **A. Wan-Bissaka** is the top rated left wing back with overall rating of 83 and potential rating of 88.

# %% [markdown]
# ### Top 10 Heaviest Players in FIFA 21

# %%
heavy_df=fifa_df.sort_values('weight_kg',ascending=False)[['name','age','nationality','club_name','overall','weight_kg']].head(10)
heavy_df
# Out:
#                 name  age    nationality          club_name  overall  \
# 10345   A. Akinfenwa   38        England  Wycombe Wanderers       65
# 9188        C. Seitz   33  United States          DC United       66
# 4003       O. Oularé   24        Belgium  Standard de Liège       71
# 5126     F. Farnolle   35          Benin     BB Erzurumspor       70
# 13863      D. Corozo   32        Ecuador          Delfín SC       62
# 13491   L. Watkowiak   24        Germany      FC St. Gallen       62
# 9252   D. Telgenkamp   33    Netherlands           FC Emmen       66
# 17713    D. Turnbull   22  United States         Portsmouth       55
# 998    L. Unnerstall   29        Germany                PSV       77
# 11407    E. Johansen   27         Norway    Kristiansund BK       64
#
#        weight_kg
# 10345        110
# 9188         107
# 4003         104
# 5126         104
# 13863        104
# 13491        103
# 9252         103
# 17713        103
# 998          103
# 11407        102

# %% [markdown]
# **A. Akinfenwa** is the heaviest player in FIFA 21 with the weight of 110 kg.

# %% [markdown]
# ### Top 10 Hardworking Players in FIFA 21

# %%
w_df=fifa_df[fifa_df.work_rate=='High/High'][['name','age','nationality','player_positions','overall','potential','work_rate']].head(10)
w_df
# Out:
#                name  age     nationality player_positions  overall  potential  \
# 5      K. De Bruyne   29         Belgium          CAM, CM       91         91
# 17         Casemiro   28          Brazil              CDM       89         89
# 21          H. Kane   26         England               ST       88         89
# 30  Bruno Fernandes   25        Portugal          CAM, CM       87         90
# 33     A. Robertson   26        Scotland               LB       87         89
# 34   Bernardo Silva   25        Portugal      RW, CAM, CM       87         88
# 41    P. Aubameyang   31           Gabon           ST, LW       87         87
# 46           H. Son   27  Korea Republic           LM, CF       87         87
# 47  Roberto Firmino   28          Brazil               CF       87         87
# 55       M. Hummels   31         Germany               CB       86         86
#
#     work_rate
# 5   High/High
# 17  High/High
# 21  High/High
# 30  High/High
# 33  High/High
# 34  High/High
# 41  High/High
# 46  High/High
# 47  High/High
# 55  High/High

# %% [markdown]
# **K. De Bruyne** is no doubt the most hard-working player in FIFA 21.

# %% [markdown]
# ### Football Leagues vs Players Frequency in FIFA 21

# %% [markdown]
# ![cover](https://images2.minutemediacdn.com/image/upload/c_fill,w_720,ar_16:9,f_auto,q_auto,g_auto/shape/cover/sport/dataimagejpegbase649j4QAYRXhpZgAASUkqAAgAAAAAAAAAA-7585d74b06b4907a3c6cde0515e7bade.jpg)

# %%
plt.figure(figsize=(20,20))
sns.countplot(y=fifa_df.league_name)
plt.xlabel('Number of Players',fontsize=20)
plt.ylabel('Leauge Names',fontsize=20)
plt.title('Football Leagues vs Players Frequency in FIFA 21',fontsize=20)
plt.show()

# %% [markdown]
# There is no certain majority but English League Championship and USA Major League Soccer are the only two leagues to have more than 1400 players from FIFA 21.<br>

# %%
c=fifa_df[fifa_df.league_name=='English League Championship'].value_counts().sum()+fifa_df[fifa_df.league_name=='USA Major League Soccer'].value_counts().sum()
print('Out of {} players {} players are playing in these two leagues.'.format(fifa_df.shape[0],c))
# Out:
# Out of 18719 players 1410 players are playing in these two leagues.

# %% [markdown]
# ### Top 10 Shooters in FIFA 21

# %%
shooters_df=fifa_df.sort_values('shooting',ascending=False)[['name','age','nationality','club_name','overall','shooting']].head(10)
shooters_df['shooting']=shooters_df['shooting'].astype(int)
shooters_df
# Out:
#                   name  age     nationality          club_name  overall  \
# 1    Cristiano Ronaldo   35        Portugal           Juventus       92
# 0             L. Messi   33       Argentina       FC Barcelona       93
# 3       R. Lewandowski   31          Poland  FC Bayern München       91
# 21             H. Kane   26         England  Tottenham Hotspur       88
# 13           S. Agüero   32       Argentina    Manchester City       89
# 37           L. Suárez   33         Uruguay       FC Barcelona       87
# 43         C. Immobile   30           Italy              Lazio       87
# 168     Z. Ibrahimović   38          Sweden              Milan       83
# 99          E. Haaland   19          Norway  Borussia Dortmund       84
# 46              H. Son   27  Korea Republic  Tottenham Hotspur       87
#
#      shooting
# 1          93
# 0          92
# 3          91
# 21         91
# 13         90
# 37         90
# 43         88
# 168        88
# 99         87
# 46         86

# %% [markdown]
# ### Top 10 Fastest Players in FIFA 21

# %%
fastest_players_df=fifa_df.sort_values(['pace','movement_acceleration','movement_sprint_speed'],ascending=(False,False,False))[['name','age','nationality','club_name','overall','movement_acceleration','movement_sprint_speed','pace']].head(10)
fastest_players_df['pace']=fastest_players_df['pace'].astype(int)
fastest_players_df
# Out:
#                 name  age nationality                club_name  overall  \
# 518     Adama Traoré   24       Spain  Wolverhampton Wanderers       79
# 6          K. Mbappé   21      France      Paris Saint-Germain       90
# 273        A. Davies   19      Canada        FC Bayern München       81
# 933         D. James   22       Wales        Manchester United       77
# 366     Vinícius Jr.   19      Brazil              Real Madrid       80
# 5564        A. Chalá   24     Ecuador                Dijon FCO       69
# 690          I. Sarr   22     Senegal                  Watford       78
# 10           S. Mané   28     Senegal                Liverpool       90
# 1581        C. Ejuke   22     Nigeria          PFC CSKA Moscow       75
# 409   Gelson Martins   25    Portugal                AS Monaco       80
#
#       movement_acceleration  movement_sprint_speed  pace
# 518                      97                     96    96
# 6                        96                     96    96
# 273                      96                     96    96
# 933                      96                     95    95
# 366                      95                     95    95
# 5564                     93                     96    95
# 690                      95                     94    94
# 10                       95                     93    94
# 1581                     95                     93    94
# 409                      94                     94    94

# %% [markdown]
# **Adama Traoré** is the fastest player in FIFA 21.

# %% [markdown]
# ### Count Plotting Players On The Basis of Their Heights

# %%
plt.figure(figsize=(20,20))
sns.countplot(y='height_cm',hue='preferred_foot',data=fifa_df);
plt.ylabel('Heights of the Players (in cm)',fontsize=20)
plt.xlabel('Counts',fontsize=20);
plt.legend(fontsize=10);
plt.show()

# %% [markdown]
# Observation - <br>
# In FIFA 21 there are more than 1000 players with the height 180 cm.<br>
# The plot also clearly shows majority r-footed players are more taller than the l-footed players in maximum specific height points.

# %% [markdown]
# ### Finding Out Players With Maximum Wage(in euro)

# %%
max_wage_df=fifa_df.sort_values('wage_eur',ascending=False)[['name','nationality','age','overall','club_name','wage_eur']]
max_wage_df
# Out:
#                name nationality  age  overall              club_name  wage_eur
# 0          L. Messi   Argentina   33       93           FC Barcelona    560000
# 5      K. De Bruyne     Belgium   29       91        Manchester City    370000
# 15       K. Benzema      France   32       89            Real Madrid    350000
# 25        E. Hazard     Belgium   29       88            Real Madrid    350000
# 17         Casemiro      Brazil   28       89            Real Madrid    310000
# ...             ...         ...  ...      ...                    ...       ...
# 16033   G. Orellana       Chile   33       59         Coquimbo Unido       500
# 7110   A. Kochenkov      Russia   33       68       Lokomotiv Moscow       500
# 11840      J. Alvez     Uruguay   36       64  Centro Atlético Fénix       500
# 11839     L. Cabral    Paraguay   36       64      Nacional Asunción       500
# 8217     M. Riveros    Paraguay   31       67       Sportivo Luqueño       500
#
# [18719 rows x 6 columns]

# %% [markdown]
# ### Top 10 Players With Maximum Wage in FIFA 21

# %%
#Lets find out top 10 players with maximum wage(in euros)
max_wage_df.head(10)
# Out:
#             name nationality  age  overall        club_name  wage_eur
# 0       L. Messi   Argentina   33       93     FC Barcelona    560000
# 5   K. De Bruyne     Belgium   29       91  Manchester City    370000
# 15    K. Benzema      France   32       89      Real Madrid    350000
# 25     E. Hazard     Belgium   29       88      Real Madrid    350000
# 17      Casemiro      Brazil   28       89      Real Madrid    310000
# 24      T. Kroos     Germany   30       88      Real Madrid    310000
# 13     S. Agüero   Argentina   32       89  Manchester City    300000
# 14  Sergio Ramos       Spain   34       89      Real Madrid    300000
# 45  A. Griezmann      France   29       87     FC Barcelona    290000
# 37     L. Suárez     Uruguay   33       87     FC Barcelona    280000

# %% [markdown]
# ### Finding Out Players With Maximum Value(in euro)

# %%
max_val_df=fifa_df.sort_values('value_eur',ascending=False)[['name','nationality','age','overall','club_name','value_eur']]
max_val_df
# Out:
#                  name   nationality  age  overall            club_name  \
# 6           K. Mbappé        France   21       90  Paris Saint-Germain
# 4           Neymar Jr        Brazil   28       91  Paris Saint-Germain
# 5        K. De Bruyne       Belgium   29       91      Manchester City
# 3      R. Lewandowski        Poland   31       91    FC Bayern München
# 10            S. Mané       Senegal   28       90            Liverpool
# ...               ...           ...  ...      ...                  ...
# 16065        K. Miura         Japan   53       59          Yokohama FC
# 6920          Y. Endo         Japan   40       68          Gamba Osaka
# 1026           Hilton        Brazil   42       77      Montpellier HSC
# 11701    H. Sulaimani  Saudi Arabia   43       64              Al Ahli
# 4170       J. Cáceres      Paraguay   40       71     Olimpia Asunción
#
#        value_eur
# 6      105500000
# 4       90000000
# 5       87000000
# 3       80000000
# 10      78000000
# ...          ...
# 16065          0
# 6920           0
# 1026           0
# 11701          0
# 4170           0
#
# [18719 rows x 6 columns]

# %% [markdown]
# ### Top 10 Valuable Players in FIFA 21

# %%
max_val_df.head(10)
# Out:
#               name  nationality  age  overall            club_name  value_eur
# 6        K. Mbappé       France   21       90  Paris Saint-Germain  105500000
# 4        Neymar Jr       Brazil   28       91  Paris Saint-Germain   90000000
# 5     K. De Bruyne      Belgium   29       91      Manchester City   87000000
# 3   R. Lewandowski       Poland   31       91    FC Bayern München   80000000
# 10         S. Mané      Senegal   28       90            Liverpool   78000000
# 11        M. Salah        Egypt   28       90            Liverpool   78000000
# 8      V. van Dijk  Netherlands   28       90            Liverpool   75500000
# 2         J. Oblak     Slovenia   27       91      Atlético Madrid   75000000
# 19     R. Sterling      England   25       88      Manchester City   72500000
# 22       P. Dybala    Argentina   26       88             Juventus   71000000

# %% [markdown]
# ###  Distributions of Players In Different Age Groups

# %%
#Illustrating number of players in different age groups  through histogram 
plt.figure(figsize=(10, 6))
plt.title('DISTRIBUTION OF NUMBER OF PLAYERS IN DIFFERENT AGE GROUPS',fontsize=19)
plt.xlabel('AGE',fontsize=19)
plt.ylabel('NUMBER OF PLAYERS',fontsize=19)
plt.hist(fifa_df.age, bins=np.arange(15,50,5), color='skyblue');

# %% [markdown]
# Through this plot we can see that more than 7000 players in FIFA 21 are in the age group between 20-25.

# %% [markdown]
# ### Players Overall  and Potential Rating  vs Age in FIFA 21

# %%
fig, axes = plt.subplots(1, 2, sharex=True, figsize=(18,10))
fig.suptitle('Overall and Potential Rating vs Age in FIFA 21',fontsize=20)
axes[0].set_title('Overall vs Age')
axes[1].set_title('Potential vs Age')
sns.scatterplot(ax=axes[0],x=fifa_df.age,y=fifa_df.overall);
sns.scatterplot(x=fifa_df.age,y=fifa_df.potential);

# %% [markdown]
# __From the plot what we can say is that here is no single player in age group 36-50  with the overall rating of more than 85.__<br>
# __The players who lies in the age group of 25-35 has the the maximum number of overall rating.__<br>
# __The under 19 players have more potential than their overall.__<br>

# %% [markdown]
# ## Top 15 Players Key Performance Indication in FIFA 21

# %%
fifa_df['mentality']=(fifa_df['mentality_aggression']+fifa_df['mentality_interceptions']+fifa_df['mentality_positioning']+fifa_df['mentality_vision']+fifa_df['mentality_penalties']+fifa_df['mentality_composure'])//6
fifa_df['skill']=(fifa_df['skill_dribbling']+fifa_df['skill_curve']+fifa_df['skill_fk_accuracy']+fifa_df['skill_long_passing']+fifa_df['skill_ball_control'])//5
fifa_df['power']=(fifa_df['power_shot_power']+fifa_df['power_jumping']+fifa_df['power_stamina']+fifa_df['power_strength']+fifa_df['power_long_shots'])//5
fifa_df['attacking']=(fifa_df['attacking_crossing']+fifa_df['attacking_finishing']+fifa_df['attacking_heading_accuracy']+fifa_df['attacking_short_passing']+fifa_df['attacking_volleys'])//5
fifa_df['movement']=(fifa_df['movement_balance']+fifa_df['movement_reactions']+fifa_df['movement_agility']+fifa_df['movement_sprint_speed']+fifa_df['movement_acceleration'])//5

# %%
top_15_players_df=fifa_df.sort_values('overall',ascending=False)[['name','overall','mentality','skill','dribbling','physic','defending','power','attacking','movement']].head(15)
top_15_players_df['dribbling']=top_15_players_df['dribbling'].astype(int)
top_15_players_df['physic']=top_15_players_df['physic'].astype(int)
top_15_players_df['defending']=top_15_players_df['defending'].astype(int)

# %%
# creating the players dataset
top_15_players_df.set_index('name',inplace = True)
plt.figure(figsize=(20,20))
plt.title("Top 15 Players Key Performance Indication",fontsize=30)
ax=sns.heatmap(top_15_players_df,fmt='d',annot=True, linewidths=.5,cmap='Reds',annot_kws={"size": 16});

# %% [markdown]
# **What we can observe -**<br>
# In each attributes we can find the top players like for example Ramos and Bruyne for mentality, Messi, Neymar and Mbappe for dribbling etc.

# %% [markdown]
# Let us save and upload our work to Jovian before continuing

# %% [markdown]
# ### Distribution of Players Mentality Aggression,Positioning and Vision

# %% [markdown]
# **Mentality Aggression -**  This parameter is based on how much the player is mentally aggressive.<br>
# **Mentality Positioning -** This parameter is based on how a player can handle multiple positions while playing.<br>
# **Mentality Vision -** This parameter is based on players mindset during match.

# %%
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(18,10))
fig.suptitle('Distribution of Players Mentality Aggression,Positioning and Vision',fontsize=20)
axes[0].set_title('Mentality Aggression Distribution')
axes[1].set_title('Mentality Positioning Distribution')
axes[2].set_title('Mentality Vision Distribution')
axes[0].hist(fifa_df.mentality_aggression)
axes[1].hist(fifa_df.mentality_positioning)
axes[2].hist(fifa_df.mentality_vision);

# %% [markdown]
# ### Observations

# %% [markdown]
# **Maximum players have the mentality aggression  score of 60-70 in FIFA 21.**<br>
# **More than 5000 players have better mentality vision  score of 50-70 in FIFA 21.**<br>
# **More than 8000 players have mentality positioning score of 65-70.**

# %% [markdown]
# ### Ballon d'OR  Analysis

# %% [markdown]
# **Ballon d'OR** - The Ballon d'Or is an annual football award presented by French news magazine France Football that is one of the oldest and generally regarded as the most prestigious individual award for football players.

# %%
#Dataframe contains players who have won Ballon d'OR in each significant year
won_df
# Out:
#       Year  Rank                  Player            Club Nationality
# 0     1956     1        Stanley Matthews       Blackpool     England
# 24    1957     1      Alfredo Di Stéfano  Real Madrid CF       Spain
# 47    1958     1            Raymond Kopa  Real Madrid CF      France
# 73    1959     1      Alfredo Di Stéfano  Real Madrid CF       Spain
# 99    1960     1  Luis Suárez Miramontes    FC Barcelona       Spain
# ...    ...   ...                     ...             ...         ...
# 1644  2014     1       Cristiano Ronaldo  Real Madrid CF    Portugal
# 1667  2015     1            Lionel Messi    FC Barcelona   Argentina
# 1690  2016     1       Cristiano Ronaldo  Real Madrid CF    Portugal
# 1720  2017     1       Cristiano Ronaldo  Real Madrid CF    Portugal
# 1750  2018     1             Luka Modrić  Real Madrid CF     Croatia
#
# [63 rows x 5 columns]

# %% [markdown]
# From the above what we can see is that there total 63 players who have won Ballon d'OR since 1956.

# %% [markdown]
# But, it is possible that one player could have also won more than one time. So, for brief analysis let's  see each player has won how many Ballon d'OR' awards/got ranked 1.

# %%
won_df.Player.value_counts()
# Out:
# Lionel Messi              5
# Cristiano Ronaldo         5
# Marco van Basten          3
# Johan Cruijff             3
# Michel Platini            3
# Alfredo Di Stéfano        2
# Karl-Heinz Rummenigge     2
# Kevin Keegan              2
# Franz Beckenbauer         2
# Ronaldo                   2
# Roberto Baggio            1
# Hristo Stoichkov          1
# George Weah               1
# Matthias Sammer           1
# Stanley Matthews          1
# Jean Pierre Papin         1
# Rivaldo                   1
# Luis Figo                 1
# Michael Owen              1
# Pavel Nedved              1
# Andriy Shevchenko         1
# Ronaldinho                1
# Fabio Cannavaro           1
# Kaká                      1
# Zinedine Zidane           1
# Igor Belanov              1
# Lothar Matthäus           1
# Ruud Gullit               1
# Raymond Kopa              1
# Luis Suárez Miramontes    1
# Omar Sívori               1
# Josef Masopust            1
# Lev Yashin                1
# Denis Law                 1
# Eusébio                   1
# Bobby Charlton            1
# Flórián Albert            1
# George Best               1
# Gianni Rivera             1
# Gerd Müller               1
# Oleg Blokhin              1
# Allan Simonsen            1
# Paolo Rossi               1
# Luka Modrić               1
# Name: Player, dtype: int64

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "sourajyotipdfghosh/zerotopandas-course-project-starter" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/sourajyotipdfghosh/zerotopandas-course-project-starter
# 'https://jovian.ai/sourajyotipdfghosh/zerotopandas-course-project-starter'

# %% [markdown]
# ## Asking and Answering Questions

# %% [markdown]
# ## Q1:  Who are the top 10 tallest players in FIFA 21?

# %%
top_10_tallest=fifa_df[fifa_df.height_cm>200].sort_values('height_cm',ascending=False).head(10)
top_10_tallest
# Out:
#                       name  age  height_cm  weight_kg     nationality  \
# 10171              T. Holý   28        206        102  Czech Republic
# 4285         C. Pantilimon   33        203         96         Romania
# 11364                A. Ba   26        203         94      Mauritania
# 18199             D. Thiam   22        202         87         Senegal
# 6582   V. Milinković-Savić   23        202         92          Serbia
# 7337           K. Scherpen   20        202         85     Netherlands
# 11569        S. Maierhofer   37        202         98         Austria
# 1361            F. Forster   32        201         93         England
# 17713          D. Turnbull   22        201        103   United States
# 14452           R. Laidlaw   27        201         85        Scotland
#
#                       club_name                   league_name  league_rank  \
# 10171              Ipswich Town            English League One          3.0
# 4285                Denizlispor             Turkish Süper Lig          1.0
# 11364                AJ Auxerre                French Ligue 2          2.0
# 18199                      SPAL               Italian Serie B          2.0
# 6582                     Torino               Italian Serie A          1.0
# 7337                       Ajax            Holland Eredivisie          1.0
# 11569  FC Admira Wacker Mödling  Austrian Football Bundesliga          1.0
# 1361                Southampton        English Premier League          1.0
# 17713                Portsmouth            English League One          3.0
# 14452            Ross County FC          Scottish Premiership          1.0
#
#        overall  potential  ...  mentality_vision  mentality_penalties  \
# 10171       65         67  ...                30                   23
# 4285        71         71  ...                38                   21
# 11364       64         67  ...                31                   47
# 18199       53         65  ...                18                    9
# 6582        68         74  ...                50                   24
# 7337        67         81  ...                31                   12
# 11569       64         64  ...                67                   65
# 1361        76         76  ...                48                   22
# 17713       55         65  ...                33                   12
# 14452       61         64  ...                35                   17
#
#       mentality_composure defending_standing_tackle  defending_sliding_tackle  \
# 10171                  43                        25                        25
# 4285                   65                        19                        17
# 11364                  60                        65                        62
# 18199                  36                        13                        11
# 6582                   65                        15                        19
# 7337                   51                        11                        10
# 11569                  65                        49                        39
# 1361                   54                        13                        12
# 17713                  23                        11                        11
# 14452                  41                        10                        13
#
#        goalkeeping_diving  goalkeeping_handling goalkeeping_kicking  \
# 10171                  68                    60                  56
# 4285                   67                    71                  72
# 11364                   9                    11                  13
# 18199                  53                    52                  62
# 6582                   67                    66                  78
# 7337                   67                    66                  64
# 11569                  14                    12                  15
# 1361                   76                    72                  65
# 17713                  55                    53                  60
# 14452                  63                    59                  56
#
#       goalkeeping_positioning goalkeeping_reflexes
# 10171                      65                   69
# 4285                       70                   72
# 11364                      12                   15
# 18199                      61                   51
# 6582                       67                   68
# 7337                       66                   69
# 11569                       6                   11
# 1361                       75                   80
# 17713                      50                   59
# 14452                      61                   59
#
# [10 rows x 65 columns]

# %%
for names in top_10_tallest.name: print(names)
# Out:
# T. Holý
# C. Pantilimon
# A. Ba
# D. Thiam
# V. Milinković-Savić
# K. Scherpen
# S. Maierhofer
# F. Forster
# D. Turnbull
# R. Laidlaw

# %% [markdown]
# **T. Holý** of **Czech Republic** is the tallest player in FIFA 21 with the height 206 cm.

# %% [markdown]
# ## Question 2 : Is there any correlation between height and age of players in FIFA-21?

# %%
#Let's check if we can find any correlation between player's age and heights with respect to their preferred foots
height_cm_df=fifa_df['height_cm']    #height dataframe
age_df=fifa_df['age']                #age dataframe

# %%
#Along with X-axis I take ages of the players
x_axis=age_df
##Along with Y-axis I take heights of the players
y_axis=height_cm_df
plt.figure(figsize=(20,15))
sns.set_style('darkgrid')
sns.scatterplot(x='age',y='height_cm',data=fifa_df)
#L-footed and R-footed players are seperated through hue
plt.xlabel('Age')
plt.ylabel('Height(cm)')
plt.title('Ages, Heights, and Preffered Foot of Players')
plt.show()

# %% [markdown]
# #### Observation ::
#  1. The sort of correlation that can be visualized is that the [20-30] age group has the maximum peak heights like in between 180-200 (more than 200 cm) cm.<br>
#  2. So if we compare R.footed players and L.footed players with respect to their heights then it is clearly visible that R.footed players are more taller than most of the L.footed players.

# %% [markdown]
# ## Q3 : Who are the top 20 strongest players in FIFA 21?

# %%
strongest_df=fifa_df[['name','age','nationality','power_strength','player_positions','overall']].sort_values('power_strength',ascending=False).head(20)
strongest_df
# Out:
#                    name  age               nationality  power_strength  \
# 10345      A. Akinfenwa   38                   England              97
# 11973           D. Dike   20             United States              96
# 78            R. Lukaku   27                   Belgium              95
# 3937          A. Méndez   24                   Uruguay              95
# 6709         A. Vukotić   24                    Serbia              95
# 6762        F. Carvalho   26                   Uruguay              94
# 7889        T. Petrášek   28            Czech Republic              94
# 26         K. Koulibaly   29                   Senegal              94
# 1613           P. Cissé   24                   Senegal              94
# 11569     S. Maierhofer   37                   Austria              94
# 339           S. Coates   29                   Uruguay              94
# 4003          O. Oularé   24                   Belgium              94
# 576        G. Kondogbia   27  Central African Republic              94
# 6810          F. Ballas   27                   Germany              94
# 11424        U. Ikpeazu   25                    Uganda              94
# 3930            F. Boya   24                  Cameroon              93
# 885    Vincente Dourado   24                    Brazil              93
# 480             W. Boly   29                    France              93
# 1738       A. Cornelius   27                   Denmark              93
# 6312          C. Garcés   30                   Ecuador              93
#
#       player_positions  overall
# 10345               ST       65
# 11973               ST       63
# 78                  ST       85
# 3937            RB, LB       71
# 6709                CB       68
# 6762                CB       68
# 7889                CB       67
# 26                  CB       88
# 1613                CB       75
# 11569               ST       64
# 339                 CB       81
# 4003                ST       71
# 576            CM, CDM       79
# 6810                CB       68
# 11424               ST       64
# 3930       CDM, CM, CB       71
# 885                 CB       78
# 480                 CB       80
# 1738                ST       75
# 6312                ST       69

# %%
for names in strongest_df.name:print(names)
# Out:
# A. Akinfenwa
# D. Dike
# R. Lukaku
# A. Méndez
# A. Vukotić
# F. Carvalho
# T. Petrášek
# K. Koulibaly
# P. Cissé
# S. Maierhofer
# S. Coates
# O. Oularé
# G. Kondogbia
# F. Ballas
# U. Ikpeazu
# F. Boya
# Vincente Dourado
# W. Boly
# A. Cornelius
# C. Garcés

# %% [markdown]
# ## Q3: Which country has the most number of left-footed players with stupendous fk accuracy in FIFA 21 ?

# %%
#Let's also check which country has the most number of L-footed players..
lfooted_count=fifa_df[['name','nationality','preferred_foot']][(fifa_df.preferred_foot=='Left') & (fifa_df.skill_fk_accuracy>75)]
lfooted_count=lfooted_count['nationality'].value_counts()
lfooted_count=pd.DataFrame(lfooted_count)
print(str(lfooted_count['nationality'].head(1)))
# Out:
# Spain    21
# Name: nationality, dtype: int64

# %% [markdown]
# It is clear that Spanish Left-footed players have more fk accuracy than other countries players in FIFA 21.

# %% [markdown]
# ## Q4 :  Which countries have the best under 19  potential in FIFA 21?

# %%
best_up=fifa_df[(fifa_df.potential>75) &(fifa_df.age<20)]
best_up=best_up.sort_values('potential', ascending = False)
best_up=best_up[['name','club_name','nationality','potential']]
x_axis=best_up['potential']
y_axis=best_up['nationality']
plt.figure(figsize=(20,20))
sns.barplot(x=best_up.potential, y=best_up.nationality, data=best_up)
plt.title('Which Nations Have The Best Under 19 Potential?',fontsize=20)
plt.show()

# %% [markdown]
# **Brazil** has the maximum number of under 19 potentials with more than 80 in FIFA 21.

# %% [markdown]
# ## Q5 : Which top 10 players have the ability to take long range shots with best accuracy in FIFA 21?

# %%
fifa_df['long_free_kick_pow_acc']=(fifa_df['power_long_shots']+fifa_df['skill_fk_accuracy']+fifa_df['power_shot_power']+fifa_df['shooting']+fifa_df['power_stamina']+fifa_df['power_strength'])//6
p_df=fifa_df[['name','age','nationality','long_free_kick_pow_acc','overall','club_name']].sort_values('long_free_kick_pow_acc',ascending=False).head(10)
p_df['long_free_kick_pow_acc']=p_df['long_free_kick_pow_acc'].astype(int)
p_df
# Out:
#                   name  age nationality  long_free_kick_pow_acc  overall  \
# 1    Cristiano Ronaldo   35    Portugal                      86       92
# 459               Hulk   33      Brazil                      85       80
# 3       R. Lewandowski   31      Poland                      85       91
# 5         K. De Bruyne   29     Belgium                      85       91
# 37           L. Suárez   33     Uruguay                      85       87
# 21             H. Kane   26     England                      84       88
# 345         K. Volland   27     Germany                      84       81
# 49            P. Pogba   27      France                      84       86
# 591     R. Malinovskyi   27     Ukraine                      84       79
# 30     Bruno Fernandes   25    Portugal                      84       87
#
#              club_name
# 1             Juventus
# 459   Shanghai SIPG FC
# 3    FC Bayern München
# 5      Manchester City
# 37        FC Barcelona
# 21   Tottenham Hotspur
# 345          AS Monaco
# 49   Manchester United
# 591           Atalanta
# 30   Manchester United

# %% [markdown]
# Looks like CR7 is the  best in case of taking long range shots with best accuracy in FIFA 21 , followed by Hulk, Lewandowski etc.

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "sourajyotipdfghosh/zerotopandas-course-project-starter" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/sourajyotipdfghosh/zerotopandas-course-project-starter
# 'https://jovian.ai/sourajyotipdfghosh/zerotopandas-course-project-starter'

# %% [markdown]
# ## Inferences and Conclusion
#
# After the analysis I have computed many interesting conclusions from this dataset.Some of are ---- <br>
# There are total 18719 players in FIFA 21.<br>
# There are total 161 different countries from where there are players in FIFA 21. Out of which England,Germany and Spain these 3 countries has more than 1000 players. <br>
# The range of ages of the players is between 16 and 53<br>
# The range of weights(in kg) of the players is between 50 and 110<br>
# The maximum potential of the players : 95<br>
# The minimum potential rating of the players : 47<br>
# The maximum overall rating of the players : 93<br>
# The minimum overall rating of the players : 47<br>
# The average potential rating of players : 71.22<br>
# The average overall rating of players : 65.77<br>
# The range of heights(in cm) of the players is between 155 and 203<br>
# The range of values(in eur) of the players is between 1.666600e+04 and 1.055000e+08<br>
# L. Messi is the only player in FIFA 21 right now who has won individual 6 Ballon d'OR awards and it's a record followed by Ronald <br>
# Out of all players, 92.88% players have international reputation of 1 in FIFA 21<br>
# Center Back is the most played position in FIFA 21.<br>
# Spain is the only country which more than 20 L-Footed players with best long range shooting accuracy.<br>
# England,Germany and Spain are major countries in case of number of players.Because these 3 countries individually more than 1000 player in FIFA 21<br>
# **There is no particular playing position of maximum players because depending upon the situation of game,player's playing position also does change.So,we can't select a single playing position for each player in FIFA 21.**<br>
# More than 7000 players in FIFA 21 are in the age group between 20-25.<br>
# The 15-25 players have more potential than their overall.It is expected that these age group players can perform better in their upcoming matches in FIFA 21.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "sourajyotipdfghosh/fifa-21-data-analysis" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/sourajyotipdfghosh/fifa-21-data-analysis
# 'https://jovian.ai/sourajyotipdfghosh/fifa-21-data-analysis'

# %% [markdown]
# ## References and Future Works
#
# Thanks for giving a view on my project.
# I hope you watched my entire analysis on FIFA 21 and get some knowledge from it. This Project is a part of the Course<a href="https://jovian.ai/learn/data-analysis-with-python-zero-to-pandas"> `DATA ANALYSIS WITH PYTHON :ZERO_TO_PANDAS`.</a>
# I would like to express my gratitude to _Aakash NS_ and the whole _Jovian.ml_ team for giving me an Oppurtunity to make such an wonderful data exploratory project. Follow [Jovian](https://jovian.ml/forum/) forum to know more about different courses on Data Science, ML etc. and connect with a huge community of students and enthusiasts.
#
# __Future Work__
#
# There are lot of scopes of improvement can be added in this project in future, with the data provided and adding extra datasets we can,
# * Create our best 11 players team from choosing each best player from each different playing positions.
# * calculate club revenues using an extra dataset from kaggle.
# * also do analysis of goals of each player from different positions.
# * make comparison chart of Lionel Messi vs Cristiano Ronaldo by all parameters and also summarize from that analysis that who is the best ?
# * distinguish the relation between overall rating and potential rating of players age wise.
#
# __REFERENCES__
#
# * FIFA 21 Dataset: https://www.kaggle.com/stefanoleone992/fifa-21-complete-player-dataset?select=players_21.csv
# * Ballon d'OR Dataset : https://raw.githubusercontent.com/Sourajyoti1234/FIFA21_required_csv_files/main/BallonDOr.csv
#
# * Kaggle Datasets (Choose Dataset of your choice): https://www.kaggle.com/datasets
#
# * Pandas user guide: https://pandas.pydata.org/docs/user_guide/index.html
#
# * Matplotlib user guide: https://matplotlib.org/3.3.1/users/index.html
#
# * Seaborn user guide & tutorial: https://seaborn.pydata.org/tutorial.html
#
# * Data analysis guide(https://jovian.ml/aakashns/python-pandas-data-analysis)
#
# * Jovian Forum (Ask Questions in this great community): https://jovian.ml/forum/
#
# * Stackoverflow Community (Get answers of any problems): https://stackoverflow.com/questions
#
# * Python solutions in Geeksforgeeks (Solutions made easy): https://www.geeksforgeeks.org/python-programming-language/
#
# * For basic understanding of how FIFA calculate ratings of players :https://www.goal.com/en-ae/news/fifa-player-ratings-explained-how-are-the-card-number-stats/1hszd2fgr7wgf1n2b2yjdpgynu
#
#
# ### Steps to run this Notebook
#
# At first SignUp and Login in [https://www.jovian.ai/](https://www.jovian.ml) and click on the __Run__ Button.
# * Select Run on Binder a new tab will open.
# * Give some time for the binder to setup it will automatically set up an environment for you
# * Open the Jupyter Notebook that loads in your browser tab.
# * Select Kernel and Restart & Clear Output and then follow the below steps to download the dataset within the notebook
#
# __Kaggle__ allows users to find and publish data sets, explore and build models in a web-based data-science environment, work with other data scientists and machine learning engineers, and enter competitions to solve data science challenges.
#
# When you try to run the notebook, the code will stop at a time and ask for Kaggle Username and Kaggle Key to download the dataset from the Kaggle Website. Follow the steps given below to get your Kaggle username and Kaggle API Key
# 1. Sign in to https://kaggle.com/, then click on your profile picture on the top right and select "My Account" from the menu
# 2. Scroll down to the "API" section and click "Create New API Token". This will download a file kaggle.json with the following contents: {"username":"YOUR_KAGGLE_USERNAME","key":"YOUR_KAGGLE_KEY"}
# 3. When you run opendatsets.download, you will be asked to enter your username & Kaggle API, which you can get from the file downloaded in step 2.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "sourajyotipdfghosh/fifa-21-data-analysis" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/sourajyotipdfghosh/fifa-21-data-analysis
# 'https://jovian.ai/sourajyotipdfghosh/fifa-21-data-analysis'
